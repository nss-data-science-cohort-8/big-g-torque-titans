# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier, MLPRegressor

from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, OrdinalEncoder
# from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline 
from sklearn.compose import ColumnTransformer

from sklearn.metrics import (
        classification_report, confusion_matrix, r2_score, mean_squared_error, root_mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score, f1_score, roc_auc_score, roc_curve, precision_recall_curve
)

from sklearn.inspection import PartialDependenceDisplay

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV, RepeatedStratifiedKFold
from xgboost import XGBClassifier, XGBRegressor, plot_importance
from sklearn.model_selection import cross_val_score

# %%
from category_encoders import TargetEncoder 
from sklearn.feature_selection import SelectFromModel

# %%
# from sklearn.datasets import make_classification

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
from feature_engine.imputation import CategoricalImputer
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor

# %%
from xgbimputer import XGBImputer

# %%
TrainPre2019 = pd.read_csv('../data/Pre2019_df_Cat9999999.csv')
# Out:
# /var/folders/nl/hqcw9pqd0ns4q0b61syv0q2m0000gn/T/ipykernel_24123/2282598049.py:1: DtypeWarning: Columns (17,41,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   TrainPre2019 = pd.read_csv('../data/Pre2019_df_Cat9999999.csv')

# %%
TrainPre2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 949528 entries, 0 to 949527
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0.1                    949528 non-null  int64
#  1   Unnamed: 0                      949528 non-null  int64
#  2   RecordID                        949528 non-null  int64
#  3   ESS_Id                          949528 non-null  int64
#  4   EventTimeStamp                  949528 non-null  object
#  5   eventDescription                902364 non-null  object
#  6   actionDescription               0 non-null       float64
#  7   ecuSoftwareVersion              747330 non-null  object
#  8   ecuSerialNumber                 707932 non-null  object
#  9   ecuModel                        900949 non-null  object
#  10  ecuMake                         900949 non-null  object
#  11  ecuSource                       949528 non-null  int64
#  12  spn                             949528 non-null  float64
#  13  fmi                             949528 non-null  float64
#  14  active                          949528 non-null  bool
#  15  activeTransitionCount           949528 non-null  int64
#  16  faultValue                      0 non-null       float64
#  17  EquipmentID                     949528 non-null  object
#  18  MCTNumber                       949528 non-null  int64
#  19  Latitude                        949528 non-null  float64
#  20  Longitude                       949528 non-null  float64
#  21  LocationTimeStamp               949528 non-null  object
#  22  FaultId                         949528 non-null  int64
#  23  AcceleratorPedal                426247 non-null  float64
#  24  BarometricPressure              476659 non-null  float64
#  25  CruiseControlActive             466508 non-null  object
#  26  CruiseControlSetSpeed           467458 non-null  float64
#  27  DistanceLtd                     476568 non-null  float64
#  28  EngineCoolantTemperature        476625 non-null  float64
#  29  EngineLoad                      476168 non-null  float64
#  30  EngineOilPressure               476735 non-null  float64
#  31  EngineOilTemperature            475236 non-null  float64
#  32  EngineRpm                       476956 non-null  float64
#  33  EngineTimeLtd                   472796 non-null  float64
#  34  FuelLevel                       402392 non-null  float64
#  35  FuelLtd                         476017 non-null  float64
#  36  FuelRate                        475932 non-null  float64
#  37  FuelTemperature                 248414 non-null  float64
#  38  IgnStatus                       494185 non-null  object
#  39  IntakeManifoldTemperature       476730 non-null  float64
#  40  LampStatus                      949528 non-null  float64
#  41  ParkingBrake                    303591 non-null  object
#  42  ServiceDistance                 200 non-null     float64
#  43  Speed                           475134 non-null  float64
#  44  SwitchedBatteryVoltage          102624 non-null  object
#  45  Throttle                        320557 non-null  float64
#  46  TurboBoostPressure              474652 non-null  float64
#  47  spn_fmi                         949528 non-null  object
#  48  is_fullderate                   949528 non-null  int64
#  49  is_fullderate_group             949528 non-null  int64
#  50  EquipID_Index                   949528 non-null  object
#  51  time_to_next_SPN5246            949528 non-null  float64
#  52  time_interval_to_SPN5246_class  949528 non-null  int64
# dtypes: bool(1), float64(27), int64(11), object(14)
# memory usage: 377.6+ MB

# %% [markdown]
# **Goal:** Predict the rank based on the total shots.

# %%
TrainPre2019['time_interval_to_SPN5246_class'].value_counts()
# Out:
# time_interval_to_SPN5246_class
# 9999999    715686
# 0          229509
# 1            2233
# 2            1263
# 3             837
# Name: count, dtype: int64

# %%
TrainPre2019
# Out:
#         Unnamed: 0.1  Unnamed: 0  RecordID   ESS_Id       EventTimeStamp  \
# 0              43931       48303     49415  2363162  2015-05-11 13:11:20
# 1              45693       50251     51363  2400445  2015-05-13 08:22:32
# 2              50271       55260     57330  2482983  2015-05-18 09:34:05
# 3              54326       59636     61706  2554027  2015-05-21 13:57:35
# 4              54418       59731     61801  2555325  2015-05-21 14:54:32
# ...              ...         ...       ...      ...                  ...
# 949523          4036        4494      4495  1052146  2015-02-24 16:24:05
# 949524          5907        6438      6439  1089561  2015-02-26 13:12:11
# 949525          5915        6446      6447  1090499  2015-02-26 13:50:59
# 949526          4472        4952      4953  1059704  2015-02-25 06:08:43
# 949527          4512        4999      5000  1060204  2015-02-25 06:38:40
#
#                                          eventDescription  actionDescription  \
# 0       Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# 1           Condition Exists Cruise Control Enable Switch                NaN
# 2       Abnormal Rate of Change Aftertreatment 1 Outle...                NaN
# 3       Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# 4       Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# ...                                                   ...                ...
# 949523          Low (Severity Medium) Catalyst Tank Level                NaN
# 949524                                                NaN                NaN
# 949525                                                NaN                NaN
# 949526  Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# 949527  Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
#
#                                      ecuSoftwareVersion ecuSerialNumber  \
# 0                                               unknown         unknown
# 1                                               unknown         unknown
# 2                                       PC4__1284P4C_2*         6U13D13
# 3                                               unknown         unknown
# 4                                               unknown         unknown
# ...                                                 ...             ...
# 949523  05317106*04119044*051914190353*09400015*G1*BDR*        79751302
# 949524  05317106*04119044*051914190353*09400015*G1*BDR*        79751302
# 949525  05317106*04119044*051914190353*09400015*G1*BDR*        79751302
# 949526                                          unknown         unknown
# 949527                                          unknown         unknown
#
#                  ecuModel  ...      Speed  SwitchedBatteryVoltage  Throttle  \
# 0                 unknown  ...   4.475814                 3276.75      14.4
# 1                 unknown  ...  64.637170                 3276.75      89.6
# 2                      MX  ...  63.525490                 3276.75       0.0
# 3                 unknown  ...   4.364162                 3276.75      12.0
# 4                 unknown  ...        NaN                     NaN       NaN
# ...                   ...  ...        ...                     ...       ...
# 949523  6X1u13D1500000000  ...        NaN                     NaN       NaN
# 949524  6X1u13D1500000000  ...   2.058292                 3276.75       0.0
# 949525  6X1u13D1500000000  ...        NaN                     NaN       NaN
# 949526            unknown  ...   4.378725                 3276.75       0.0
# 949527            unknown  ...        NaN                     NaN       NaN
#
#         TurboBoostPressure      spn_fmi  is_fullderate  is_fullderate_group  \
# 0                     0.58    639.0_2.0              0                    0
# 1                     4.64   596.0_31.0              0                    0
# 2                    20.30  3226.0_10.0              0                    0
# 3                     1.45    639.0_2.0              0                    0
# 4                      NaN    639.0_2.0              0                    0
# ...                    ...          ...            ...                  ...
# 949523                 NaN  1761.0_18.0              0                    0
# 949524                0.29   5848.0_9.0              0                    0
# 949525                 NaN   5848.0_9.0              0                    0
# 949526                1.74    639.0_2.0              0                    0
# 949527                 NaN    639.0_2.0              0                    0
#
#        EquipID_Index  time_to_next_SPN5246  time_interval_to_SPN5246_class
# 0              301_0          1.027800e+04                               0
# 1              301_0          1.023481e+04                               0
# 2              301_0          1.011362e+04                               0
# 3              301_0          1.003723e+04                               0
# 4              301_0          1.003628e+04                               0
# ...              ...                   ...                             ...
# 949523       R1762_0          2.400000e+08                         9999999
# 949524       R1762_0          2.400000e+08                         9999999
# 949525       R1762_0          2.400000e+08                         9999999
# 949526       R1764_0          2.400000e+08                         9999999
# 949527       R1764_0          2.400000e+08                         9999999
#
# [949528 rows x 53 columns]

# %% [markdown]
# class MultiColumnLabelEncoder:
#     def __init__(self,columns = None):
#         self.columns = columns # array of column names to encode
#
#     def fit(self,X,y=None):
#         return self # not relevant here
#
#     def transform(self,X):
#         '''
#         Transforms columns of X specified in self.columns using
#         LabelEncoder(). If no columns specified, transforms all
#         columns in X.
#         '''
#         output = X.copy()
#         if self.columns is not None:
#             for col in self.columns:
#                 output[col] = OneHotEncoder().fit_transform(output[col])
#         else:
#             for colname,col in output.iteritems():
#                 output[colname] = OneHotEncoder().fit_transform(col)
#         return output
#
#     def fit_transform(self,X,y=None):
#         return self.fit(X,y).transform(X)

# %%
TrainPre2019[['ecuSource', 'LampStatus', 'time_interval_to_SPN5246_class', 'ecuSerialNumber', 'ecuModel', 'ecuMake']] = TrainPre2019[['ecuSource', 'LampStatus', 'time_interval_to_SPN5246_class', 'ecuSerialNumber', 'ecuModel', 'ecuMake']].astype('category')

# %%
TrainPre2019[['activeTransitionCount']] = TrainPre2019[['activeTransitionCount']].astype('category')

# %%
TrainPre2019.replace(to_replace='3276,75', value='3278.75', inplace=True)

# %%
TrainPre2019[[  'AcceleratorPedal',
                    'BarometricPressure',
                    'CruiseControlSetSpeed',
                    'DistanceLtd',
                    'EngineCoolantTemperature',
                    'EngineLoad',
                    'EngineOilPressure',
                    'EngineOilTemperature',
                    'EngineRpm',
                    'EngineTimeLtd',
                    'FuelLevel',
                    'FuelLtd',
                    'FuelRate',
                    'FuelTemperature',
                    'IntakeManifoldTemperature',
                    'Speed',
                    'Throttle',
                    'active',
                    'TurboBoostPressure',
                    'CruiseControlActive',
                    'IgnStatus',
                    'ParkingBrake',
                    'SwitchedBatteryVoltage'
]] = TrainPre2019[[                         'AcceleratorPedal',
                                            'BarometricPressure',
                                            'CruiseControlSetSpeed',
                                            'DistanceLtd',
                                            'EngineCoolantTemperature',
                                            'EngineLoad',
                                            'EngineOilPressure',
                                            'EngineOilTemperature',
                                            'EngineRpm',
                                            'EngineTimeLtd',
                                            'FuelLevel',
                                            'FuelLtd',
                                            'FuelRate',
                                            'FuelTemperature',
                                            'IntakeManifoldTemperature',
                                            'Speed',
                                            'Throttle',
                                            'active',
                                            'TurboBoostPressure',
                                            'CruiseControlActive',
                                            'IgnStatus',
                                            'ParkingBrake',
                                            'SwitchedBatteryVoltage'
                     ]].astype('float64')

# %%
NumericColumns = TrainPre2019.select_dtypes(include=[np.number]).columns.tolist()
NumericColumns_Without_MatchID = NumericColumns.pop(0)
NumericColumns
# Out:
# ['Unnamed: 0',
#  'RecordID',
#  'ESS_Id',
#  'actionDescription',
#  'spn',
#  'fmi',
#  'active',
#  'faultValue',
#  'MCTNumber',
#  'Latitude',
#  'Longitude',
#  'FaultId',
#  'AcceleratorPedal',
#  'BarometricPressure',
#  'CruiseControlActive',
#  'CruiseControlSetSpeed',
#  'DistanceLtd',
#  'EngineCoolantTemperature',
#  'EngineLoad',
#  'EngineOilPressure',
#  'EngineOilTemperature',
#  'EngineRpm',
#  'EngineTimeLtd',
#  'FuelLevel',
#  'FuelLtd',
#  'FuelRate',
#  'FuelTemperature',
#  'IgnStatus',
#  'IntakeManifoldTemperature',
#  'ParkingBrake',
#  'ServiceDistance',
#  'Speed',
#  'SwitchedBatteryVoltage',
#  'Throttle',
#  'TurboBoostPressure',
#  'is_fullderate',
#  'is_fullderate_group',
#  'time_to_next_SPN5246']

# %% [markdown]
# Among numeric columns, will keep:
#
#
# ['AcceleratorPedal',
# 'BarometricPressure',
# 'CruiseControlSetSpeed',
# 'DistanceLtd',
# 'EngineCoolantTemperature',
# 'EngineLoad',
# 'EngineOilPressure',
# 'EngineOilTemperature',
# 'EngineRpm',
# 'EngineTimeLtd',
# 'FuelLevel',
# 'FuelLtd',
# 'FuelRate',
# 'FuelTemperature',
# 'IntakeManifoldTemperature',
# 'Speed',
# 'Throttle',
# 'active',
# 'TurboBoostPressure',
# 'activeTransitionCount',
# 'CruiseControlActive',
# 'IgnStatus',
# 'ParkingBrake',
# 'SwitchedBatteryVoltage']

# %%
NonNumericColumns = TrainPre2019.select_dtypes(exclude=[np.number]).columns.tolist()
NonNumericColumns
# Out:
# ['EventTimeStamp',
#  'eventDescription',
#  'ecuSoftwareVersion',
#  'ecuSerialNumber',
#  'ecuModel',
#  'ecuMake',
#  'ecuSource',
#  'activeTransitionCount',
#  'EquipmentID',
#  'LocationTimeStamp',
#  'LampStatus',
#  'spn_fmi',
#  'EquipID_Index',
#  'time_interval_to_SPN5246_class']

# %% [markdown]
# Among, non-numeric columns, will keep:
#
#         ('target_encoder', TargetEncoder(handle_unknown='ignore'), [   'ecuSoftwareVersion',
#                                                                         'ecuSerialNumber',
#                                                                         'ecuModel',
#                                                                         'ecuMake',
#                                                                         'spn_fmi'
#                                                                     ]),
#         ('ordinal_encoder', OrdinalEncoder(handle_unknown='ignore'), [   'ecuSource',
#                                                                                 'LampStatus'
#                                                                         ])

# %%
X = TrainPre2019.drop(columns = [   'Unnamed: 0',
                                    'Unnamed: 0.1',
                                    'RecordID',
                                    'ESS_Id',
                                    'actionDescription',
                                    'spn',
                                    'fmi',
                                    'faultValue',
                                    'MCTNumber',
                                    'Latitude',
                                    'Longitude',
                                    'is_fullderate',
                                    'is_fullderate_group',
                                    'time_to_next_SPN5246',
                                    'ServiceDistance',
                                    'EventTimeStamp',
                                    'eventDescription',
                                    'EquipmentID',
                                    'LocationTimeStamp',
                                    'EquipID_Index',
                                    'time_interval_to_SPN5246_class',
                                    'MCTNumber',                                  
                                    'FaultId',
                                    'ecuSoftwareVersion',
                                    'ecuSerialNumber',
                                    'ecuModel',
                                    'ecuMake'                                                                                      
                                ]
                      )
y = TrainPre2019['time_interval_to_SPN5246_class']

# %%
X['spn_fmi'] = X['spn_fmi'].str.replace('.0', '')

# %%
X
# Out:
#        ecuSource  active activeTransitionCount  AcceleratorPedal  \
# 0             11     1.0                   127              14.4
# 1             49     1.0                     3              89.6
# 2              0     1.0                     6               0.0
# 3             11     1.0                   127              12.0
# 4             11     0.0                   127               NaN
# ...          ...     ...                   ...               ...
# 949523         0     0.0                    11               NaN
# 949524         0     1.0                     1               0.0
# 949525         0     0.0                     1               NaN
# 949526        11     1.0                   127              21.6
# 949527        11     0.0                   127               NaN
#
#         BarometricPressure  CruiseControlActive  CruiseControlSetSpeed  \
# 0                  13.9200                  0.0                0.00000
# 1                  14.4275                  0.0                0.00000
# 2                  14.3550                  0.0                0.00000
# 3                  14.5725                  0.0                0.00000
# 4                      NaN                  NaN                    NaN
# ...                    ...                  ...                    ...
# 949523                 NaN                  NaN                    NaN
# 949524             14.2100                  0.0               66.48672
# 949525                 NaN                  NaN                    NaN
# 949526             14.4275                  0.0               66.48672
# 949527                 NaN                  NaN                    NaN
#
#         DistanceLtd  EngineCoolantTemperature  EngineLoad  ...  \
# 0         120841.70                     185.0        18.0  ...
# 1         121687.10                     186.8        38.0  ...
# 2         123057.10                     185.0         0.0  ...
# 3         124496.50                     183.2        14.0  ...
# 4               NaN                       NaN         NaN  ...
# ...             ...                       ...         ...  ...
# 949523          NaN                       NaN         NaN  ...
# 949524     80838.70                     134.6        11.0  ...
# 949525          NaN                       NaN         NaN  ...
# 949526     83681.85                     154.4        12.0  ...
# 949527          NaN                       NaN         NaN  ...
#
#         FuelTemperature  IgnStatus  IntakeManifoldTemperature  LampStatus  \
# 0                 134.6        1.0                      154.4      1279.0
# 1                 100.4        1.0                      120.2      4351.0
# 2                 120.2        1.0                      118.4     17407.0
# 3                 109.4        1.0                      107.6      1279.0
# 4                   NaN        NaN                        NaN      1279.0
# ...                 ...        ...                        ...         ...
# 949523              NaN        NaN                        NaN      1023.0
# 949524             32.0        1.0                       84.2     17407.0
# 949525              NaN        NaN                        NaN      1023.0
# 949526             32.0        1.0                       93.2      1279.0
# 949527              NaN        NaN                        NaN      1279.0
#
#         ParkingBrake      Speed  SwitchedBatteryVoltage  Throttle  \
# 0                0.0   4.475814                 3276.75      14.4
# 1                0.0  64.637170                 3276.75      89.6
# 2                0.0  63.525490                 3276.75       0.0
# 3                0.0   4.364162                 3276.75      12.0
# 4                NaN        NaN                     NaN       NaN
# ...              ...        ...                     ...       ...
# 949523           NaN        NaN                     NaN       NaN
# 949524           0.0   2.058292                 3276.75       0.0
# 949525           NaN        NaN                     NaN       NaN
# 949526           0.0   4.378725                 3276.75       0.0
# 949527           NaN        NaN                     NaN       NaN
#
#         TurboBoostPressure  spn_fmi
# 0                     0.58    639_2
# 1                     4.64   596_31
# 2                    20.30  3226_10
# 3                     1.45    639_2
# 4                      NaN    639_2
# ...                    ...      ...
# 949523                 NaN  1761_18
# 949524                0.29   5848_9
# 949525                 NaN   5848_9
# 949526                1.74    639_2
# 949527                 NaN    639_2
#
# [949528 rows x 27 columns]

# %%
y
# Out:
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
#            ...
# 949523    9999999
# 949524    9999999
# 949525    9999999
# 949526    9999999
# 949527    9999999
# Name: time_interval_to_SPN5246_class, Length: 949528, dtype: category
# Categories (5, int64): [0, 1, 2, 3, 9999999]

# %%
X.describe()
# Out:
#               active  AcceleratorPedal  BarometricPressure  \
# count  949528.000000     426247.000000       476659.000000
# mean        0.520453         28.544902           14.191954
# std         0.499582         36.550423            1.195484
# min         0.000000          0.000000            3.045000
# 25%         0.000000          0.000000           14.210000
# 50%         1.000000          4.000000           14.355000
# 75%         1.000000         48.800000           14.500000
# max         1.000000        100.000000           15.225000
#
#        CruiseControlActive  CruiseControlSetSpeed    DistanceLtd  \
# count        466508.000000          467458.000000  476568.000000
# mean              0.096682              62.174458  364626.882789
# std               0.295525              12.239142  142701.441105
# min               0.000000               0.000000       0.000000
# 25%               0.000000              64.622600  267338.900000
# 50%               0.000000              66.486720  379825.250000
# 75%               0.000000              66.486720  481544.650000
# max               1.000000              69.593570  649549.000000
#
#        EngineCoolantTemperature     EngineLoad  EngineOilPressure  \
# count             476625.000000  476168.000000      476735.000000
# mean                 169.566761      31.959878          33.453187
# std                   32.811442      30.635726          11.282650
# min                   -7.600000       0.000000           0.000000
# 25%                  170.600000      11.000000          28.420000
# 50%                  183.200000      19.000000          36.540000
# 75%                  186.800000      48.000000          39.440000
# max                  406.400000     101.000000         145.000000
#
#        EngineOilTemperature  ...        FuelLtd       FuelRate  \
# count         475236.000000  ...  476017.000000  475932.000000
# mean             187.261404  ...   50560.896556       4.627839
# std               61.171250  ...   24171.307050       5.783522
# min              -39.156250  ...       0.000000       0.000000
# 25%              179.937500  ...   33494.638645       0.647223
# 50%              202.775000  ...   51938.602972       1.690706
# 75%              214.531300  ...   68751.040705       7.211920
# max             3212.544000  ...  312737.574126      25.611560
#
#        FuelTemperature      IgnStatus  IntakeManifoldTemperature  \
# count    248414.000000  494185.000000              476730.000000
# mean         37.043151       0.995724                 106.750817
# std          23.152840       0.065249                  25.476308
# min          17.600000       0.000000                 -40.000000
# 25%          32.000000       1.000000                  89.600000
# 50%          32.000000       1.000000                 109.400000
# 75%          32.000000       1.000000                 125.600000
# max         231.800000       1.000000                 264.200000
#
#         ParkingBrake          Speed  SwitchedBatteryVoltage       Throttle  \
# count  303591.000000  475134.000000           102624.000000  320557.000000
# mean        0.283948      26.293766             3104.761359      66.074916
# std         0.450913      28.208800              729.139651      46.345526
# min         0.000000       0.000000                7.650000       0.000000
# 25%         0.000000       0.000000             3276.750000       0.000000
# 50%         0.000000       9.699216             3276.750000     100.000000
# 75%         1.000000      59.933190             3276.750000     100.000000
# max         1.000000     158.447200             3278.750000     100.000000
#
#        TurboBoostPressure
# count       474652.000000
# mean             6.286150
# std              8.557188
# min              0.000000
# 25%              0.580000
# 50%              2.030000
# 75%              8.700000
# max             63.220000
#
# [8 rows x 23 columns]

# %%
X

le_y = LabelEncoder()

y_fitted = le_y.fit(y)
y_encoded = le_y.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size = 0.2, random_state = 321, shuffle=True, stratify = y_encoded)

# %% [markdown]
# # Apply SMOTE
# smote = SMOTE(random_state=3434)
# X_resampled, y_resampled = smote.fit_resample(X_train, y_train)    # might need another set of pipeline; alternatively, we can go with the following approach:

# %% [markdown]
#
#
# ct0 = ColumnTransformer(
#         [('target_encoder', TargetEncoder(handle_unknown='ignore'), ['spn_fmi',
#                                                                         'ecuSource',
#                                                                         'LampStatus',
#                                                                         'activeTransitionCount'
#                                                                     ]
#           )],
#         remainder='passthrough')
#
#
#
#
# xgbc_pipe = Pipeline(
#     steps=[
#         ('preprocessor0', ct0),
#         ('StandardScaler', StandardScaler()),
#         ('imputer', IterativeImputer(estimator = GradientBoostingRegressor(verbose=2, random_state=434), max_iter=100, random_state=343)),
#         ('smote', SMOTE(random_state=344)),
#         ('xgbc', XGBClassifier(# tree_method = "hist",
#                                enable_categorical=True,
#                                 eval_metric='mlogloss',
#                                 objective = 'multi:softmax',
#                                 num_class = 5,
#                                 device = "cuda",
#                                 random_state = 535
#                             )
#         )
#     ]
# ).fit(X_train, y_train)
#
# y_pred = xgbc_pipe.predict(X_test)

# %%
 


ct = ColumnTransformer(
    transformers=[
        ('scaler', StandardScaler(), [  'AcceleratorPedal',
                                        'BarometricPressure',
                                        'CruiseControlSetSpeed',
                                        'DistanceLtd',
                                        'EngineCoolantTemperature',
                                        'EngineLoad',
                                        'EngineOilPressure',
                                        'EngineOilTemperature',
                                        'EngineRpm',
                                        'EngineTimeLtd',
                                        'FuelLevel',
                                        'FuelLtd',
                                        'FuelRate',
                                        'FuelTemperature',
                                        'IntakeManifoldTemperature',
                                        'Speed',
                                        'Throttle',
                                        'active',
                                        'TurboBoostPressure',
                                        'CruiseControlActive',
                                        'IgnStatus',
                                        'ParkingBrake',
                                        'SwitchedBatteryVoltage'
                                        ]),
        ('target_encoder', TargetEncoder(handle_unknown='ignore'), [    'spn_fmi',
                                                                        'ecuSource',
                                                                        'LampStatus',
                                                                        'activeTransitionCount'
                                                                    ]) #,
      # ('ordinal_encoder', OrdinalEncoder(handle_unknown='ignore'), [   'ecuSource',
       #                                                                         'LampStatus'
        #                                                                ])
    ],
    remainder='passthrough' 
)

xgbc_pipe = Pipeline(
    steps=[
        ('preprocessor', ct),
        ('imputer1', XGBImputer(categorical_features_index=[0, 2, -7, -1], replace_categorical_values_back=True, verbose=2)), 
        ('imputer2', IterativeImputer(estimator = GradientBoostingRegressor(verbose=2, random_state=434), max_iter=10, random_state=343)),
        ('smote', SMOTE(random_state=344)),
        ('xgbc', XGBClassifier( enable_categorical=True, 
                               # booster='gbtree', 
                                eval_metric='mlogloss',
                                objective = 'multi:softprob'
                            )
        )
    ]
).fit(X_train, y_train) 

y_pred = xgbc_pipe.predict(X_test)
# Out:
# XGBImputer - Epoch: 1 | Categorical gamma: inf/266751.5 | Numerical gamma: inf/0.4787590717
# XGBImputer - Epoch: 2 | Categorical gamma: 266751.5/894. | Numerical gamma: 0.4787590717/0.2750536637
# XGBImputer - Epoch: 3 | Categorical gamma: 894./0. | Numerical gamma: 0.2750536637/0.000776488
# XGBImputer - Epoch: 4 | Categorical gamma: 0./0. | Numerical gamma: 0.000776488/0.
# XGBImputer - Epoch: 5 | Categorical gamma: 0./0. | Numerical gamma: 0./0.
#       Iter       Train Loss   Remaining Time
#          1           1.1771            3.91m
#          2           0.9991            3.72m
#          3           0.8540            3.42m
#          4           0.7286            3.48m
#          5           0.6284            3.35m
#          6           0.5496            3.28m
#          7           0.4797            3.33m
#          8           0.4266            3.24m
#          9           0.3787            3.16m
#         10           0.3393            3.15m
#         11           0.3068            3.10m
#         12           0.2813            3.08m
#         13           0.2589            3.04m
#         14           0.2395            2.99m
#         15           0.2245            3.02m
#         16           0.2111            2.96m
#         17           0.2007            2.91m
#         18           0.1914            2.90m
#         19           0.1834            2.84m
#         20           0.1762            2.87m
#         21           0.1703            2.82m
#         22           0.1645            2.79m
#         23           0.1570            2.81m
#         24           0.1537            2.77m
#         25           0.1494            2.77m
#         26           0.1469            2.72m
#         27           0.1446            2.68m
#         28           0.1406            2.65m
#         29           0.1380            2.61m
#         30           0.1350            2.57m
#         31           0.1316            2.53m
#         32           0.1288            2.48m
#         33           0.1271            2.45m
#         34           0.1246            2.41m
#         35           0.1207            2.38m
#         36           0.1190            2.34m
#         37           0.1178            2.30m
#         38           0.1161            2.25m
#         39           0.1151            2.20m
#         40           0.1132            2.16m
#         41           0.1103            2.11m
#         42           0.1092            2.07m
#         43           0.1084            2.02m
#         44           0.1062            1.98m
#         45           0.1052            1.95m
#         46           0.1046            1.90m
#         47           0.1027            1.87m
#         48           0.1011            1.83m
#         49           0.1004            1.78m
#         50           0.0999            1.74m
#         51           0.0990            1.71m
#         52           0.0983            1.66m
#         53           0.0978            1.62m
#         54           0.0959            1.58m
#         55           0.0931            1.55m
#         56           0.0923            1.51m
#         57           0.0900            1.47m
#         58           0.0887            1.44m
#         59           0.0884            1.40m
#         60           0.0879            1.36m
#         61           0.0869            1.32m
#         62           0.0864            1.28m
#         63           0.0860            1.25m
#         64           0.0856            1.21m
#         65           0.0851            1.18m
#         66           0.0848            1.14m
#         67           0.0845            1.10m
#         68           0.0832            1.07m
#         69           0.0819            1.03m
#         70           0.0816           59.94s
#         71           0.0814           57.82s
#         72           0.0808           55.68s
#         73           0.0803           53.57s
#         74           0.0792           51.47s
#         75           0.0788           49.36s
#         76           0.0785           47.43s
#         77           0.0782           45.37s
#         78           0.0774           43.30s
#         79           0.0772           41.37s
#         80           0.0770           39.33s
#         81           0.0766           37.27s
#         82           0.0759           35.34s
#         83           0.0754           33.31s
#         84           0.0747           31.29s
#         85           0.0746           29.35s
#         86           0.0739           27.34s
#         87           0.0737           25.41s
#         88           0.0735           23.43s
#         89           0.0730           21.44s
#         90           0.0721           19.50s
#         91           0.0718           17.52s
#         92           0.0717           15.55s
#         93           0.0715           13.62s
#         94           0.0707           11.66s
#         95           0.0705            9.72s
#         96           0.0704            7.77s
#         97           0.0702            5.82s
#         98           0.0700            3.89s
#         99           0.0699            1.94s
#        100           0.0696            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.4738            2.89m
#          2           0.4329            2.76m
#          3           0.3997            2.98m
#          4           0.3729            2.90m
#          5           0.3497            2.83m
#          6           0.3308            2.97m
#          7           0.3153            2.90m
#          8           0.3021            2.92m
#          9           0.2912            2.84m
#         10           0.2821            2.83m
#         11           0.2742            2.79m
#         12           0.2648            2.74m
#         13           0.2587            2.73m
#         14           0.2521            2.67m
#         15           0.2393            2.62m
#         16           0.2345            2.63m
#         17           0.2304            2.59m
#         18           0.2234            2.60m
#         19           0.2183            2.56m
#         20           0.2108            2.54m
#         21           0.1992            2.50m
#         22           0.1935            2.49m
#         23           0.1820            2.44m
#         24           0.1779            2.39m
#         25           0.1679            2.37m
#         26           0.1644            2.33m
#         27           0.1614            2.29m
#         28           0.1539            2.27m
#         29           0.1516            2.23m
#         30           0.1456            2.19m
#         31           0.1437            2.17m
#         32           0.1373            2.14m
#         33           0.1364            2.11m
#         34           0.1312            2.08m
#         35           0.1277            2.06m
#         36           0.1267            2.03m
#         37           0.1236            1.99m
#         38           0.1227            1.97m
#         39           0.1192            1.93m
#         40           0.1185            1.91m
#         41           0.1180            1.88m
#         42           0.1156            1.85m
#         43           0.1150            1.83m
#         44           0.1143            1.81m
#         45           0.1134            1.77m
#         46           0.1128            1.75m
#         47           0.1117            1.72m
#         48           0.1114            1.69m
#         49           0.1084            1.66m
#         50           0.1078            1.63m
#         51           0.1073            1.60m
#         52           0.1068            1.56m
#         53           0.1065            1.53m
#         54           0.1057            1.50m
#         55           0.1053            1.47m
#         56           0.1043            1.44m
#         57           0.1039            1.41m
#         58           0.1035            1.38m
#         59           0.1005            1.34m
#         60           0.1001            1.31m
#         61           0.0997            1.28m
#         62           0.0993            1.25m
#         63           0.0990            1.22m
#         64           0.0988            1.18m
#         65           0.0971            1.15m
#         66           0.0968            1.12m
#         67           0.0961            1.08m
#         68           0.0956            1.05m
#         69           0.0955            1.02m
#         70           0.0932           59.35s
#         71           0.0929           57.32s
#         72           0.0926           55.31s
#         73           0.0921           53.45s
#         74           0.0919           51.41s
#         75           0.0906           49.56s
#         76           0.0904           47.55s
#         77           0.0902           45.53s
#         78           0.0897           43.63s
#         79           0.0895           41.59s
#         80           0.0889           39.62s
#         81           0.0887           37.56s
#         82           0.0879           35.52s
#         83           0.0876           33.47s
#         84           0.0875           31.52s
#         85           0.0870           29.50s
#         86           0.0866           27.49s
#         87           0.0864           25.48s
#         88           0.0860           23.48s
#         89           0.0850           21.49s
#         90           0.0848           19.55s
#         91           0.0846           17.56s
#         92           0.0845           15.59s
#         93           0.0834           13.61s
#         94           0.0831           11.65s
#         95           0.0817            9.72s
#         96           0.0815            7.76s
#         97           0.0814            5.82s
#         98           0.0812            3.88s
#         99           0.0811            1.94s
#        100           0.0808            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.4826            2.98m
#          2           0.4516            3.08m
#          3           0.4261            3.29m
#          4           0.3763            3.10m
#          5           0.3359            3.00m
#          6           0.3035            3.04m
#          7           0.2909            2.96m
#          8           0.2657            2.88m
#          9           0.2482            2.89m
#         10           0.2362            2.82m
#         11           0.2233            2.83m
#         12           0.2086            2.77m
#         13           0.2014            2.72m
#         14           0.1924            2.71m
#         15           0.1863            2.66m
#         16           0.1817            2.66m
#         17           0.1706            2.61m
#         18           0.1600            2.55m
#         19           0.1531            2.53m
#         20           0.1455            2.48m
#         21           0.1402            2.44m
#         22           0.1357            2.43m
#         23           0.1318            2.39m
#         24           0.1273            2.34m
#         25           0.1263            2.32m
#         26           0.1235            2.28m
#         27           0.1214            2.24m
#         28           0.1190            2.23m
#         29           0.1182            2.20m
#         30           0.1154            2.15m
#         31           0.1145            2.13m
#         32           0.1138            2.10m
#         33           0.1117            2.07m
#         34           0.1112            2.04m
#         35           0.1089            2.00m
#         36           0.1085            1.98m
#         37           0.1079            1.94m
#         38           0.1075            1.92m
#         39           0.1065            1.89m
#         40           0.1061            1.86m
#         41           0.1057            1.83m
#         42           0.1046            1.80m
#         43           0.1041            1.77m
#         44           0.1040            1.74m
#         45           0.1036            1.70m
#         46           0.1030            1.68m
#         47           0.1027            1.65m
#         48           0.1019            1.62m
#         49           0.1011            1.59m
#         50           0.1009            1.55m
#         51           0.1001            1.52m
#         52           0.0993            1.49m
#         53           0.0992            1.46m
#         54           0.0983            1.43m
#         55           0.0981            1.40m
#         56           0.0979            1.37m
#         57           0.0976            1.34m
#         58           0.0968            1.31m
#         59           0.0964            1.28m
#         60           0.0962            1.25m
#         61           0.0960            1.22m
#         62           0.0958            1.19m
#         63           0.0954            1.15m
#         64           0.0952            1.13m
#         65           0.0944            1.09m
#         66           0.0941            1.06m
#         67           0.0938            1.03m
#         68           0.0936           59.95s
#         69           0.0933           58.19s
#         70           0.0929           56.30s
#         71           0.0925           54.36s
#         72           0.0922           52.59s
#         73           0.0917           50.61s
#         74           0.0917           48.64s
#         75           0.0912           46.83s
#         76           0.0908           44.95s
#         77           0.0902           43.18s
#         78           0.0900           41.26s
#         79           0.0898           39.33s
#         80           0.0895           37.54s
#         81           0.0894           35.66s
#         82           0.0891           33.85s
#         83           0.0887           31.92s
#         84           0.0883           29.99s
#         85           0.0882           28.16s
#         86           0.0877           26.24s
#         87           0.0876           24.34s
#         88           0.0875           22.50s
#         89           0.0874           20.61s
#         90           0.0873           18.77s
#         91           0.0870           16.87s
#         92           0.0869           15.01s
#         93           0.0867           13.13s
#         94           0.0867           11.24s
#         95           0.0866            9.38s
#         96           0.0863            7.50s
#         97           0.0855            5.63s
#         98           0.0855            3.75s
#         99           0.0854            1.89s
#        100           0.0853            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.5470            3.86m
#          2           0.4612            3.77m
#          3           0.3912            3.63m
#          4           0.3340            3.39m
#          5           0.2871            3.43m
#          6           0.2488            3.26m
#          7           0.2168            3.15m
#          8           0.1905            3.12m
#          9           0.1675            3.06m
#         10           0.1499            3.10m
#         11           0.1342            3.02m
#         12           0.1212            2.94m
#         13           0.1100            2.93m
#         14           0.1006            2.86m
#         15           0.0929            2.81m
#         16           0.0861            2.81m
#         17           0.0811            2.76m
#         18           0.0762            2.74m
#         19           0.0721            2.70m
#         20           0.0684            2.64m
#         21           0.0657            2.62m
#         22           0.0631            2.57m
#         23           0.0603            2.53m
#         24           0.0583            2.50m
#         25           0.0567            2.46m
#         26           0.0549            2.42m
#         27           0.0526            2.39m
#         28           0.0514            2.34m
#         29           0.0499            2.31m
#         30           0.0482            2.29m
#         31           0.0471            2.25m
#         32           0.0463            2.21m
#         33           0.0453            2.18m
#         34           0.0445            2.15m
#         35           0.0439            2.14m
#         36           0.0433            2.10m
#         37           0.0429            2.06m
#         38           0.0421            2.05m
#         39           0.0418            2.01m
#         40           0.0415            1.98m
#         41           0.0412            1.94m
#         42           0.0402            1.90m
#         43           0.0399            1.88m
#         44           0.0397            1.84m
#         45           0.0394            1.82m
#         46           0.0392            1.78m
#         47           0.0389            1.74m
#         48           0.0388            1.71m
#         49           0.0385            1.67m
#         50           0.0383            1.64m
#         51           0.0382            1.62m
#         52           0.0379            1.58m
#         53           0.0374            1.55m
#         54           0.0373            1.52m
#         55           0.0372            1.48m
#         56           0.0371            1.45m
#         57           0.0370            1.43m
#         58           0.0365            1.42m
#         59           0.0361            1.39m
#         60           0.0359            1.36m
#         61           0.0358            1.34m
#         62           0.0355            1.32m
#         63           0.0354            1.30m
#         64           0.0353            1.26m
#         65           0.0352            1.24m
#         66           0.0349            1.21m
#         67           0.0348            1.18m
#         68           0.0347            1.15m
#         69           0.0346            1.13m
#         70           0.0339            1.09m
#         71           0.0338            1.05m
#         72           0.0337            1.02m
#         73           0.0336           59.15s
#         74           0.0335           56.97s
#         75           0.0334           55.08s
#         76           0.0333           52.89s
#         77           0.0329           50.67s
#         78           0.0327           48.75s
#         79           0.0327           46.53s
#         80           0.0326           44.57s
#         81           0.0322           42.38s
#         82           0.0321           40.15s
#         83           0.0321           38.11s
#         84           0.0319           35.86s
#         85           0.0319           33.72s
#         86           0.0318           31.44s
#         87           0.0315           29.30s
#         88           0.0314           27.02s
#         89           0.0313           24.81s
#         90           0.0312           22.52s
#         91           0.0311           20.31s
#         92           0.0309           18.03s
#         93           0.0309           15.76s
#         94           0.0307           13.53s
#         95           0.0306           11.26s
#         96           0.0305            9.00s
#         97           0.0304            6.76s
#         98           0.0304            4.50s
#         99           0.0303            2.25s
#        100           0.0303            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.4490            3.51m
#          2           0.3718            3.78m
#          3           0.3090            3.65m
#          4           0.2579            3.60m
#          5           0.2165            3.67m
#          6           0.1825            3.57m
#          7           0.1548            3.52m
#          8           0.1323            3.54m
#          9           0.1140            3.48m
#         10           0.0989            3.48m
#         11           0.0865            3.46m
#         12           0.0764            3.42m
#         13           0.0682            3.37m
#         14           0.0614            3.33m
#         15           0.0558            3.27m
#         16           0.0510            3.26m
#         17           0.0471            3.21m
#         18           0.0439            3.18m
#         19           0.0413            3.12m
#         20           0.0390            3.08m
#         21           0.0372            3.01m
#         22           0.0356            2.97m
#         23           0.0343            2.91m
#         24           0.0331            2.86m
#         25           0.0322            2.84m
#         26           0.0313            2.79m
#         27           0.0307            2.75m
#         28           0.0300            2.73m
#         29           0.0295            2.68m
#         30           0.0290            2.65m
#         31           0.0285            2.61m
#         32           0.0281            2.59m
#         33           0.0277            2.54m
#         34           0.0274            2.51m
#         35           0.0271            2.47m
#         36           0.0267            2.43m
#         37           0.0263            2.40m
#         38           0.0261            2.36m
#         39           0.0258            2.33m
#         40           0.0255            2.29m
#         41           0.0253            2.26m
#         42           0.0251            2.22m
#         43           0.0248            2.20m
#         44           0.0247            2.16m
#         45           0.0245            2.14m
#         46           0.0244            2.09m
#         47           0.0242            2.07m
#         48           0.0240            2.04m
#         49           0.0239            2.00m
#         50           0.0237            1.97m
#         51           0.0236            1.92m
#         52           0.0235            1.88m
#         53           0.0233            1.85m
#         54           0.0233            1.81m
#         55           0.0231            1.77m
#         56           0.0229            1.74m
#         57           0.0228            1.70m
#         58           0.0228            1.68m
#         59           0.0226            1.63m
#         60           0.0225            1.60m
#         61           0.0225            1.57m
#         62           0.0223            1.54m
#         63           0.0223            1.50m
#         64           0.0222            1.46m
#         65           0.0221            1.42m
#         66           0.0221            1.38m
#         67           0.0220            1.35m
#         68           0.0219            1.31m
#         69           0.0219            1.26m
#         70           0.0218            1.22m
#         71           0.0217            1.18m
#         72           0.0216            1.15m
#         73           0.0215            1.10m
#         74           0.0214            1.07m
#         75           0.0214            1.03m
#         76           0.0214           58.97s
#         77           0.0213           56.81s
#         78           0.0213           54.25s
#         79           0.0212           51.90s
#         80           0.0211           49.40s
#         81           0.0211           46.80s
#         82           0.0211           44.29s
#         83           0.0210           41.70s
#         84           0.0210           39.13s
#         85           0.0210           36.66s
#         86           0.0209           34.13s
#         87           0.0209           31.73s
#         88           0.0208           29.25s
#         89           0.0208           26.81s
#         90           0.0207           24.41s
#         91           0.0207           22.13s
#         92           0.0207           19.82s
#         93           0.0206           17.33s
#         94           0.0206           14.88s
#         95           0.0206           12.39s
#         96           0.0205            9.93s
#         97           0.0205            7.45s
#         98           0.0205            4.97s
#         99           0.0205            2.48s
#        100           0.0204            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.6486            3.50m
#          2           0.5338            3.44m
#          3           0.4408            4.52m
#          4           0.3651            5.34m
#          5           0.3036            5.51m
#          6           0.2539            5.10m
#          7           0.2133            5.03m
#          8           0.1803            4.77m
#          9           0.1533            4.55m
#         10           0.1310            4.50m
#         11           0.1132            4.33m
#         12           0.0981            4.27m
#         13           0.0857            4.14m
#         14           0.0755            4.10m
#         15           0.0671            4.09m
#         16           0.0602            4.05m
#         17           0.0545            3.94m
#         18           0.0498            3.91m
#         19           0.0460            3.81m
#         20           0.0427            3.78m
#         21           0.0400            3.70m
#         22           0.0378            3.61m
#         23           0.0358            3.60m
#         24           0.0343            3.52m
#         25           0.0329            3.49m
#         26           0.0318            3.41m
#         27           0.0307            3.35m
#         28           0.0299            3.29m
#         29           0.0291            3.22m
#         30           0.0285            3.18m
#         31           0.0279            3.11m
#         32           0.0273            3.06m
#         33           0.0269            2.99m
#         34           0.0264            2.99m
#         35           0.0260            2.92m
#         36           0.0256            2.91m
#         37           0.0252            2.85m
#         38           0.0249            2.78m
#         39           0.0245            2.75m
#         40           0.0243            2.69m
#         41           0.0241            2.64m
#         42           0.0239            2.59m
#         43           0.0238            2.54m
#         44           0.0235            2.49m
#         45           0.0232            2.43m
#         46           0.0230            2.37m
#         47           0.0229            2.32m
#         48           0.0227            2.26m
#         49           0.0226            2.20m
#         50           0.0225            2.15m
#         51           0.0224            2.10m
#         52           0.0221            2.07m
#         53           0.0219            2.02m
#         54           0.0218            1.97m
#         55           0.0217            1.93m
#         56           0.0217            1.88m
#         57           0.0215            1.84m
#         58           0.0215            1.80m
#         59           0.0214            1.75m
#         60           0.0212            1.70m
#         61           0.0211            1.66m
#         62           0.0210            1.61m
#         63           0.0209            1.57m
#         64           0.0209            1.52m
#         65           0.0208            1.48m
#         66           0.0208            1.44m
#         67           0.0208            1.39m
#         68           0.0207            1.35m
#         69           0.0205            1.31m
#         70           0.0205            1.26m
#         71           0.0204            1.22m
#         72           0.0204            1.19m
#         73           0.0202            1.14m
#         74           0.0201            1.10m
#         75           0.0201            1.06m
#         76           0.0200            1.02m
#         77           0.0200           58.31s
#         78           0.0200           56.05s
#         79           0.0200           53.39s
#         80           0.0199           50.93s
#         81           0.0199           48.37s
#         82           0.0198           45.97s
#         83           0.0197           43.37s
#         84           0.0197           40.76s
#         85           0.0196           38.36s
#         86           0.0196           35.77s
#         87           0.0196           33.25s
#         88           0.0193           30.69s
#         89           0.0193           28.21s
#         90           0.0193           25.59s
#         91           0.0193           23.01s
#         92           0.0192           20.50s
#         93           0.0191           17.90s
#         94           0.0191           15.41s
#         95           0.0191           12.82s
#         96           0.0191           10.26s
#         97           0.0191            7.68s
#         98           0.0190            5.11s
#         99           0.0190            2.56s
#        100           0.0189            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.4789            3.41m
#          2           0.4127            3.98m
#          3           0.3579            3.76m
#          4           0.3137            3.66m
#          5           0.2765            3.66m
#          6           0.2464            3.48m
#          7           0.2216            3.46m
#          8           0.1990            3.34m
#          9           0.1788            3.32m
#         10           0.1623            3.25m
#         11           0.1473            3.19m
#         12           0.1353            3.25m
#         13           0.1246            3.20m
#         14           0.1155            3.20m
#         15           0.1085            3.15m
#         16           0.1021            3.12m
#         17           0.0963            3.11m
#         18           0.0916            3.07m
#         19           0.0872            3.08m
#         20           0.0835            3.04m
#         21           0.0802            2.99m
#         22           0.0768            2.99m
#         23           0.0739            2.96m
#         24           0.0716            2.95m
#         25           0.0693            2.90m
#         26           0.0675            2.88m
#         27           0.0655            2.84m
#         28           0.0638            2.79m
#         29           0.0622            2.77m
#         30           0.0607            2.72m
#         31           0.0594            2.68m
#         32           0.0583            2.65m
#         33           0.0571            2.60m
#         34           0.0558            2.57m
#         35           0.0550            2.53m
#         36           0.0542            2.48m
#         37           0.0532            2.45m
#         38           0.0524            2.41m
#         39           0.0515            2.36m
#         40           0.0507            2.34m
#         41           0.0500            2.29m
#         42           0.0493            2.26m
#         43           0.0487            2.24m
#         44           0.0481            2.19m
#         45           0.0476            2.16m
#         46           0.0472            2.12m
#         47           0.0466            2.08m
#         48           0.0461            2.05m
#         49           0.0457            2.00m
#         50           0.0453            1.96m
#         51           0.0449            1.93m
#         52           0.0442            1.89m
#         53           0.0439            1.86m
#         54           0.0435            1.82m
#         55           0.0431            1.77m
#         56           0.0429            1.74m
#         57           0.0427            1.70m
#         58           0.0423            1.65m
#         59           0.0421            1.62m
#         60           0.0418            1.58m
#         61           0.0415            1.54m
#         62           0.0412            1.50m
#         63           0.0411            1.46m
#         64           0.0408            1.42m
#         65           0.0407            1.37m
#         66           0.0404            1.33m
#         67           0.0401            1.29m
#         68           0.0397            1.25m
#         69           0.0395            1.21m
#         70           0.0394            1.17m
#         71           0.0391            1.13m
#         72           0.0390            1.09m
#         73           0.0386            1.05m
#         74           0.0384            1.02m
#         75           0.0383           58.63s
#         76           0.0382           56.21s
#         77           0.0380           54.00s
#         78           0.0379           51.58s
#         79           0.0377           49.33s
#         80           0.0376           46.91s
#         81           0.0373           44.62s
#         82           0.0372           42.22s
#         83           0.0371           39.84s
#         84           0.0369           37.53s
#         85           0.0367           35.14s
#         86           0.0366           32.83s
#         87           0.0364           30.46s
#         88           0.0363           28.15s
#         89           0.0362           25.78s
#         90           0.0361           23.41s
#         91           0.0359           21.12s
#         92           0.0358           18.76s
#         93           0.0357           16.44s
#         94           0.0356           14.08s
#         95           0.0354           11.76s
#         96           0.0353            9.40s
#         97           0.0352            7.04s
#         98           0.0351            4.70s
#         99           0.0350            2.35s
#        100           0.0349            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.4728            3.41m
#          2           0.4269            3.95m
#          3           0.3893            3.75m
#          4           0.3614            3.82m
#          5           0.3383            3.70m
#          6           0.3155            3.59m
#          7           0.3003            3.63m
#          8           0.2875            3.56m
#          9           0.2772            3.57m
#         10           0.2686            3.50m
#         11           0.2604            3.50m
#         12           0.2372            3.42m
#         13           0.2185            3.37m
#         14           0.2142            3.36m
#         15           0.2109            3.30m
#         16           0.1967            3.29m
#         17           0.1944            3.22m
#         18           0.1901            3.21m
#         19           0.1884            3.16m
#         20           0.1864            3.11m
#         21           0.1846            3.09m
#         22           0.1831            3.04m
#         23           0.1814            2.98m
#         24           0.1805            2.93m
#         25           0.1797            2.87m
#         26           0.1751            2.83m
#         27           0.1744            2.77m
#         28           0.1737            2.71m
#         29           0.1731            2.68m
#         30           0.1727            2.63m
#         31           0.1675            2.59m
#         32           0.1611            2.54m
#         33           0.1596            2.51m
#         34           0.1593            2.47m
#         35           0.1589            2.43m
#         36           0.1586            2.39m
#         37           0.1583            2.35m
#         38           0.1580            2.31m
#         39           0.1577            2.27m
#         40           0.1574            2.24m
#         41           0.1557            2.19m
#         42           0.1525            2.16m
#         43           0.1440            2.12m
#         44           0.1439            2.08m
#         45           0.1371            2.04m
#         46           0.1370            2.00m
#         47           0.1368            1.97m
#         48           0.1312            1.93m
#         49           0.1309            1.89m
#         50           0.1308            1.85m
#         51           0.1307            1.82m
#         52           0.1306            1.78m
#         53           0.1305            1.74m
#         54           0.1220            1.70m
#         55           0.1213            1.66m
#         56           0.1212            1.63m
#         57           0.1201            1.59m
#         58           0.1178            1.55m
#         59           0.1177            1.51m
#         60           0.1176            1.47m
#         61           0.1111            1.43m
#         62           0.1106            1.39m
#         63           0.1096            1.35m
#         64           0.1095            1.32m
#         65           0.1095            1.28m
#         66           0.1092            1.25m
#         67           0.1058            1.21m
#         68           0.1057            1.17m
#         69           0.1055            1.14m
#         70           0.1051            1.10m
#         71           0.1006            1.06m
#         72           0.1006            1.02m
#         73           0.1003           59.36s
#         74           0.1002           57.10s
#         75           0.0991           54.98s
#         76           0.0971           52.72s
#         77           0.0960           50.46s
#         78           0.0950           48.32s
#         79           0.0930           46.08s
#         80           0.0925           43.92s
#         81           0.0925           41.69s
#         82           0.0925           39.55s
#         83           0.0917           37.31s
#         84           0.0917           35.08s
#         85           0.0910           32.85s
#         86           0.0903           30.64s
#         87           0.0899           28.43s
#         88           0.0898           26.23s
#         89           0.0894           24.08s
#         90           0.0894           21.85s
#         91           0.0888           19.63s
#         92           0.0880           17.42s
#         93           0.0877           15.22s
#         94           0.0876           13.05s
#         95           0.0863           10.86s
#         96           0.0860            8.68s
#         97           0.0860            6.50s
#         98           0.0858            4.33s
#         99           0.0857            2.16s
#        100           0.0856            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.5530            3.26m
#          2           0.4618            3.27m
#          3           0.3878            3.23m
#          4           0.3277            3.20m
#          5           0.2784            3.15m
#          6           0.2382            3.12m
#          7           0.2052            3.10m
#          8           0.1782            3.07m
#          9           0.1560            3.04m
#         10           0.1378            3.00m
#         11           0.1229            2.97m
#         12           0.1105            2.94m
#         13           0.1002            2.90m
#         14           0.0911            2.87m
#         15           0.0836            2.83m
#         16           0.0775            2.80m
#         17           0.0721            2.77m
#         18           0.0677            2.74m
#         19           0.0638            2.71m
#         20           0.0609            2.67m
#         21           0.0579            2.62m
#         22           0.0555            2.58m
#         23           0.0535            2.53m
#         24           0.0515            2.49m
#         25           0.0499            2.48m
#         26           0.0488            2.44m
#         27           0.0475            2.41m
#         28           0.0465            2.37m
#         29           0.0453            2.34m
#         30           0.0444            2.31m
#         31           0.0435            2.28m
#         32           0.0428            2.25m
#         33           0.0422            2.22m
#         34           0.0415            2.18m
#         35           0.0407            2.15m
#         36           0.0401            2.12m
#         37           0.0396            2.08m
#         38           0.0392            2.05m
#         39           0.0384            2.02m
#         40           0.0380            1.99m
#         41           0.0376            1.96m
#         42           0.0374            1.92m
#         43           0.0369            1.89m
#         44           0.0366            1.86m
#         45           0.0361            1.82m
#         46           0.0359            1.79m
#         47           0.0355            1.76m
#         48           0.0353            1.72m
#         49           0.0351            1.69m
#         50           0.0348            1.66m
#         51           0.0346            1.63m
#         52           0.0344            1.59m
#         53           0.0340            1.55m
#         54           0.0338            1.52m
#         55           0.0337            1.48m
#         56           0.0335            1.45m
#         57           0.0333            1.42m
#         58           0.0331            1.38m
#         59           0.0330            1.35m
#         60           0.0327            1.32m
#         61           0.0325            1.28m
#         62           0.0324            1.25m
#         63           0.0323            1.22m
#         64           0.0322            1.19m
#         65           0.0321            1.16m
#         66           0.0319            1.12m
#         67           0.0317            1.10m
#         68           0.0316            1.06m
#         69           0.0315            1.03m
#         70           0.0312           59.82s
#         71           0.0311           57.88s
#         72           0.0310           55.89s
#         73           0.0309           53.90s
#         74           0.0307           51.91s
#         75           0.0306           49.91s
#         76           0.0304           47.92s
#         77           0.0302           45.92s
#         78           0.0301           43.93s
#         79           0.0300           41.93s
#         80           0.0299           39.93s
#         81           0.0297           37.93s
#         82           0.0294           35.96s
#         83           0.0293           33.93s
#         84           0.0292           31.90s
#         85           0.0292           29.89s
#         86           0.0290           27.86s
#         87           0.0289           25.85s
#         88           0.0288           23.82s
#         89           0.0287           21.78s
#         90           0.0286           19.76s
#         91           0.0286           17.80s
#         92           0.0285           15.80s
#         93           0.0284           13.80s
#         94           0.0283           11.80s
#         95           0.0282            9.81s
#         96           0.0281            7.83s
#         97           0.0280            5.86s
#         98           0.0279            3.90s
#         99           0.0278            1.95s
#        100           0.0276            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.5202            2.53m
#          2           0.4595            2.49m
#          3           0.4105            2.46m
#          4           0.3702            2.43m
#          5           0.3374            2.40m
#          6           0.3105            2.41m
#          7           0.2887            2.41m
#          8           0.2704            2.40m
#          9           0.2554            2.38m
#         10           0.2434            2.36m
#         11           0.2332            2.33m
#         12           0.2246            2.31m
#         13           0.2174            2.28m
#         14           0.2117            2.24m
#         15           0.2069            2.26m
#         16           0.2030            2.23m
#         17           0.1997            2.19m
#         18           0.1940            2.16m
#         19           0.1888            2.15m
#         20           0.1819            2.13m
#         21           0.1767            2.11m
#         22           0.1712            2.08m
#         23           0.1699            2.08m
#         24           0.1686            2.05m
#         25           0.1674            2.02m
#         26           0.1658            1.99m
#         27           0.1650            1.98m
#         28           0.1642            1.95m
#         29           0.1562            1.91m
#         30           0.1554            1.89m
#         31           0.1548            1.87m
#         32           0.1483            1.84m
#         33           0.1472            1.81m
#         34           0.1466            1.78m
#         35           0.1455            1.75m
#         36           0.1447            1.73m
#         37           0.1411            1.71m
#         38           0.1403            1.68m
#         39           0.1399            1.65m
#         40           0.1351            1.62m
#         41           0.1346            1.60m
#         42           0.1342            1.57m
#         43           0.1328            1.54m
#         44           0.1326            1.51m
#         45           0.1318            1.48m
#         46           0.1316            1.46m
#         47           0.1292            1.43m
#         48           0.1289            1.41m
#         49           0.1288            1.38m
#         50           0.1286            1.35m
#         51           0.1282            1.33m
#         52           0.1280            1.30m
#         53           0.1255            1.27m
#         54           0.1253            1.24m
#         55           0.1251            1.22m
#         56           0.1249            1.19m
#         57           0.1247            1.17m
#         58           0.1246            1.14m
#         59           0.1228            1.11m
#         60           0.1226            1.09m
#         61           0.1224            1.06m
#         62           0.1224            1.03m
#         63           0.1211            1.00m
#         64           0.1210           58.55s
#         65           0.1206           57.15s
#         66           0.1202           55.48s
#         67           0.1191           53.80s
#         68           0.1191           52.13s
#         69           0.1189           50.44s
#         70           0.1184           48.99s
#         71           0.1180           47.32s
#         72           0.1166           45.65s
#         73           0.1164           43.99s
#         74           0.1163           42.32s
#         75           0.1151           40.83s
#         76           0.1151           39.17s
#         77           0.1148           37.50s
#         78           0.1123           35.84s
#         79           0.1122           34.25s
#         80           0.1121           32.66s
#         81           0.1116           31.01s
#         82           0.1112           29.38s
#         83           0.1110           27.72s
#         84           0.1107           26.16s
#         85           0.1097           24.51s
#         86           0.1096           22.86s
#         87           0.1096           21.22s
#         88           0.1075           19.58s
#         89           0.1073           17.99s
#         90           0.1072           16.35s
#         91           0.1071           14.70s
#         92           0.1071           13.06s
#         93           0.1067           11.42s
#         94           0.1066            9.81s
#         95           0.1065            8.17s
#         96           0.1047            6.53s
#         97           0.1046            4.90s
#         98           0.1045            3.26s
#         99           0.1044            1.64s
#        100           0.1038            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.4249            2.62m
#          2           0.4211            2.62m
#          3           0.4177            2.85m
#          4           0.4149            2.76m
#          5           0.4126            2.69m
#          6           0.4106            2.63m
#          7           0.4090            2.70m
#          8           0.4076            2.63m
#          9           0.4065            2.58m
#         10           0.4056            2.53m
#         11           0.4042            2.55m
#         12           0.4034            2.51m
#         13           0.4029            2.46m
#         14           0.4013            2.43m
#         15           0.4009            2.39m
#         16           0.4003            2.40m
#         17           0.3998            2.37m
#         18           0.3994            2.33m
#         19           0.3985            2.29m
#         20           0.3980            2.29m
#         21           0.3968            2.25m
#         22           0.3963            2.22m
#         23           0.3959            2.18m
#         24           0.3956            2.15m
#         25           0.3954            2.14m
#         26           0.3950            2.10m
#         27           0.3941            2.06m
#         28           0.3939            2.03m
#         29           0.3934            2.00m
#         30           0.3926            1.99m
#         31           0.3921            1.96m
#         32           0.3918            1.93m
#         33           0.3916            1.89m
#         34           0.3915            1.87m
#         35           0.3909            1.85m
#         36           0.3908            1.82m
#         37           0.3904            1.79m
#         38           0.3900            1.75m
#         39           0.3899            1.74m
#         40           0.3898            1.71m
#         41           0.3893            1.68m
#         42           0.3889            1.65m
#         43           0.3887            1.62m
#         44           0.3882            1.60m
#         45           0.3881            1.57m
# ...
#         62           0.0023            1.41m
#         63           0.0023            1.37m
#         64           0.0023            1.34m
#         65           0.0023            1.30m
#         66           0.0023            1.26m
#         67           0.0023            1.23m
#         68           0.0023            1.19m
#         69           0.0022            1.15m
#         70           0.0022            1.11m
#         71           0.0022            1.08m
#         72           0.0022            1.04m
#         73           0.0022            1.00m
#         74           0.0022           58.00s
#         75           0.0022           55.71s
#         76           0.0022           53.43s
#         77           0.0022           51.28s
#         78           0.0022           49.05s
#         79           0.0022           46.78s
#         80           0.0022           44.50s
#         81           0.0022           42.37s
#         82           0.0021           40.12s
#         83           0.0021           37.86s
#         84           0.0021           35.72s
#         85           0.0021           33.46s
#         86           0.0021           31.21s
#         87           0.0021           28.95s
#         88           0.0021           26.77s
#         89           0.0021           24.50s
#         90           0.0021           22.23s
#         91           0.0021           20.05s
#         92           0.0021           17.80s
#         93           0.0020           15.55s
#         94           0.0020           13.35s
#         95           0.0020           11.12s
#         96           0.0020            8.89s
#         97           0.0020            6.66s
#         98           0.0020            4.45s
#         99           0.0020            2.23s
#        100           0.0020            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.1836            4.98m
#          2           0.1542            4.19m
#          3           0.1303            3.88m
#          4           0.1106            3.71m
#          5           0.0947            3.85m
#          6           0.0819            3.74m
#          7           0.0713            3.62m
#          8           0.0628            3.72m
#          9           0.0558            3.64m
#         10           0.0501            3.55m
#         11           0.0453            3.56m
#         12           0.0414            3.48m
#         13           0.0383            3.40m
#         14           0.0357            3.34m
#         15           0.0336            3.33m
#         16           0.0318            3.27m
#         17           0.0303            3.21m
#         18           0.0291            3.19m
#         19           0.0280            3.13m
#         20           0.0272            3.07m
#         21           0.0264            3.01m
#         22           0.0256            2.98m
#         23           0.0251            2.91m
#         24           0.0246            2.85m
#         25           0.0242            2.82m
#         26           0.0238            2.75m
#         27           0.0234            2.70m
#         28           0.0230            2.65m
#         29           0.0227            2.59m
#         30           0.0225            2.53m
#         31           0.0223            2.49m
#         32           0.0220            2.44m
#         33           0.0218            2.38m
#         34           0.0215            2.35m
#         35           0.0212            2.30m
#         36           0.0210            2.25m
#         37           0.0209            2.20m
#         38           0.0207            2.17m
#         39           0.0206            2.12m
#         40           0.0204            2.07m
#         41           0.0203            2.04m
#         42           0.0202            2.00m
#         43           0.0201            1.95m
#         44           0.0201            1.91m
#         45           0.0200            1.88m
#         46           0.0199            1.84m
#         47           0.0198            1.80m
#         48           0.0198            1.77m
#         49           0.0197            1.72m
#         50           0.0196            1.69m
#         51           0.0196            1.65m
#         52           0.0194            1.61m
#         53           0.0193            1.57m
#         54           0.0192            1.54m
#         55           0.0192            1.51m
#         56           0.0190            1.47m
#         57           0.0190            1.43m
#         58           0.0189            1.39m
#         59           0.0187            1.36m
#         60           0.0187            1.32m
#         61           0.0186            1.29m
#         62           0.0186            1.26m
#         63           0.0186            1.22m
#         64           0.0185            1.18m
#         65           0.0185            1.15m
#         66           0.0184            1.12m
#         67           0.0183            1.08m
#         68           0.0183            1.05m
#         69           0.0182            1.02m
#         70           0.0181           58.80s
#         71           0.0180           56.71s
#         72           0.0180           54.85s
#         73           0.0180           52.78s
#         74           0.0179           50.71s
#         75           0.0179           48.66s
#         76           0.0179           46.78s
#         77           0.0179           44.74s
#         78           0.0178           42.71s
#         79           0.0178           40.84s
#         80           0.0177           38.82s
#         81           0.0177           36.80s
#         82           0.0176           34.81s
#         83           0.0176           32.92s
#         84           0.0176           30.92s
#         85           0.0175           28.94s
#         86           0.0175           27.05s
#         87           0.0175           25.08s
#         88           0.0175           23.10s
#         89           0.0174           21.21s
#         90           0.0173           19.25s
#         91           0.0173           17.29s
#         92           0.0173           15.35s
#         93           0.0172           13.45s
#         94           0.0172           11.51s
#         95           0.0172            9.57s
#         96           0.0172            7.67s
#         97           0.0171            5.74s
#         98           0.0171            3.82s
#         99           0.0170            1.91s
#        100           0.0169            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.0645            2.62m
#          2           0.0558            2.61m
#          3           0.0484            2.90m
#          4           0.0425            2.79m
#          5           0.0376            2.71m
#          6           0.0333            2.64m
#          7           0.0298            2.73m
#          8           0.0269            2.68m
#          9           0.0245            2.63m
#         10           0.0225            2.66m
#         11           0.0209            2.61m
#         12           0.0195            2.56m
#         13           0.0183            2.51m
#         14           0.0170            2.54m
#         15           0.0159            2.49m
#         16           0.0152            2.45m
#         17           0.0145            2.46m
#         18           0.0140            2.42m
#         19           0.0135            2.38m
#         20           0.0131            2.33m
#         21           0.0128            2.33m
#         22           0.0125            2.30m
#         23           0.0122            2.26m
#         24           0.0120            2.25m
#         25           0.0118            2.22m
#         26           0.0116            2.18m
#         27           0.0115            2.15m
#         28           0.0113            2.13m
#         29           0.0112            2.10m
#         30           0.0111            2.07m
#         31           0.0110            2.05m
#         32           0.0109            2.02m
#         33           0.0108            1.98m
#         34           0.0106            1.96m
#         35           0.0104            1.93m
#         36           0.0104            1.90m
#         37           0.0103            1.86m
#         38           0.0102            1.84m
#         39           0.0101            1.81m
#         40           0.0100            1.78m
#         41           0.0100            1.75m
#         42           0.0099            1.72m
#         43           0.0099            1.69m
#         44           0.0099            1.66m
#         45           0.0098            1.63m
#         46           0.0097            1.60m
#         47           0.0097            1.57m
#         48           0.0097            1.55m
#         49           0.0096            1.52m
#         50           0.0096            1.49m
#         51           0.0095            1.46m
#         52           0.0095            1.43m
#         53           0.0095            1.40m
#         54           0.0094            1.37m
#         55           0.0094            1.34m
#         56           0.0094            1.31m
#         57           0.0094            1.28m
#         58           0.0093            1.25m
#         59           0.0092            1.22m
#         60           0.0092            1.19m
#         61           0.0092            1.16m
#         62           0.0091            1.13m
#         63           0.0091            1.10m
#         64           0.0091            1.07m
#         65           0.0090            1.05m
#         66           0.0090            1.01m
#         67           0.0090           58.97s
#         68           0.0089           57.26s
#         69           0.0089           55.53s
#         70           0.0089           53.66s
#         71           0.0089           51.82s
#         72           0.0089           50.21s
#         73           0.0088           48.36s
#         74           0.0088           46.52s
#         75           0.0088           44.87s
#         76           0.0088           43.06s
#         77           0.0088           41.22s
#         78           0.0087           39.38s
#         79           0.0087           37.71s
#         80           0.0087           35.86s
#         81           0.0087           34.03s
#         82           0.0086           32.32s
#         83           0.0086           30.49s
#         84           0.0086           28.66s
#         85           0.0086           26.89s
#         86           0.0086           25.14s
#         87           0.0085           23.32s
#         88           0.0085           21.50s
#         89           0.0085           19.77s
#         90           0.0085           17.96s
#         91           0.0085           16.15s
#         92           0.0084           14.39s
#         93           0.0084           12.57s
#         94           0.0084           10.77s
#         95           0.0083            8.99s
#         96           0.0083            7.19s
#         97           0.0083            5.39s
#         98           0.0083            3.59s
#         99           0.0083            1.80s
#        100           0.0083            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.9437            1.84m
#          2           0.8980            1.82m
#          3           0.8594            2.09m
#          4           0.8341            2.01m
#          5           0.7902            1.96m
#          6           0.7543            1.91m
#          7           0.7246            1.87m
#          8           0.7001            1.85m
#          9           0.6726            1.92m
#         10           0.6551            1.87m
#         11           0.6382            1.83m
#         12           0.6199            1.80m
#         13           0.6005            1.78m
#         14           0.5887            1.82m
#         15           0.5775            1.78m
#         16           0.5567            1.75m
#         17           0.5426            1.72m
#         18           0.5302            1.69m
#         19           0.5208            1.66m
#         20           0.5053            1.67m
#         21           0.4972            1.64m
#         22           0.4816            1.61m
#         23           0.4753            1.58m
#         24           0.4594            1.56m
#         25           0.4531            1.56m
#         26           0.4479            1.53m
#         27           0.4445            1.50m
#         28           0.4410            1.48m
#         29           0.4372            1.46m
#         30           0.4346            1.46m
#         31           0.4317            1.43m
#         32           0.4295            1.41m
#         33           0.4272            1.38m
#         34           0.4241            1.36m
#         35           0.4198            1.35m
#         36           0.4177            1.33m
#         37           0.4162            1.31m
#         38           0.4092            1.28m
#         39           0.3995            1.26m
#         40           0.3982            1.25m
#         41           0.3811            1.23m
#         42           0.3778            1.20m
#         43           0.3764            1.18m
#         44           0.3750            1.16m
#         45           0.3615            1.14m
#         46           0.3603            1.12m
#         47           0.3580            1.10m
#         48           0.3554            1.08m
#         49           0.3547            1.05m
#         50           0.3544            1.03m
#         51           0.3522            1.02m
#         52           0.3461           59.67s
#         53           0.3458           58.33s
#         54           0.3425           57.00s
#         55           0.3407           55.65s
#         56           0.3404           54.80s
#         57           0.3385           53.44s
#         58           0.3383           52.10s
#         59           0.3356           50.77s
#         60           0.3343           49.43s
#         61           0.3333           48.48s
#         62           0.3318           47.16s
#         63           0.3295           45.85s
#         64           0.3292           44.55s
#         65           0.3272           43.24s
#         66           0.3230           42.26s
#         67           0.3227           40.98s
#         68           0.3221           39.68s
#         69           0.3218           38.39s
#         70           0.3217           37.10s
#         71           0.3204           36.03s
#         72           0.3203           34.73s
#         73           0.3201           33.45s
#         74           0.3114           32.17s
#         75           0.3111           30.89s
#         76           0.3093           29.61s
#         77           0.3092           28.52s
#         78           0.3077           27.26s
#         79           0.3072           25.98s
#         80           0.3055           24.72s
#         81           0.3054           23.47s
#         82           0.2982           22.34s
#         83           0.2970           21.08s
#         84           0.2969           19.83s
#         85           0.2967           18.57s
#         86           0.2966           17.31s
#         87           0.2872           16.14s
#         88           0.2865           14.88s
#         89           0.2864           13.63s
#         90           0.2852           12.37s
#         91           0.2845           11.12s
#         92           0.2844            9.92s
#         93           0.2837            8.68s
#         94           0.2817            7.43s
#         95           0.2809            6.18s
#         96           0.2791            4.94s
#         97           0.2790            3.72s
#         98           0.2787            2.48s
#         99           0.2776            1.24s
#        100           0.2726            0.00s
# XGBImputer - Epoch: 1 | Categorical gamma: inf/67011.5 | Numerical gamma: inf/0.3088798592
# XGBImputer - Epoch: 2 | Categorical gamma: 67011.5/5568. | Numerical gamma: 0.3088798592/0.1938966992
# XGBImputer - Epoch: 3 | Categorical gamma: 5568./46.5 | Numerical gamma: 0.1938966992/0.0023576856
# XGBImputer - Epoch: 4 | Categorical gamma: 46.5/8. | Numerical gamma: 0.0023576856/0.0012433751
# XGBImputer - Epoch: 5 | Categorical gamma: 8./4. | Numerical gamma: 0.0012433751/0.0010106278
# XGBImputer - Epoch: 6 | Categorical gamma: 4./5.5 | Numerical gamma: 0.0010106278/0.0014809376

# %% [markdown]
# ~ For Ref / Backup purposes ~
#
#
# ct1 = ColumnTransformer(
#     transformers=[
#         ('scaler', StandardScaler(), [  'AcceleratorPedal',
#                                         'BarometricPressure',
#                                         'CruiseControlSetSpeed',
#                                         'DistanceLtd',
#                                         'EngineCoolantTemperature',
#                                         'EngineLoad',
#                                         'EngineOilPressure',
#                                         'EngineOilTemperature',
#                                         'EngineRpm',
#                                         'EngineTimeLtd',
#                                         'FuelLevel',
#                                         'FuelLtd',
#                                         'FuelRate',
#                                         'FuelTemperature',
#                                         'IntakeManifoldTemperature',
#                                         'Speed',
#                                         'Throttle',
#                                         'active',
#                                         'TurboBoostPressure',
#                                         'CruiseControlActive',
#                                         'IgnStatus',
#                                         'ParkingBrake',
#                                         'SwitchedBatteryVoltage'
#                                         ]),
#
#          ('num_imputer', IterativeImputer(estimator=ExtraTreesRegressor(), max_iter=10, random_state=343), [
#                                         'AcceleratorPedal',
#                                         'BarometricPressure',
#                                         'CruiseControlSetSpeed',
#                                         'DistanceLtd',
#                                         'EngineCoolantTemperature',
#                                         'EngineLoad',
#                                         'EngineOilPressure',
#                                         'EngineOilTemperature',
#                                         'EngineRpm',
#                                         'EngineTimeLtd',
#                                         'FuelLevel',
#                                         'FuelLtd',
#                                         'FuelRate',
#                                         'FuelTemperature',
#                                         'IntakeManifoldTemperature',
#                                         'Speed',
#                                         'Throttle',
#                                         'active',
#                                         'TurboBoostPressure',
#                                         'CruiseControlActive',
#                                         'IgnStatus',
#                                         'ParkingBrake',
#                                         'SwitchedBatteryVoltage',
#                                         'spn_fmi',
#                                         'ecuSource',
#                                         'LampStatus',
#                                         'activeTransitionCount'
#                                         ])
#     ],
#     remainder='passthrough'
# )

# %% [markdown]
# ~ For Ref / Backup purposes ~
#
#
# xgbc_pipe = Pipeline(
#     steps=[
#         ('preprocessor0', ct0),
#         ('StandardScaler', StandardScaler()),
#         ('imputer', IterativeImputer(estimator=ExtraTreesRegressor(), max_iter=10, random_state=343)),
#         ('smote', SMOTE(random_state=3434)),
#         ('xgbc', XGBClassifier( enable_categorical=True,
#                                # max_cat_to_onehot=1,
#                                 booster='gbtree',
#                                 eval_metric='mlogloss',
#                                 objective = 'multi:softprob'
#                             )
#         )
#     ]
# ).fit(X_train, y_train)
#
# y_pred = xgbc_pipe.predict(X_test)

# %% [markdown]
# ~ For Ref / Backup purposes ~
#
# Other imputer methodologies to try: XGBImputer(), GradientBoostingRegressor(), ExtraTreesRegressor()

# %%
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {root_mean_squared_error(y_test, y_pred)}')
print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MAPE: {mean_absolute_percentage_error(y_test, y_pred)}')
print(f'R2: {r2_score(y_test, y_pred)}')
# Out:
# MSE: 5.608790664855245
# RMSE: 2.368288551856645
# MAE: 1.4493538908723262
# MAPE: 931117669633649.4
# R2: -0.908176679758874

# %% [markdown]
# xgb = XGBClassifier(
#                     eval_metric='mlogloss'
#
#                     ).fit(X_train, y_train)

# %%
le_y
# Out:
# LabelEncoder()

# %%
y_fitted
# Out:
# LabelEncoder()

# %%
y_encoded
# Out:
# array([0, 0, 0, ..., 4, 4, 4], shape=(949528,))

# %%
y
# Out:
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
#            ...
# 949523    9999999
# 949524    9999999
# 949525    9999999
# 949526    9999999
# 949527    9999999
# Name: time_interval_to_SPN5246_class, Length: 949528, dtype: category
# Categories (5, int64): [0, 1, 2, 3, 9999999]

# %% [markdown]
# #RandomizedSearchCV
#
# param_dist = {
#     'max_depth': range(1, 10, 1),
#     'min_child_weight':range(1, 6, 1),
#     'learning_rate': stats.uniform(0.01, 0.1),
#     'subsample':[i/10.0 for i in range(1, 10)],
#     'colsample_bytree':[i/10.0 for i in range(1, 10)],
#     'n_estimators':stats.randint(1, 70),
#     'gamma':[i/10.0 for i in range(0, 5)],
#    # 'reg_alpha':[1e-5, 1e-2, 0.1, 1, 100],
#     'reg_alpha':[0, 0.001, 0.005, 0.01, 0.05]
#
# }
#
#
#
# # xgb_model = XGBClassifier()
#
# # Create the RandomizedSearchCV object
# cv = RepeatedStratifiedKFold(n_splits=10, shuffle=True, random_state=343)
# random_search = RandomizedSearchCV(xgbc_pipe[1], param_distributions=param_dist, n_iter=20, cv=cv, scoring='precision_macro', verbose=2, n_jobs=-1, random_state=321)
#
# # Fit the RandomizedSearchCV object to the training data
# random_search.fit(X_train, y_train)
#
# # Print the best set of hyperparameters and the corresponding score
# print("Best set of hyperparameters: ", random_search.best_params_)
# print("Best score: ", random_search.best_score_)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.6133718787189452

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[34002,  2489,   432,     6,  8973],
#        [   44,   288,    45,     0,    70],
#        [   19,    47,   167,     0,    20],
#        [    0,     0,     2,   164,     1],
#        [53129,  6751,  1387,     8, 81862]])

# %% [markdown]
# Without ExtraTrees Imputer or SMOTE + XGBClassifier(): 106/(71+106+14+256) = 0.23 precision score for Time Interval Class 1
# With HistGradientBoostImputer + SMOTE + XGBClassifier(tree_method = "hist"): 0.6375838926 precision score for Time Interval Class 1
# With GradientBoostImputer + SMOTE + XGBClassifier(tree_method = "hist"): ___ precision score for Time Interval Class 1
# With GradientBoostImputer + SMOTE + XGBClassifier(): ___ precision score for Time Interval Class 1

# %%
print(classification_report(y_test, y_pred, zero_division = 0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.39      0.74      0.51     45902
#            1       0.03      0.64      0.06       447
#            2       0.08      0.66      0.15       253
#            3       0.92      0.98      0.95       167
#            4       0.90      0.57      0.70    143137
#
#     accuracy                           0.61    189906
#    macro avg       0.46      0.72      0.47    189906
# weighted avg       0.77      0.61      0.65    189906

# %% [markdown]
# scores = cross_val_score(xgbc_pipe, X_test, y_test, cv=10, scoring='precision_macro')

# %% [markdown]
# print('Cross Validation Macro Precision Scores:', scores)

# %%
### Top Features' Importance

# %% [markdown]
# selection = SelectFromModel(xgbc_pipe[1], threshold=0.0001, prefit=True)

# %% [markdown]
# X_selected = selection.transform(X_train)
# X_selected

# %% [markdown]
# plot_importance_object = plot_importance(xgbc_pipe[1], importance_type='gain')
# plt.title('Feature Importance for Full Derate Prediction')
# plt.show()

# %% [markdown]
# feature_importances = xgbc_pipe[1].feature_importances_
#
# feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importances})
#
# feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
#
# top_27_features = feature_importance_df.head(27)
#
# print(top_27_features)

# %% [markdown]
# print("Top 27 features:", top_27_features['Feature'].tolist())

# %% [markdown]
# ### Import fresh test data (previously held out) for a fresh round of testing

# %%
test = pd.read_csv('../data/In2019_df_Cat9999999.csv')

# %%
FreshTest_In2019 = test
FreshTest_In2019
# Out:
#         Unnamed: 0.1  Unnamed: 0  RecordID    ESS_Id       EventTimeStamp  \
# 0             952775     1062090   1104925  73930906  2019-01-11 12:51:18
# 1             952776     1062091   1104926  73930907  2019-01-11 12:51:18
# 2             952781     1062096   1104931  73934247  2019-01-11 13:11:40
# 3             952782     1062097   1104932  73934248  2019-01-11 13:11:40
# 4             952809     1062135   1104970  73942005  2019-01-11 13:13:38
# ...              ...         ...       ...       ...                  ...
# 112014        977126     1089938   1137548  80503703  2019-03-16 11:22:32
# 112015        977150     1089962   1137572  80509396  2019-03-16 11:24:04
# 112016        977151     1089963   1137573  80509397  2019-03-16 11:27:41
# 112017        978491     1091502   1139112  80907838  2019-03-20 10:57:34
# 112018        978891     1091973   1139583  81025027  2019-03-21 10:05:14
#
#                                          eventDescription  actionDescription  \
# 0                               High Voltage (Fuel Level)                NaN
# 1                   High Voltage (Left Fuel Level Sensor)                NaN
# 2                               High Voltage (Fuel Level)                NaN
# 3                   High Voltage (Left Fuel Level Sensor)                NaN
# 4                               High Voltage (Fuel Level)                NaN
# ...                                                   ...                ...
# 112014  Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# 112015  Special Instructions Engine Starter Solenoid L...                NaN
# 112016                                                NaN                NaN
# 112017  Special Instructions Engine Starter Solenoid L...                NaN
# 112018                                                NaN                NaN
#
#                                        ecuSoftwareVersion ecuSerialNumber  \
# 0                                                 unknown         unknown
# 1                                                 unknown         unknown
# 2                                                 unknown         unknown
# 3                                                 unknown         unknown
# 4                                                 unknown         unknown
# ...                                                   ...             ...
# 112014  AAAI000051*AAAM010056*Z091290   *A82J170202A_b...      6232171647
# 112015                                5569997 *E250.e003*        K1243673
# 112016                                5569997 *E250.e003*        K1243673
# 112017                                                NaN        K1243673
# 112018                                5569997 *E250.e003*        K1243673
#
#                ecuModel  ...     Speed  SwitchedBatteryVoltage  Throttle  \
# 0               unknown  ...  46.52031                     NaN      34.4
# 1               unknown  ...  46.52031                     NaN      34.4
# 2               unknown  ...       NaN                     NaN       NaN
# 3               unknown  ...       NaN                     NaN       NaN
# 4               unknown  ...   0.00000                     NaN       0.0
# ...                 ...  ...       ...                     ...       ...
# 112014          EC80ESP  ...       NaN                     NaN       NaN
# 112015  FAOM-xx810S-EC3  ...   0.00000                     NaN     100.0
# 112016  FAOM-xx810S-EC3  ...   0.00000                     NaN     100.0
# 112017  FAOM-xx810S-EC3  ...       NaN                     NaN       NaN
# 112018  FAOM-xx810S-EC3  ...       NaN                     NaN       NaN
#
#         TurboBoostPressure        spn_fmi  is_fullderate  is_fullderate_group  \
# 0                    13.05       96.0_3.0              0                    1
# 1                    13.05      829.0_3.0              0                    1
# 2                      NaN       96.0_3.0              0                    1
# 3                      NaN      829.0_3.0              0                    1
# 4                     1.16       96.0_3.0              0                    1
# ...                    ...            ...            ...                  ...
# 112014                 NaN      639.0_2.0              0                    0
# 112015                0.29    1321.0_14.0              0                    0
# 112016                0.29  520321.0_13.0              0                    0
# 112017                 NaN    1321.0_14.0              0                    0
# 112018                 NaN  520321.0_13.0              0                    0
#
#         EquipID_Index  time_to_next_SPN5246  time_interval_to_SPN5246_class
# 0               301_1           239999976.0                         9999999
# 1               301_1           239999976.0                         9999999
# 2               301_1           239999976.0                         9999999
# 3               301_1           239999976.0                         9999999
# 4               301_1           239999976.0                         9999999
# ...               ...                   ...                             ...
# 112014    105437340_0           239999976.0                         9999999
# 112015    105437340_0           239999976.0                         9999999
# 112016    105437340_0           239999976.0                         9999999
# 112017    105437340_0           239999976.0                         9999999
# 112018    105437340_0           239999976.0                         9999999
#
# [112019 rows x 53 columns]

# %%
FreshTest_In2019[['ecuSource', 'LampStatus', 'time_interval_to_SPN5246_class', 'ecuSerialNumber', 'ecuModel', 'ecuMake']] = FreshTest_In2019[['ecuSource', 'LampStatus', 'time_interval_to_SPN5246_class', 'ecuSerialNumber', 'ecuModel', 'ecuMake']].astype('category')

# %%
FreshTest_In2019[['activeTransitionCount']] = FreshTest_In2019[['activeTransitionCount']].astype('category')

# %%
X_fresh_test = FreshTest_In2019.drop(columns = [    'Unnamed: 0',
                                                    'Unnamed: 0.1',
                                                    'RecordID',
                                                    'ESS_Id',
                                                    'actionDescription',
                                                    'spn',
                                                    'fmi',
                                                    'faultValue',
                                                    'MCTNumber',
                                                    'Latitude',
                                                    'Longitude',
                                                    'is_fullderate',
                                                    'is_fullderate_group',
                                                    'time_to_next_SPN5246',
                                                    'ServiceDistance',
                                                    'EventTimeStamp',
                                                    'eventDescription',
                                                    'EquipmentID',
                                                    'LocationTimeStamp',
                                                    'EquipID_Index',
                                                    'time_interval_to_SPN5246_class',
                                                    'MCTNumber',                                  
                                                    'FaultId',
                                                    'ecuSoftwareVersion',
                                                    'ecuSerialNumber',
                                                    'ecuModel',
                                                    'ecuMake'  
                                                    ]
                                     )  
X_fresh_test
# Out:
#        ecuSource  active activeTransitionCount  AcceleratorPedal  \
# 0             49    True                   126              34.0
# 1             49    True                   126              34.0
# 2             49   False                   126               NaN
# 3             49   False                   126               NaN
# 4             49    True                   126               0.0
# ...          ...     ...                   ...               ...
# 112014        11   False                   127               NaN
# 112015         3    True                     1               0.0
# 112016         3    True                     4               0.0
# 112017         3   False                     5               NaN
# 112018         3   False                    12               NaN
#
#         BarometricPressure CruiseControlActive  CruiseControlSetSpeed  \
# 0                     14.5               False                    0.0
# 1                     14.5               False                    0.0
# 2                      NaN                 NaN                    NaN
# 3                      NaN                 NaN                    NaN
# 4                     14.5               False                    0.0
# ...                    ...                 ...                    ...
# 112014                 NaN                 NaN                    NaN
# 112015                14.5               False                    0.0
# 112016                14.5               False                    0.0
# 112017                 NaN                 NaN                    NaN
# 112018                 NaN                 NaN                    NaN
#
#         DistanceLtd  EngineCoolantTemperature  EngineLoad  ...  \
# 0          389864.2                     145.4        46.0  ...
# 1          389864.2                     145.4        46.0  ...
# 2               NaN                       NaN         NaN  ...
# 3               NaN                       NaN         NaN  ...
# 4          389870.2                     156.2        13.0  ...
# ...             ...                       ...         ...  ...
# 112014          NaN                       NaN         NaN  ...
# 112015     147893.8                      82.4        25.0  ...
# 112016     147893.8                      91.4        24.0  ...
# 112017          NaN                       NaN         NaN  ...
# 112018          NaN                       NaN         NaN  ...
#
#         FuelTemperature  IgnStatus  IntakeManifoldTemperature  LampStatus  \
# 0                  71.6       True                       84.2      1279.0
# 1                  71.6       True                       84.2      1279.0
# 2                   NaN        NaN                        NaN       255.0
# 3                   NaN        NaN                        NaN       255.0
# 4                  87.8       True                      107.6      1279.0
# ...                 ...        ...                        ...         ...
# 112014              NaN        NaN                        NaN     50175.0
# 112015              NaN       True                       68.0     63487.0
# 112016              NaN       True                       73.4     63487.0
# 112017              NaN        NaN                        NaN     63487.0
# 112018              NaN        NaN                        NaN       255.0
#
#         ParkingBrake     Speed  SwitchedBatteryVoltage  Throttle  \
# 0              False  46.52031                     NaN      34.4
# 1              False  46.52031                     NaN      34.4
# 2                NaN       NaN                     NaN       NaN
# 3                NaN       NaN                     NaN       NaN
# 4               True   0.00000                     NaN       0.0
# ...              ...       ...                     ...       ...
# 112014           NaN       NaN                     NaN       NaN
# 112015          True   0.00000                     NaN     100.0
# 112016          True   0.00000                     NaN     100.0
# 112017           NaN       NaN                     NaN       NaN
# 112018           NaN       NaN                     NaN       NaN
#
#        TurboBoostPressure        spn_fmi
# 0                   13.05       96.0_3.0
# 1                   13.05      829.0_3.0
# 2                     NaN       96.0_3.0
# 3                     NaN      829.0_3.0
# 4                    1.16       96.0_3.0
# ...                   ...            ...
# 112014                NaN      639.0_2.0
# 112015               0.29    1321.0_14.0
# 112016               0.29  520321.0_13.0
# 112017                NaN    1321.0_14.0
# 112018                NaN  520321.0_13.0
#
# [112019 rows x 27 columns]

# %%
X_fresh_test['spn_fmi'] = X_fresh_test['spn_fmi'].str.replace('.0', '')

# %%
X_fresh_test.shape
# Out:
# (112019, 27)

# %% [markdown]
# X_FreshTest_Transformed = ct.transform(X_fresh_test)
# X_FreshTest_Transformed

# %%
y_fresh_pred = xgbc_pipe.predict(X_fresh_test)
# Out:
# XGBImputer - Epoch: 1 | Categorical gamma: inf/37163. | Numerical gamma: inf/0.0699539864
# XGBImputer - Epoch: 2 | Categorical gamma: 37163./8583. | Numerical gamma: 0.0699539864/0.1192365424
# XGBImputer - Epoch: 3 | Categorical gamma: 8583./0. | Numerical gamma: 0.1192365424/0.0070854019
# XGBImputer - Epoch: 4 | Categorical gamma: 0./0. | Numerical gamma: 0.0070854019/0.
# XGBImputer - Epoch: 5 | Categorical gamma: 0./0. | Numerical gamma: 0./0.

# %%
y_fresh_pred
# Out:
# array([4, 4, 4, ..., 4, 4, 1], shape=(112019,))

# %%
y_fresh_test = FreshTest_In2019['time_interval_to_SPN5246_class']

# %%
y_fresh_test_encoded = le_y.transform(y_fresh_test)

# %%
accuracy_score(y_fresh_test_encoded, y_fresh_pred)
# Out:
# 0.6527196279202635

# %%
confusion_matrix(y_fresh_test_encoded, y_fresh_pred)
# Out:
# array([[  635,   109,    89,     0,  1280],
#        [   63,    84,    47,     0,   117],
#        [   31,    18,    47,     0,    44],
#        [    0,     0,     0,    98,     3],
#        [33635,  2355,  1111,     0, 72253]])

# %% [markdown]
# Without ExtraTrees Imputer or SMOTE + XGBClassifier(): 0 precision score for Time Interval Class 1
# With HistGradientBoostImputer + SMOTE + XGBClassifier(tree_method = "hist"): 0.421221865 precision score for Time Interval Class 1
# With GradientBoostImputer + SMOTE + XGBClassifier(tree_method = "hist"): ___ precision score for Time Interval Class 1
# With GradientBoostImputer + SMOTE + XGBClassifier(): ___ precision score for Time Interval Class 1

# %%
print(classification_report(y_fresh_test_encoded, y_fresh_pred, zero_division = 0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.02      0.30      0.03      2113
#            1       0.03      0.27      0.06       311
#            2       0.04      0.34      0.07       140
#            3       1.00      0.97      0.98       101
#            4       0.98      0.66      0.79    109354
#
#     accuracy                           0.65    112019
#    macro avg       0.41      0.51      0.39    112019
# weighted avg       0.96      0.65      0.77    112019

# %%
print(f'MSE: {mean_squared_error(y_fresh_test_encoded, y_fresh_pred)}')
print(f'RMSE: {root_mean_squared_error(y_fresh_test_encoded, y_fresh_pred)}')
print(f'MAE: {mean_absolute_error(y_fresh_test_encoded, y_fresh_pred)}')
print(f'MAPE: {mean_absolute_percentage_error(y_fresh_test_encoded, y_fresh_pred)}')
print(f'R2: {r2_score(y_fresh_test_encoded, y_fresh_pred)}')
# Out:
# MSE: 5.233290781028218
# RMSE: 2.2876386911022943
# MAE: 1.337862326926682
# MAPE: 217382436775835.47
# R2: -15.097830541865616

# %% [markdown]
# fresh_CV_scores = cross_val_score(xgbc_pipe, X_fresh_test, y_fresh_test_encoded, cv=10, scoring='precision_macro')

# %% [markdown]
# print('Cross Validation Macro Precision Scores:', fresh_CV_scores)

# %%
# submission.to_csv('../data/submission_XGBClassifier_TunedHyperparameter_TargetEncoder_LearningRatePt05_MaxTreeDepth5_MinChild1_Estimators199_TestSizePt001_MostFeatures_ExcludingMapCode.csv', index = False)
