# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier, MLPRegressor

from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.metrics import (
        classification_report, confusion_matrix, r2_score, mean_squared_error, root_mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score, f1_score, roc_auc_score, roc_curve
)

from sklearn.inspection import PartialDependenceDisplay

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV, RepeatedStratifiedKFold
from xgboost import XGBClassifier, XGBRegressor, plot_importance
from sklearn.model_selection import cross_val_score

# %%
from category_encoders import TargetEncoder 
from sklearn.feature_selection import SelectFromModel

# %%
TrainPre2019 = pd.read_csv('../data/Train_Pre2019_TimeIntervalLabeled_PerTruck.csv')
# Out:
# /var/folders/nl/hqcw9pqd0ns4q0b61syv0q2m0000gn/T/ipykernel_14764/1553715100.py:1: DtypeWarning: Columns (17,41,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   TrainPre2019 = pd.read_csv('../data/Train_Pre2019_TimeIntervalLabeled_PerTruck.csv')

# %%
TrainPre2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945558 entries, 0 to 945557
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0.1                    945558 non-null  int64
#  1   Unnamed: 0                      945558 non-null  int64
#  2   RecordID                        945558 non-null  int64
#  3   ESS_Id                          945558 non-null  int64
#  4   EventTimeStamp                  945558 non-null  object
#  5   eventDescription                898600 non-null  object
#  6   actionDescription               0 non-null       float64
#  7   ecuSoftwareVersion              743930 non-null  object
#  8   ecuSerialNumber                 704649 non-null  object
#  9   ecuModel                        897109 non-null  object
#  10  ecuMake                         897109 non-null  object
#  11  ecuSource                       945558 non-null  int64
#  12  spn                             945558 non-null  float64
#  13  fmi                             945558 non-null  float64
#  14  active                          945558 non-null  bool
#  15  activeTransitionCount           945558 non-null  int64
#  16  faultValue                      0 non-null       float64
#  17  EquipmentID                     945558 non-null  object
#  18  MCTNumber                       945558 non-null  int64
#  19  Latitude                        945558 non-null  float64
#  20  Longitude                       945558 non-null  float64
#  21  LocationTimeStamp               945558 non-null  object
#  22  FaultId                         945558 non-null  int64
#  23  AcceleratorPedal                424358 non-null  float64
#  24  BarometricPressure              474521 non-null  float64
#  25  CruiseControlActive             464434 non-null  object
#  26  CruiseControlSetSpeed           465383 non-null  float64
#  27  DistanceLtd                     474430 non-null  float64
#  28  EngineCoolantTemperature        474488 non-null  float64
#  29  EngineLoad                      474031 non-null  float64
#  30  EngineOilPressure               474597 non-null  float64
#  31  EngineOilTemperature            473100 non-null  float64
#  32  EngineRpm                       474818 non-null  float64
#  33  EngineTimeLtd                   470684 non-null  float64
#  34  FuelLevel                       400576 non-null  float64
#  35  FuelLtd                         473878 non-null  float64
#  36  FuelRate                        473795 non-null  float64
#  37  FuelTemperature                 247372 non-null  float64
#  38  IgnStatus                       491978 non-null  object
#  39  IntakeManifoldTemperature       474592 non-null  float64
#  40  LampStatus                      945558 non-null  float64
#  41  ParkingBrake                    302314 non-null  object
#  42  ServiceDistance                 198 non-null     float64
#  43  Speed                           472999 non-null  float64
#  44  SwitchedBatteryVoltage          102095 non-null  object
#  45  Throttle                        319235 non-null  float64
#  46  TurboBoostPressure              472518 non-null  float64
#  47  spn_fmi                         945558 non-null  object
#  48  is_fullderate                   945558 non-null  int64
#  49  is_fullderate_group             945558 non-null  int64
#  50  EquipID_Index                   945558 non-null  object
#  51  time_to_next_SPN5246            945558 non-null  float64
#  52  time_interval_to_SPN5246_class  945558 non-null  int64
# dtypes: bool(1), float64(27), int64(11), object(14)
# memory usage: 376.0+ MB

# %% [markdown]
# **Goal:** Predict the rank based on the total shots.

# %%
TrainPre2019['time_interval_to_SPN5246_class'].value_counts()
# Out:
# time_interval_to_SPN5246_class
# 0    943246
# 2      1546
# 1       766
# Name: count, dtype: int64

# %%
TrainPre2019
# Out:
#         Unnamed: 0.1  Unnamed: 0  RecordID   ESS_Id       EventTimeStamp  \
# 0              43695       48303     49415  2363162  2015-05-11 13:11:20
# 1              45443       50251     51363  2400445  2015-05-13 08:22:32
# 2              49998       55260     57330  2482983  2015-05-18 09:34:05
# 3              54040       59636     61706  2554027  2015-05-21 13:57:35
# 4              54132       59731     61801  2555325  2015-05-21 14:54:32
# ...              ...         ...       ...      ...                  ...
# 945553          3991        4494      4495  1052146  2015-02-24 16:24:05
# 945554          5856        6438      6439  1089561  2015-02-26 13:12:11
# 945555          5864        6446      6447  1090499  2015-02-26 13:50:59
# 945556          4423        4952      4953  1059704  2015-02-25 06:08:43
# 945557          4463        4999      5000  1060204  2015-02-25 06:38:40
#
#                                          eventDescription  actionDescription  \
# 0       Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# 1           Condition Exists Cruise Control Enable Switch                NaN
# 2       Abnormal Rate of Change Aftertreatment 1 Outle...                NaN
# 3       Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# 4       Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# ...                                                   ...                ...
# 945553          Low (Severity Medium) Catalyst Tank Level                NaN
# 945554                                                NaN                NaN
# 945555                                                NaN                NaN
# 945556  Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# 945557  Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
#
#                                      ecuSoftwareVersion ecuSerialNumber  \
# 0                                               unknown         unknown
# 1                                               unknown         unknown
# 2                                       PC4__1284P4C_2*         6U13D13
# 3                                               unknown         unknown
# 4                                               unknown         unknown
# ...                                                 ...             ...
# 945553  05317106*04119044*051914190353*09400015*G1*BDR*        79751302
# 945554  05317106*04119044*051914190353*09400015*G1*BDR*        79751302
# 945555  05317106*04119044*051914190353*09400015*G1*BDR*        79751302
# 945556                                          unknown         unknown
# 945557                                          unknown         unknown
#
#                  ecuModel  ...      Speed  SwitchedBatteryVoltage  Throttle  \
# 0                 unknown  ...   4.475814                 3276.75      14.4
# 1                 unknown  ...  64.637170                 3276.75      89.6
# 2                      MX  ...  63.525490                 3276.75       0.0
# 3                 unknown  ...   4.364162                 3276.75      12.0
# 4                 unknown  ...        NaN                     NaN       NaN
# ...                   ...  ...        ...                     ...       ...
# 945553  6X1u13D1500000000  ...        NaN                     NaN       NaN
# 945554  6X1u13D1500000000  ...   2.058292                 3276.75       0.0
# 945555  6X1u13D1500000000  ...        NaN                     NaN       NaN
# 945556            unknown  ...   4.378725                 3276.75       0.0
# 945557            unknown  ...        NaN                     NaN       NaN
#
#         TurboBoostPressure      spn_fmi  is_fullderate  is_fullderate_group  \
# 0                     0.58    639.0_2.0              0                    0
# 1                     4.64   596.0_31.0              0                    0
# 2                    20.30  3226.0_10.0              0                    0
# 3                     1.45    639.0_2.0              0                    0
# 4                      NaN    639.0_2.0              0                    0
# ...                    ...          ...            ...                  ...
# 945553                 NaN  1761.0_18.0              0                    0
# 945554                0.29   5848.0_9.0              0                    0
# 945555                 NaN   5848.0_9.0              0                    0
# 945556                1.74    639.0_2.0              0                    0
# 945557                 NaN    639.0_2.0              0                    0
#
#        EquipID_Index  time_to_next_SPN5246  time_interval_to_SPN5246_class
# 0              301_0          1.027800e+04                               0
# 1              301_0          1.023481e+04                               0
# 2              301_0          1.011362e+04                               0
# 3              301_0          1.003723e+04                               0
# 4              301_0          1.003628e+04                               0
# ...              ...                   ...                             ...
# 945553       R1762_0          2.400000e+08                               0
# 945554       R1762_0          2.400000e+08                               0
# 945555       R1762_0          2.400000e+08                               0
# 945556       R1764_0          2.400000e+08                               0
# 945557       R1764_0          2.400000e+08                               0
#
# [945558 rows x 53 columns]

# %% [markdown]
# class MultiColumnLabelEncoder:
#     def __init__(self,columns = None):
#         self.columns = columns # array of column names to encode
#
#     def fit(self,X,y=None):
#         return self # not relevant here
#
#     def transform(self,X):
#         '''
#         Transforms columns of X specified in self.columns using
#         LabelEncoder(). If no columns specified, transforms all
#         columns in X.
#         '''
#         output = X.copy()
#         if self.columns is not None:
#             for col in self.columns:
#                 output[col] = OneHotEncoder().fit_transform(output[col])
#         else:
#             for colname,col in output.iteritems():
#                 output[colname] = OneHotEncoder().fit_transform(col)
#         return output
#
#     def fit_transform(self,X,y=None):
#         return self.fit(X,y).transform(X)

# %%
TrainPre2019[['ecuSource', 'LampStatus', 'time_interval_to_SPN5246_class', 'ecuSerialNumber', 'ecuModel', 'ecuMake']] = TrainPre2019[['ecuSource', 'LampStatus', 'time_interval_to_SPN5246_class', 'ecuSerialNumber', 'ecuModel', 'ecuMake']].astype('str')

# %%
TrainPre2019[['ecuSource', 'LampStatus', ]] = TrainPre2019[['ecuSource', 'LampStatus']].astype('str')

# %%
TrainPre2019.replace(to_replace='3276,75', value='3278.75', inplace=True)

# %%
TrainPre2019[[  'AcceleratorPedal',
                    'BarometricPressure',
                    'CruiseControlSetSpeed',
                    'DistanceLtd',
                    'EngineCoolantTemperature',
                    'EngineLoad',
                    'EngineOilPressure',
                    'EngineOilTemperature',
                    'EngineRpm',
                    'EngineTimeLtd',
                    'FuelLevel',
                    'FuelLtd',
                    'FuelRate',
                    'FuelTemperature',
                    'IntakeManifoldTemperature',
                    'Speed',
                    'Throttle',
                    'active',
                    'TurboBoostPressure',
                    'activeTransitionCount',
                    'CruiseControlActive',
                    'IgnStatus',
                    'ParkingBrake',
                    'SwitchedBatteryVoltage'
]] = TrainPre2019[[                         'AcceleratorPedal',
                                            'BarometricPressure',
                                            'CruiseControlSetSpeed',
                                            'DistanceLtd',
                                            'EngineCoolantTemperature',
                                            'EngineLoad',
                                            'EngineOilPressure',
                                            'EngineOilTemperature',
                                            'EngineRpm',
                                            'EngineTimeLtd',
                                            'FuelLevel',
                                            'FuelLtd',
                                            'FuelRate',
                                            'FuelTemperature',
                                            'IntakeManifoldTemperature',
                                            'Speed',
                                            'Throttle',
                                            'active',
                                            'TurboBoostPressure',
                                            'activeTransitionCount',
                                            'CruiseControlActive',
                                            'IgnStatus',
                                            'ParkingBrake',
                                            'SwitchedBatteryVoltage'
                     ]].astype('float64')

# %%
NumericColumns = TrainPre2019.select_dtypes(include=[np.number]).columns.tolist()
NumericColumns_Without_MatchID = NumericColumns.pop(0)
NumericColumns
# Out:
# ['Unnamed: 0',
#  'RecordID',
#  'ESS_Id',
#  'actionDescription',
#  'spn',
#  'fmi',
#  'active',
#  'activeTransitionCount',
#  'faultValue',
#  'MCTNumber',
#  'Latitude',
#  'Longitude',
#  'FaultId',
#  'AcceleratorPedal',
#  'BarometricPressure',
#  'CruiseControlActive',
#  'CruiseControlSetSpeed',
#  'DistanceLtd',
#  'EngineCoolantTemperature',
#  'EngineLoad',
#  'EngineOilPressure',
#  'EngineOilTemperature',
#  'EngineRpm',
#  'EngineTimeLtd',
#  'FuelLevel',
#  'FuelLtd',
#  'FuelRate',
#  'FuelTemperature',
#  'IgnStatus',
#  'IntakeManifoldTemperature',
#  'ParkingBrake',
#  'ServiceDistance',
#  'Speed',
#  'SwitchedBatteryVoltage',
#  'Throttle',
#  'TurboBoostPressure',
#  'is_fullderate',
#  'is_fullderate_group',
#  'time_to_next_SPN5246']

# %% [markdown]
# Among numeric columns, will keep:
#
#
# ['AcceleratorPedal',
# 'BarometricPressure',
# 'CruiseControlSetSpeed',
# 'DistanceLtd',
# 'EngineCoolantTemperature',
# 'EngineLoad',
# 'EngineOilPressure',
# 'EngineOilTemperature',
# 'EngineRpm',
# 'EngineTimeLtd',
# 'FuelLevel',
# 'FuelLtd',
# 'FuelRate',
# 'FuelTemperature',
# 'IntakeManifoldTemperature',
# 'Speed',
# 'Throttle',
# 'active',
# 'TurboBoostPressure',
# 'activeTransitionCount',
# 'CruiseControlActive',
# 'IgnStatus',
# 'ParkingBrake',
# 'SwitchedBatteryVoltage']

# %%
NonNumericColumns = TrainPre2019.select_dtypes(exclude=[np.number]).columns.tolist()
NonNumericColumns
# Out:
# ['EventTimeStamp',
#  'eventDescription',
#  'ecuSoftwareVersion',
#  'ecuSerialNumber',
#  'ecuModel',
#  'ecuMake',
#  'ecuSource',
#  'EquipmentID',
#  'LocationTimeStamp',
#  'LampStatus',
#  'spn_fmi',
#  'EquipID_Index',
#  'time_interval_to_SPN5246_class']

# %% [markdown]
# Among, non-numeric columns, will keep:
#
#         ('target_encoder', TargetEncoder(handle_unknown='ignore'), [   'ecuSoftwareVersion',
#                                                                         'ecuSerialNumber',
#                                                                         'ecuModel',
#                                                                         'ecuMake',
#                                                                         'spn_fmi'
#                                                                     ]),
#         ('ordinal_encoder', OrdinalEncoder(handle_unknown='ignore'), [   'ecuSource',
#                                                                                 'LampStatus'
#                                                                         ])

# %%
X = TrainPre2019.drop(columns = [   'Unnamed: 0',
                                    'RecordID',
                                    'ESS_Id',
                                    'actionDescription',
                                    'spn',
                                    'fmi',
                                    'faultValue',
                                    'MCTNumber',
                                    'Latitude',
                                    'Longitude',
                                    'is_fullderate',
                                    'is_fullderate_group',
                                    'time_to_next_SPN5246',
                                    'ServiceDistance',
                                    'EventTimeStamp',
                                    'eventDescription',
                                    'EquipmentID',
                                    'LocationTimeStamp',
                                    'EquipID_Index',
                                    'time_interval_to_SPN5246_class',
                                    'MCTNumber',                                  
                                    'FaultId'                                                                                        
                                ]
                      )
y = TrainPre2019['time_interval_to_SPN5246_class']

# %%
X
# Out:
#         Unnamed: 0.1                               ecuSoftwareVersion  \
# 0              43695                                          unknown
# 1              45443                                          unknown
# 2              49998                                  PC4__1284P4C_2*
# 3              54040                                          unknown
# 4              54132                                          unknown
# ...              ...                                              ...
# 945553          3991  05317106*04119044*051914190353*09400015*G1*BDR*
# 945554          5856  05317106*04119044*051914190353*09400015*G1*BDR*
# 945555          5864  05317106*04119044*051914190353*09400015*G1*BDR*
# 945556          4423                                          unknown
# 945557          4463                                          unknown
#
#        ecuSerialNumber           ecuModel  ecuMake ecuSource  active  \
# 0              unknown            unknown  unknown        11     1.0
# 1              unknown            unknown  unknown        49     1.0
# 2              6U13D13                 MX     PCAR         0     1.0
# 3              unknown            unknown  unknown        11     1.0
# 4              unknown            unknown  unknown        11     0.0
# ...                ...                ...      ...       ...     ...
# 945553        79751302  6X1u13D1500000000    CMMNS         0     0.0
# 945554        79751302  6X1u13D1500000000    CMMNS         0     1.0
# 945555        79751302  6X1u13D1500000000    CMMNS         0     0.0
# 945556         unknown            unknown  unknown        11     1.0
# 945557         unknown            unknown  unknown        11     0.0
#
#         activeTransitionCount  AcceleratorPedal  BarometricPressure  ...  \
# 0                       127.0              14.4             13.9200  ...
# 1                         3.0              89.6             14.4275  ...
# 2                         6.0               0.0             14.3550  ...
# 3                       127.0              12.0             14.5725  ...
# 4                       127.0               NaN                 NaN  ...
# ...                       ...               ...                 ...  ...
# 945553                   11.0               NaN                 NaN  ...
# 945554                    1.0               0.0             14.2100  ...
# 945555                    1.0               NaN                 NaN  ...
# 945556                  127.0              21.6             14.4275  ...
# 945557                  127.0               NaN                 NaN  ...
#
#         FuelTemperature  IgnStatus  IntakeManifoldTemperature  LampStatus  \
# 0                 134.6        1.0                      154.4      1279.0
# 1                 100.4        1.0                      120.2      4351.0
# 2                 120.2        1.0                      118.4     17407.0
# 3                 109.4        1.0                      107.6      1279.0
# 4                   NaN        NaN                        NaN      1279.0
# ...                 ...        ...                        ...         ...
# 945553              NaN        NaN                        NaN      1023.0
# 945554             32.0        1.0                       84.2     17407.0
# 945555              NaN        NaN                        NaN      1023.0
# 945556             32.0        1.0                       93.2      1279.0
# 945557              NaN        NaN                        NaN      1279.0
#
#         ParkingBrake      Speed  SwitchedBatteryVoltage  Throttle  \
# 0                0.0   4.475814                 3276.75      14.4
# 1                0.0  64.637170                 3276.75      89.6
# 2                0.0  63.525490                 3276.75       0.0
# 3                0.0   4.364162                 3276.75      12.0
# 4                NaN        NaN                     NaN       NaN
# ...              ...        ...                     ...       ...
# 945553           NaN        NaN                     NaN       NaN
# 945554           0.0   2.058292                 3276.75       0.0
# 945555           NaN        NaN                     NaN       NaN
# 945556           0.0   4.378725                 3276.75       0.0
# 945557           NaN        NaN                     NaN       NaN
#
#         TurboBoostPressure      spn_fmi
# 0                     0.58    639.0_2.0
# 1                     4.64   596.0_31.0
# 2                    20.30  3226.0_10.0
# 3                     1.45    639.0_2.0
# 4                      NaN    639.0_2.0
# ...                    ...          ...
# 945553                 NaN  1761.0_18.0
# 945554                0.29   5848.0_9.0
# 945555                 NaN   5848.0_9.0
# 945556                1.74    639.0_2.0
# 945557                 NaN    639.0_2.0
#
# [945558 rows x 32 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 945553    0
# 945554    0
# 945555    0
# 945556    0
# 945557    0
# Name: time_interval_to_SPN5246_class, Length: 945558, dtype: object

# %%
X.describe()
# Out:
#        Unnamed: 0.1         active  activeTransitionCount  AcceleratorPedal  \
# count  9.455580e+05  945558.000000          945558.000000     424358.000000
# mean   4.728048e+05       0.520304              77.225354         28.541964
# std    2.730089e+05       0.499588              59.232122         36.575343
# min    0.000000e+00       0.000000               0.000000          0.000000
# 25%    2.363892e+05       0.000000               1.000000          0.000000
# 50%    4.727785e+05       1.000000             126.000000          3.600000
# 75%    7.091678e+05       1.000000             126.000000         48.800000
# max    1.053228e+06       1.000000             127.000000        100.000000
#
#        BarometricPressure  CruiseControlActive  CruiseControlSetSpeed  \
# count       474521.000000        464434.000000          465383.000000
# mean            14.191881             0.097049              62.181007
# std              1.194569             0.296025              12.223644
# min              3.045000             0.000000               0.000000
# 25%             14.210000             0.000000              64.622600
# 50%             14.355000             0.000000              66.486720
# 75%             14.500000             0.000000              66.486720
# max             15.225000             1.000000              69.593570
#
#          DistanceLtd  EngineCoolantTemperature     EngineLoad  ...  \
# count  474430.000000             474488.000000  474031.000000  ...
# mean   364649.003943                169.567350      31.972046  ...
# std    142702.162418                 32.833615      30.646621  ...
# min         0.000000                 -7.600000       0.000000  ...
# 25%    267356.325000                170.600000      11.000000  ...
# 50%    379834.450000                183.200000      19.000000  ...
# 75%    481544.600000                186.800000      48.000000  ...
# max    649549.000000                406.400000     101.000000  ...
#
#              FuelLtd       FuelRate  FuelTemperature      IgnStatus  \
# count  473878.000000  473795.000000    247372.000000  491978.000000
# mean    50561.567985       4.630860        37.023005       0.995723
# std     24175.339372       5.787473        23.115581       0.065256
# min         0.000000       0.000000        17.600000       0.000000
# 25%     33491.996925       0.647223        32.000000       1.000000
# 50%     51943.886413       1.690706        32.000000       1.000000
# 75%     68751.172791       7.211920        32.000000       1.000000
# max    312737.574126      25.611560       231.800000       1.000000
#
#        IntakeManifoldTemperature   ParkingBrake          Speed  \
# count              474592.000000  302314.000000  472999.000000
# mean                  106.751831       0.284529      26.339840
# std                    25.486344       0.451190      28.238055
# min                   -40.000000       0.000000       0.000000
# 25%                    89.600000       0.000000       0.000000
# 50%                   109.400000       0.000000       9.679798
# 75%                   125.600000       1.000000      60.018145
# max                   264.200000       1.000000     158.447200
#
#        SwitchedBatteryVoltage       Throttle  TurboBoostPressure
# count           102095.000000  319235.000000       472518.000000
# mean              3104.445477      66.092073            6.289805
# std                729.771748      46.339979            8.563973
# min                  7.650000       0.000000            0.000000
# 25%               3276.750000       0.000000            0.580000
# 50%               3276.750000     100.000000            2.030000
# 75%               3276.750000     100.000000            8.700000
# max               3278.750000     100.000000           63.220000
#
# [8 rows x 25 columns]

# %%
X

le_y = LabelEncoder()

y_fitted = le_y.fit(y)
y_encoded = le_y.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size = 0.001, random_state = 321, shuffle=True, stratify = y_encoded)

# %%
# scaler = StandardScaler()


ct = ColumnTransformer(
    transformers=[
        ('scaler', StandardScaler(), [  'AcceleratorPedal',
                                        'BarometricPressure',
                                        'CruiseControlSetSpeed',
                                        'DistanceLtd',
                                        'EngineCoolantTemperature',
                                        'EngineLoad',
                                        'EngineOilPressure',
                                        'EngineOilTemperature',
                                        'EngineRpm',
                                        'EngineTimeLtd',
                                        'FuelLevel',
                                        'FuelLtd',
                                        'FuelRate',
                                        'FuelTemperature',
                                        'IntakeManifoldTemperature',
                                        'Speed',
                                        'Throttle',
                                        'active',
                                        'TurboBoostPressure',
                                        'activeTransitionCount',
                                        'CruiseControlActive',
                                        'IgnStatus',
                                        'ParkingBrake',
                                        'SwitchedBatteryVoltage'
                                        ]),
        ('target_encoder', TargetEncoder(handle_unknown='ignore'), [   'ecuSoftwareVersion',
                                                                        'ecuSerialNumber',
                                                                        'ecuModel',
                                                                        'ecuMake',
                                                                        'spn_fmi',
                                                                        'ecuSource',
                                                                        'LampStatus'
                                                                    ]) #,
      # ('ordinal_encoder', OrdinalEncoder(handle_unknown='ignore'), [   'ecuSource',
       #                                                                         'LampStatus'
        #                                                                ])
    ],
    remainder='passthrough'
)

xgbc_pipe = Pipeline(
    steps=[
        ('preprocessor', ct),
        ('xgbc', XGBClassifier(
                    eval_metric='mlogloss'
                            )
        )
    ]
).fit(X_train, y_train) 

y_pred = xgbc_pipe.predict(X_test)

# %% [markdown]
# ('xgbc', XGBClassifier(learning_rate = 0.05,
#                     colsample_bytree = 0.8,
#                     gamma = 0.1,
#                     max_depth = 5,
#                     min_child_weight = 1,
#                     reg_alpha = 0.01,
#                     n_estimators = 199,
#                     subsample = 0.6,
#                     eval_metric='mlogloss'
#                             )

# %% [markdown]
#         ('xgbc', XGBClassifier(learning_rate = 0.05,
#                     colsample_bytree = 0.8,
#                     gamma = 0.1,
#                     max_depth = 4,
#                     min_child_weight = 3,
#                     reg_alpha = 0.01,
#                     n_estimators = 190,
#                     subsample = 0.6,
#                     eval_metric='mlogloss'
#                             )

# %%
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {root_mean_squared_error(y_test, y_pred)}')
print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MAPE: {mean_absolute_percentage_error(y_test, y_pred)}')
print(f'R2: {r2_score(y_test, y_pred)}')
# Out:
# MSE: 0.0010570824524312897
# RMSE: 0.03251280443811776
# MAE: 0.0010570824524312897
# MAPE: 0.0010570824524312897
# R2: 0.7996187248464307

# %% [markdown]
# xgb = XGBClassifier(
#                     eval_metric='mlogloss'
#
#                     ).fit(X_train, y_train)

# %%
le_y
# Out:
# LabelEncoder()

# %%
y_fitted
# Out:
# LabelEncoder()

# %%
y_encoded
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(945558,))

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 945553    0
# 945554    0
# 945555    0
# 945556    0
# 945557    0
# Name: time_interval_to_SPN5246_class, Length: 945558, dtype: object

# %%
stop here
# Out:
#   Cell In[26], line 1
#     stop here
#          ^
# SyntaxError: invalid syntax

# %%
#RandomizedSearchCV

param_dist = {
    'max_depth': range(1, 10, 1),
    'min_child_weight':range(1, 6, 1),
    'learning_rate': stats.uniform(0.01, 0.1),
    'subsample':[i/10.0 for i in range(1, 10)],
    'colsample_bytree':[i/10.0 for i in range(1, 10)],
    'n_estimators':stats.randint(1, 70),
    'gamma':[i/10.0 for i in range(0, 5)],
   # 'reg_alpha':[1e-5, 1e-2, 0.1, 1, 100],
    'reg_alpha':[0, 0.001, 0.005, 0.01, 0.05]
    
}



# xgb_model = XGBClassifier()

# Create the RandomizedSearchCV object
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=10, random_state=343)
random_search = RandomizedSearchCV(xgbc_pipe[1], param_distributions=param_dist, n_iter=20, cv=cv, scoring='accuracy', verbose=2, n_jobs=-1, random_state=321)

# Fit the RandomizedSearchCV object to the training data
random_search.fit(X_train, y_train)

# Print the best set of hyperparameters and the corresponding score
print("Best set of hyperparameters: ", random_search.best_params_)
print("Best score: ", random_search.best_score_)
# Out:
# Fitting 100 folds for each of 20 candidates, totalling 2000 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 25
#      22 random_search = RandomizedSearchCV(xgbc_pipe[1], param_distributions=param_dist, n_iter=20, cv=cv, scoring='accuracy', verbose=2, n_jobs=-1, random_state=321)
#      24 # Fit the RandomizedSearchCV object to the training data
# ---> 25 random_search.fit(X_train, y_train)
#      27 # Print the best set of hyperparameters and the corresponding score
#      28 print("Best set of hyperparameters: ", random_search.best_params_)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1951, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1949 def _run_search(self, evaluate_candidates):
#    1950     """Search n_iter candidates from param_distributions"""
# -> 1951     evaluate_candidates(
#    1952         ParameterSampler(
#    1953             self.param_distributions, self.n_iter, random_state=self.random_state
#    1954         )
#    1955     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
stop_here

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9989429175475687

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[944,   0,   0],
#        [  1,   0,   0],
#        [  0,   0,   1]])

# %%
print(classification_report(y_test, y_pred, zero_division = 0))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       944
#            1       0.00      0.00      0.00         1
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       946
#    macro avg       0.67      0.67      0.67       946
# weighted avg       1.00      1.00      1.00       946

# %% [markdown]
# scores = cross_val_score(xgbc_pipe, X_test, y_test, cv=10, scoring='precision_macro')

# %% [markdown]
# print('Cross Validation Accuracy Scores:', scores)

# %% [markdown]
# ### Top Features' Importance

# %%
selection = SelectFromModel(xgbc_pipe[1], threshold=0.01, prefit=True)

# %%
X_selected = selection.transform(X_train)
X_selected
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# array([[254518, 'unknown', 'unknown', ..., nan, nan, '723.0_2.0'],
#        [5769, '04993120*00021657*082113134117*07700053*I0*BBZ*',
#         '79466573', ..., nan, 12.76, '111.0_17.0'],
#        [392576, 'unknown', 'unknown', ..., 100.0, 1.45, '929.0_9.0'],
#        ...,
#        [442595, '05317106*05031149*050815201656*09400035*G1*BDR*',
#         '79857689', ..., nan, nan, '111.0_17.0'],
#        [723091, nan, 'nan', ..., 100.0, 15.37, '96.0_3.0'],
#        [645361, nan, 'nan', ..., 0.0, 7.54, '929.0_9.0']],
#       shape=(944612, 32), dtype=object)

# %%
plot_importance_object = plot_importance(xgbc_pipe[1], importance_type='gain')
plt.title('Feature Importance for Full Derate Prediction')
plt.show()

# %%
feature_importances = xgbc_pipe[1].feature_importances_

feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importances})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

top_30_features = feature_importance_df.head(30)

print(top_30_features)
# Out:
#                       Feature  Importance
# 28     SwitchedBatteryVoltage    0.219535
# 30         TurboBoostPressure    0.068036
# 24  IntakeManifoldTemperature    0.067950
# 25                 LampStatus    0.051005
# 23                  IgnStatus    0.041820
# 13   EngineCoolantTemperature    0.039274
# 29                   Throttle    0.032330
# 31                    spn_fmi    0.027891
# 26               ParkingBrake    0.027244
# 2             ecuSerialNumber    0.026744
# 16       EngineOilTemperature    0.024260
# 19                  FuelLevel    0.023113
# 6                      active    0.023051
# 11      CruiseControlSetSpeed    0.022094
# 20                    FuelLtd    0.021878
# 3                    ecuModel    0.020943
# 9          BarometricPressure    0.019579
# 7       activeTransitionCount    0.019499
# 22            FuelTemperature    0.019088
# 8            AcceleratorPedal    0.019069
# 5                   ecuSource    0.017091
# 1          ecuSoftwareVersion    0.016808
# 10        CruiseControlActive    0.016678
# 27                      Speed    0.016306
# 4                     ecuMake    0.016259
# 17                  EngineRpm    0.016108
# 18              EngineTimeLtd    0.015471
# 12                DistanceLtd    0.015418
# 15          EngineOilPressure    0.015343
# 14                 EngineLoad    0.014880

# %%
print("Top 30 features:", top_30_features['Feature'].tolist())
# Out:
# Top 30 features: ['SwitchedBatteryVoltage', 'TurboBoostPressure', 'IntakeManifoldTemperature', 'LampStatus', 'IgnStatus', 'EngineCoolantTemperature', 'Throttle', 'spn_fmi', 'ParkingBrake', 'ecuSerialNumber', 'EngineOilTemperature', 'FuelLevel', 'active', 'CruiseControlSetSpeed', 'FuelLtd', 'ecuModel', 'BarometricPressure', 'activeTransitionCount', 'FuelTemperature', 'AcceleratorPedal', 'ecuSource', 'ecuSoftwareVersion', 'CruiseControlActive', 'Speed', 'ecuMake', 'EngineRpm', 'EngineTimeLtd', 'DistanceLtd', 'EngineOilPressure', 'EngineLoad']

# %% [markdown]
# ### Import fresh test data (previously held out) for a fresh round of testing

# %%
test = pd.read_csv('../data/Test_In2019_TimeIntervalLabeled_PerTruck.csv')

# %%
FreshTest_In2019 = test
FreshTest_In2019
# Out:
#         Unnamed: 0.1  Unnamed: 0  RecordID    ESS_Id       EventTimeStamp  \
# 0             948793     1062090   1104925  73930906  2019-01-11 12:51:18
# 1             948794     1062091   1104926  73930907  2019-01-11 12:51:18
# 2             948799     1062096   1104931  73934247  2019-01-11 13:11:40
# 3             948800     1062097   1104932  73934248  2019-01-11 13:11:40
# 4             948826     1062135   1104970  73942005  2019-01-11 13:13:38
# ...              ...         ...       ...       ...                  ...
# 111707        973069     1089938   1137548  80503703  2019-03-16 11:22:32
# 111708        973093     1089962   1137572  80509396  2019-03-16 11:24:04
# 111709        973094     1089963   1137573  80509397  2019-03-16 11:27:41
# 111710        974430     1091502   1139112  80907838  2019-03-20 10:57:34
# 111711        974828     1091973   1139583  81025027  2019-03-21 10:05:14
#
#                                          eventDescription  actionDescription  \
# 0                               High Voltage (Fuel Level)                NaN
# 1                   High Voltage (Left Fuel Level Sensor)                NaN
# 2                               High Voltage (Fuel Level)                NaN
# 3                   High Voltage (Left Fuel Level Sensor)                NaN
# 4                               High Voltage (Fuel Level)                NaN
# ...                                                   ...                ...
# 111707  Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# 111708  Special Instructions Engine Starter Solenoid L...                NaN
# 111709                                                NaN                NaN
# 111710  Special Instructions Engine Starter Solenoid L...                NaN
# 111711                                                NaN                NaN
#
#                                        ecuSoftwareVersion ecuSerialNumber  \
# 0                                                 unknown         unknown
# 1                                                 unknown         unknown
# 2                                                 unknown         unknown
# 3                                                 unknown         unknown
# 4                                                 unknown         unknown
# ...                                                   ...             ...
# 111707  AAAI000051*AAAM010056*Z091290   *A82J170202A_b...      6232171647
# 111708                                5569997 *E250.e003*        K1243673
# 111709                                5569997 *E250.e003*        K1243673
# 111710                                                NaN        K1243673
# 111711                                5569997 *E250.e003*        K1243673
#
#                ecuModel  ...     Speed  SwitchedBatteryVoltage  Throttle  \
# 0               unknown  ...  46.52031                     NaN      34.4
# 1               unknown  ...  46.52031                     NaN      34.4
# 2               unknown  ...       NaN                     NaN       NaN
# 3               unknown  ...       NaN                     NaN       NaN
# 4               unknown  ...   0.00000                     NaN       0.0
# ...                 ...  ...       ...                     ...       ...
# 111707          EC80ESP  ...       NaN                     NaN       NaN
# 111708  FAOM-xx810S-EC3  ...   0.00000                     NaN     100.0
# 111709  FAOM-xx810S-EC3  ...   0.00000                     NaN     100.0
# 111710  FAOM-xx810S-EC3  ...       NaN                     NaN       NaN
# 111711  FAOM-xx810S-EC3  ...       NaN                     NaN       NaN
#
#         TurboBoostPressure        spn_fmi  is_fullderate  is_fullderate_group  \
# 0                    13.05       96.0_3.0              0                    1
# 1                    13.05      829.0_3.0              0                    1
# 2                      NaN       96.0_3.0              0                    1
# 3                      NaN      829.0_3.0              0                    1
# 4                     1.16       96.0_3.0              0                    1
# ...                    ...            ...            ...                  ...
# 111707                 NaN      639.0_2.0              0                    0
# 111708                0.29    1321.0_14.0              0                    0
# 111709                0.29  520321.0_13.0              0                    0
# 111710                 NaN    1321.0_14.0              0                    0
# 111711                 NaN  520321.0_13.0              0                    0
#
#         EquipID_Index  time_to_next_SPN5246  time_interval_to_SPN5246_class
# 0               301_1           239999976.0                               0
# 1               301_1           239999976.0                               0
# 2               301_1           239999976.0                               0
# 3               301_1           239999976.0                               0
# 4               301_1           239999976.0                               0
# ...               ...                   ...                             ...
# 111707    105437340_0           239999976.0                               0
# 111708    105437340_0           239999976.0                               0
# 111709    105437340_0           239999976.0                               0
# 111710    105437340_0           239999976.0                               0
# 111711    105437340_0           239999976.0                               0
#
# [111712 rows x 53 columns]

# %%
FreshTest_In2019[['ecuSource', 'LampStatus', 'time_interval_to_SPN5246_class']] = FreshTest_In2019[['ecuSource', 'LampStatus', 'time_interval_to_SPN5246_class']].astype('str')

# %%
X_fresh_test = FreshTest_In2019.drop(columns = [    'Unnamed: 0',
                                                    'RecordID',
                                                    'ESS_Id',
                                                    'actionDescription',
                                                    'spn',
                                                    'fmi',
                                                    'faultValue',
                                                    'MCTNumber',
                                                    'Latitude',
                                                    'Longitude',
                                                    'is_fullderate',
                                                    'is_fullderate_group',
                                                    'time_to_next_SPN5246',
                                                    'ServiceDistance',
                                                    'EventTimeStamp',
                                                    'eventDescription',
                                                    'EquipmentID',
                                                    'LocationTimeStamp',
                                                    'EquipID_Index',
                                                    'time_interval_to_SPN5246_class',
                                                    'MCTNumber',                                  
                                                    'FaultId'                                                        
                                                ]
                                     )  
X_fresh_test
# Out:
#         Unnamed: 0.1                                 ecuSoftwareVersion  \
# 0             948793                                            unknown
# 1             948794                                            unknown
# 2             948799                                            unknown
# 3             948800                                            unknown
# 4             948826                                            unknown
# ...              ...                                                ...
# 111707        973069  AAAI000051*AAAM010056*Z091290   *A82J170202A_b...
# 111708        973093                                5569997 *E250.e003*
# 111709        973094                                5569997 *E250.e003*
# 111710        974430                                                NaN
# 111711        974828                                5569997 *E250.e003*
#
#        ecuSerialNumber         ecuModel  ecuMake ecuSource  active  \
# 0              unknown          unknown  unknown        49    True
# 1              unknown          unknown  unknown        49    True
# 2              unknown          unknown  unknown        49   False
# 3              unknown          unknown  unknown        49   False
# 4              unknown          unknown  unknown        49    True
# ...                ...              ...      ...       ...     ...
# 111707      6232171647          EC80ESP    BNDWS        11   False
# 111708        K1243673  FAOM-xx810S-EC3    EATON         3    True
# 111709        K1243673  FAOM-xx810S-EC3    EATON         3    True
# 111710        K1243673  FAOM-xx810S-EC3    EATON         3   False
# 111711        K1243673  FAOM-xx810S-EC3    EATON         3   False
#
#         activeTransitionCount  AcceleratorPedal  BarometricPressure  ...  \
# 0                         126              34.0                14.5  ...
# 1                         126              34.0                14.5  ...
# 2                         126               NaN                 NaN  ...
# 3                         126               NaN                 NaN  ...
# 4                         126               0.0                14.5  ...
# ...                       ...               ...                 ...  ...
# 111707                    127               NaN                 NaN  ...
# 111708                      1               0.0                14.5  ...
# 111709                      4               0.0                14.5  ...
# 111710                      5               NaN                 NaN  ...
# 111711                     12               NaN                 NaN  ...
#
#        FuelTemperature  IgnStatus  IntakeManifoldTemperature  LampStatus  \
# 0                 71.6       True                       84.2      1279.0
# 1                 71.6       True                       84.2      1279.0
# 2                  NaN        NaN                        NaN       255.0
# 3                  NaN        NaN                        NaN       255.0
# 4                 87.8       True                      107.6      1279.0
# ...                ...        ...                        ...         ...
# 111707             NaN        NaN                        NaN     50175.0
# 111708             NaN       True                       68.0     63487.0
# 111709             NaN       True                       73.4     63487.0
# 111710             NaN        NaN                        NaN     63487.0
# 111711             NaN        NaN                        NaN       255.0
#
#         ParkingBrake     Speed  SwitchedBatteryVoltage  Throttle  \
# 0              False  46.52031                     NaN      34.4
# 1              False  46.52031                     NaN      34.4
# 2                NaN       NaN                     NaN       NaN
# 3                NaN       NaN                     NaN       NaN
# 4               True   0.00000                     NaN       0.0
# ...              ...       ...                     ...       ...
# 111707           NaN       NaN                     NaN       NaN
# 111708          True   0.00000                     NaN     100.0
# 111709          True   0.00000                     NaN     100.0
# 111710           NaN       NaN                     NaN       NaN
# 111711           NaN       NaN                     NaN       NaN
#
#         TurboBoostPressure        spn_fmi
# 0                    13.05       96.0_3.0
# 1                    13.05      829.0_3.0
# 2                      NaN       96.0_3.0
# 3                      NaN      829.0_3.0
# 4                     1.16       96.0_3.0
# ...                    ...            ...
# 111707                 NaN      639.0_2.0
# 111708                0.29    1321.0_14.0
# 111709                0.29  520321.0_13.0
# 111710                 NaN    1321.0_14.0
# 111711                 NaN  520321.0_13.0
#
# [111712 rows x 32 columns]

# %%
X_fresh_test.shape
# Out:
# (111712, 32)

# %% [markdown]
# X_FreshTest_Transformed = ct.transform(X_fresh_test)
# X_FreshTest_Transformed

# %%
y_fresh_pred = xgbc_pipe.predict(X_fresh_test)

# %%
y_fresh_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(111712,))

# %%
y_fresh_test = FreshTest_In2019['time_interval_to_SPN5246_class']

# %%
y_fresh_test_encoded = le_y.transform(y_fresh_test)

# %%
accuracy_score(y_fresh_test_encoded, y_fresh_pred)
# Out:
# 0.9916660698940132

# %%
confusion_matrix(y_fresh_test_encoded, y_fresh_pred)
# Out:
# array([[110757,      0,    637],
#        [   148,      0,      7],
#        [   139,      0,     24]])

# %%
print(classification_report(y_fresh_test_encoded, y_fresh_pred, zero_division = 0))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    111394
#            1       0.00      0.00      0.00       155
#            2       0.04      0.15      0.06       163
#
#     accuracy                           0.99    111712
#    macro avg       0.34      0.38      0.35    111712
# weighted avg       0.99      0.99      0.99    111712

# %%
print(f'MSE: {mean_squared_error(y_fresh_test_encoded, y_fresh_pred)}')
print(f'RMSE: {root_mean_squared_error(y_fresh_test_encoded, y_fresh_pred)}')
print(f'MAE: {mean_absolute_error(y_fresh_test_encoded, y_fresh_pred)}')
print(f'MAPE: {mean_absolute_percentage_error(y_fresh_test_encoded, y_fresh_pred)}')
print(f'R2: {r2_score(y_fresh_test_encoded, y_fresh_pred)}')
# Out:
# MSE: 0.029173231165855056
# RMSE: 0.1708017305704338
# MAE: 0.015280363792609568
# MAPE: 51360515658747.6
# R2: -3.0488045497840917

# %%
fresh_CV_scores = cross_val_score(xgbc_pipe, X_fresh_test, y_fresh_test_encoded, cv=10, scoring='precision_macro')

# %%
print('Cross Validation Accuracy Scores:', fresh_CV_scores)
# Out:
# Cross Validation Accuracy Scores: [0.33820684 0.3437605  0.35651069 0.45468937 0.34392096 0.34197963
#  0.37337755 0.39182955 0.43294765 0.54086036]

# %%
# submission.to_csv('../data/submission_XGBClassifier_TunedHyperparameter_TargetEncoder_LearningRatePt05_MaxTreeDepth5_MinChild1_Estimators199_TestSizePt001_MostFeatures_ExcludingMapCode.csv', index = False)
