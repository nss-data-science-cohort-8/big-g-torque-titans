# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier, MLPRegressor

from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, OrdinalEncoder
# from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline 
from sklearn.compose import ColumnTransformer

from sklearn.metrics import (
        classification_report, confusion_matrix, r2_score, mean_squared_error, root_mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score, f1_score, roc_auc_score, roc_curve, precision_recall_curve
)

from sklearn.inspection import PartialDependenceDisplay

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV, RepeatedStratifiedKFold
from xgboost import XGBClassifier, XGBRegressor, plot_importance
from sklearn.model_selection import cross_val_score

# %%
from category_encoders import TargetEncoder 
from sklearn.feature_selection import SelectFromModel

# %%
# from sklearn.datasets import make_classification

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
from feature_engine.imputation import CategoricalImputer
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor

# %%
from xgbimputer import XGBImputer

# %%
TrainPre2019 = pd.read_csv('../data/Pre2019_df_Cat9999999.csv')
# Out:
# /var/folders/nl/hqcw9pqd0ns4q0b61syv0q2m0000gn/T/ipykernel_32157/2282598049.py:1: DtypeWarning: Columns (17,41,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   TrainPre2019 = pd.read_csv('../data/Pre2019_df_Cat9999999.csv')

# %%
TrainPre2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 949528 entries, 0 to 949527
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0.1                    949528 non-null  int64
#  1   Unnamed: 0                      949528 non-null  int64
#  2   RecordID                        949528 non-null  int64
#  3   ESS_Id                          949528 non-null  int64
#  4   EventTimeStamp                  949528 non-null  object
#  5   eventDescription                902364 non-null  object
#  6   actionDescription               0 non-null       float64
#  7   ecuSoftwareVersion              747330 non-null  object
#  8   ecuSerialNumber                 707932 non-null  object
#  9   ecuModel                        900949 non-null  object
#  10  ecuMake                         900949 non-null  object
#  11  ecuSource                       949528 non-null  int64
#  12  spn                             949528 non-null  float64
#  13  fmi                             949528 non-null  float64
#  14  active                          949528 non-null  bool
#  15  activeTransitionCount           949528 non-null  int64
#  16  faultValue                      0 non-null       float64
#  17  EquipmentID                     949528 non-null  object
#  18  MCTNumber                       949528 non-null  int64
#  19  Latitude                        949528 non-null  float64
#  20  Longitude                       949528 non-null  float64
#  21  LocationTimeStamp               949528 non-null  object
#  22  FaultId                         949528 non-null  int64
#  23  AcceleratorPedal                426247 non-null  float64
#  24  BarometricPressure              476659 non-null  float64
#  25  CruiseControlActive             466508 non-null  object
#  26  CruiseControlSetSpeed           467458 non-null  float64
#  27  DistanceLtd                     476568 non-null  float64
#  28  EngineCoolantTemperature        476625 non-null  float64
#  29  EngineLoad                      476168 non-null  float64
#  30  EngineOilPressure               476735 non-null  float64
#  31  EngineOilTemperature            475236 non-null  float64
#  32  EngineRpm                       476956 non-null  float64
#  33  EngineTimeLtd                   472796 non-null  float64
#  34  FuelLevel                       402392 non-null  float64
#  35  FuelLtd                         476017 non-null  float64
#  36  FuelRate                        475932 non-null  float64
#  37  FuelTemperature                 248414 non-null  float64
#  38  IgnStatus                       494185 non-null  object
#  39  IntakeManifoldTemperature       476730 non-null  float64
#  40  LampStatus                      949528 non-null  float64
#  41  ParkingBrake                    303591 non-null  object
#  42  ServiceDistance                 200 non-null     float64
#  43  Speed                           475134 non-null  float64
#  44  SwitchedBatteryVoltage          102624 non-null  object
#  45  Throttle                        320557 non-null  float64
#  46  TurboBoostPressure              474652 non-null  float64
#  47  spn_fmi                         949528 non-null  object
#  48  is_fullderate                   949528 non-null  int64
#  49  is_fullderate_group             949528 non-null  int64
#  50  EquipID_Index                   949528 non-null  object
#  51  time_to_next_SPN5246            949528 non-null  float64
#  52  time_interval_to_SPN5246_class  949528 non-null  int64
# dtypes: bool(1), float64(27), int64(11), object(14)
# memory usage: 377.6+ MB

# %% [markdown]
# **Goal:** Predict the rank based on the total shots.

# %%
TrainPre2019['time_interval_to_SPN5246_class'].value_counts()
# Out:
# time_interval_to_SPN5246_class
# 9999999    715686
# 0          229509
# 1            2233
# 2            1263
# 3             837
# Name: count, dtype: int64

# %%
TrainPre2019
# Out:
#         Unnamed: 0.1  Unnamed: 0  RecordID   ESS_Id       EventTimeStamp  \
# 0              43931       48303     49415  2363162  2015-05-11 13:11:20
# 1              45693       50251     51363  2400445  2015-05-13 08:22:32
# 2              50271       55260     57330  2482983  2015-05-18 09:34:05
# 3              54326       59636     61706  2554027  2015-05-21 13:57:35
# 4              54418       59731     61801  2555325  2015-05-21 14:54:32
# ...              ...         ...       ...      ...                  ...
# 949523          4036        4494      4495  1052146  2015-02-24 16:24:05
# 949524          5907        6438      6439  1089561  2015-02-26 13:12:11
# 949525          5915        6446      6447  1090499  2015-02-26 13:50:59
# 949526          4472        4952      4953  1059704  2015-02-25 06:08:43
# 949527          4512        4999      5000  1060204  2015-02-25 06:38:40
#
#                                          eventDescription  actionDescription  \
# 0       Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# 1           Condition Exists Cruise Control Enable Switch                NaN
# 2       Abnormal Rate of Change Aftertreatment 1 Outle...                NaN
# 3       Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# 4       Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# ...                                                   ...                ...
# 949523          Low (Severity Medium) Catalyst Tank Level                NaN
# 949524                                                NaN                NaN
# 949525                                                NaN                NaN
# 949526  Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# 949527  Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
#
#                                      ecuSoftwareVersion ecuSerialNumber  \
# 0                                               unknown         unknown
# 1                                               unknown         unknown
# 2                                       PC4__1284P4C_2*         6U13D13
# 3                                               unknown         unknown
# 4                                               unknown         unknown
# ...                                                 ...             ...
# 949523  05317106*04119044*051914190353*09400015*G1*BDR*        79751302
# 949524  05317106*04119044*051914190353*09400015*G1*BDR*        79751302
# 949525  05317106*04119044*051914190353*09400015*G1*BDR*        79751302
# 949526                                          unknown         unknown
# 949527                                          unknown         unknown
#
#                  ecuModel  ...      Speed  SwitchedBatteryVoltage  Throttle  \
# 0                 unknown  ...   4.475814                 3276.75      14.4
# 1                 unknown  ...  64.637170                 3276.75      89.6
# 2                      MX  ...  63.525490                 3276.75       0.0
# 3                 unknown  ...   4.364162                 3276.75      12.0
# 4                 unknown  ...        NaN                     NaN       NaN
# ...                   ...  ...        ...                     ...       ...
# 949523  6X1u13D1500000000  ...        NaN                     NaN       NaN
# 949524  6X1u13D1500000000  ...   2.058292                 3276.75       0.0
# 949525  6X1u13D1500000000  ...        NaN                     NaN       NaN
# 949526            unknown  ...   4.378725                 3276.75       0.0
# 949527            unknown  ...        NaN                     NaN       NaN
#
#         TurboBoostPressure      spn_fmi  is_fullderate  is_fullderate_group  \
# 0                     0.58    639.0_2.0              0                    0
# 1                     4.64   596.0_31.0              0                    0
# 2                    20.30  3226.0_10.0              0                    0
# 3                     1.45    639.0_2.0              0                    0
# 4                      NaN    639.0_2.0              0                    0
# ...                    ...          ...            ...                  ...
# 949523                 NaN  1761.0_18.0              0                    0
# 949524                0.29   5848.0_9.0              0                    0
# 949525                 NaN   5848.0_9.0              0                    0
# 949526                1.74    639.0_2.0              0                    0
# 949527                 NaN    639.0_2.0              0                    0
#
#        EquipID_Index  time_to_next_SPN5246  time_interval_to_SPN5246_class
# 0              301_0          1.027800e+04                               0
# 1              301_0          1.023481e+04                               0
# 2              301_0          1.011362e+04                               0
# 3              301_0          1.003723e+04                               0
# 4              301_0          1.003628e+04                               0
# ...              ...                   ...                             ...
# 949523       R1762_0          2.400000e+08                         9999999
# 949524       R1762_0          2.400000e+08                         9999999
# 949525       R1762_0          2.400000e+08                         9999999
# 949526       R1764_0          2.400000e+08                         9999999
# 949527       R1764_0          2.400000e+08                         9999999
#
# [949528 rows x 53 columns]

# %% [markdown]
# class MultiColumnLabelEncoder:
#     def __init__(self,columns = None):
#         self.columns = columns # array of column names to encode
#
#     def fit(self,X,y=None):
#         return self # not relevant here
#
#     def transform(self,X):
#         '''
#         Transforms columns of X specified in self.columns using
#         LabelEncoder(). If no columns specified, transforms all
#         columns in X.
#         '''
#         output = X.copy()
#         if self.columns is not None:
#             for col in self.columns:
#                 output[col] = OneHotEncoder().fit_transform(output[col])
#         else:
#             for colname,col in output.iteritems():
#                 output[colname] = OneHotEncoder().fit_transform(col)
#         return output
#
#     def fit_transform(self,X,y=None):
#         return self.fit(X,y).transform(X)

# %%
TrainPre2019[['ecuSource', 'LampStatus', 'time_interval_to_SPN5246_class', 'ecuSerialNumber', 'ecuModel', 'ecuMake']] = TrainPre2019[['ecuSource', 'LampStatus', 'time_interval_to_SPN5246_class', 'ecuSerialNumber', 'ecuModel', 'ecuMake']].astype('category')

# %%
TrainPre2019[['activeTransitionCount']] = TrainPre2019[['activeTransitionCount']].astype('category')

# %%
TrainPre2019.replace(to_replace='3276,75', value='3278.75', inplace=True)

# %%
TrainPre2019[[  'AcceleratorPedal',
                    'BarometricPressure',
                    'CruiseControlSetSpeed',
                    'DistanceLtd',
                    'EngineCoolantTemperature',
                    'EngineLoad',
                    'EngineOilPressure',
                    'EngineOilTemperature',
                    'EngineRpm',
                    'EngineTimeLtd',
                    'FuelLevel',
                    'FuelLtd',
                    'FuelRate',
                    'FuelTemperature',
                    'IntakeManifoldTemperature',
                    'Speed',
                    'Throttle',
                    'active',
                    'TurboBoostPressure',
                    'CruiseControlActive',
                    'IgnStatus',
                    'ParkingBrake',
                    'SwitchedBatteryVoltage'
]] = TrainPre2019[[                         'AcceleratorPedal',
                                            'BarometricPressure',
                                            'CruiseControlSetSpeed',
                                            'DistanceLtd',
                                            'EngineCoolantTemperature',
                                            'EngineLoad',
                                            'EngineOilPressure',
                                            'EngineOilTemperature',
                                            'EngineRpm',
                                            'EngineTimeLtd',
                                            'FuelLevel',
                                            'FuelLtd',
                                            'FuelRate',
                                            'FuelTemperature',
                                            'IntakeManifoldTemperature',
                                            'Speed',
                                            'Throttle',
                                            'active',
                                            'TurboBoostPressure',
                                            'CruiseControlActive',
                                            'IgnStatus',
                                            'ParkingBrake',
                                            'SwitchedBatteryVoltage'
                     ]].astype('float64')

# %%
NumericColumns = TrainPre2019.select_dtypes(include=[np.number]).columns.tolist()
NumericColumns_Without_MatchID = NumericColumns.pop(0)
NumericColumns
# Out:
# ['Unnamed: 0',
#  'RecordID',
#  'ESS_Id',
#  'actionDescription',
#  'spn',
#  'fmi',
#  'active',
#  'faultValue',
#  'MCTNumber',
#  'Latitude',
#  'Longitude',
#  'FaultId',
#  'AcceleratorPedal',
#  'BarometricPressure',
#  'CruiseControlActive',
#  'CruiseControlSetSpeed',
#  'DistanceLtd',
#  'EngineCoolantTemperature',
#  'EngineLoad',
#  'EngineOilPressure',
#  'EngineOilTemperature',
#  'EngineRpm',
#  'EngineTimeLtd',
#  'FuelLevel',
#  'FuelLtd',
#  'FuelRate',
#  'FuelTemperature',
#  'IgnStatus',
#  'IntakeManifoldTemperature',
#  'ParkingBrake',
#  'ServiceDistance',
#  'Speed',
#  'SwitchedBatteryVoltage',
#  'Throttle',
#  'TurboBoostPressure',
#  'is_fullderate',
#  'is_fullderate_group',
#  'time_to_next_SPN5246']

# %% [markdown]
# Among numeric columns, will keep:
#
#
# ['AcceleratorPedal',
# 'BarometricPressure',
# 'CruiseControlSetSpeed',
# 'DistanceLtd',
# 'EngineCoolantTemperature',
# 'EngineLoad',
# 'EngineOilPressure',
# 'EngineOilTemperature',
# 'EngineRpm',
# 'EngineTimeLtd',
# 'FuelLevel',
# 'FuelLtd',
# 'FuelRate',
# 'FuelTemperature',
# 'IntakeManifoldTemperature',
# 'Speed',
# 'Throttle',
# 'active',
# 'TurboBoostPressure',
# 'activeTransitionCount',
# 'CruiseControlActive',
# 'IgnStatus',
# 'ParkingBrake',
# 'SwitchedBatteryVoltage']

# %%
NonNumericColumns = TrainPre2019.select_dtypes(exclude=[np.number]).columns.tolist()
NonNumericColumns
# Out:
# ['EventTimeStamp',
#  'eventDescription',
#  'ecuSoftwareVersion',
#  'ecuSerialNumber',
#  'ecuModel',
#  'ecuMake',
#  'ecuSource',
#  'activeTransitionCount',
#  'EquipmentID',
#  'LocationTimeStamp',
#  'LampStatus',
#  'spn_fmi',
#  'EquipID_Index',
#  'time_interval_to_SPN5246_class']

# %% [markdown]
# Among, non-numeric columns, will keep:
#
#         ('target_encoder', TargetEncoder(handle_unknown='ignore'), [   'ecuSoftwareVersion',
#                                                                         'ecuSerialNumber',
#                                                                         'ecuModel',
#                                                                         'ecuMake',
#                                                                         'spn_fmi'
#                                                                     ]),
#         ('ordinal_encoder', OrdinalEncoder(handle_unknown='ignore'), [   'ecuSource',
#                                                                                 'LampStatus'
#                                                                         ])

# %%
X = TrainPre2019.drop(columns = [   'Unnamed: 0',
                                    'Unnamed: 0.1',
                                    'RecordID',
                                    'ESS_Id',
                                    'actionDescription',
                                    'spn',
                                    'fmi',
                                    'faultValue',
                                    'MCTNumber',
                                    'Latitude',
                                    'Longitude',
                                    'is_fullderate',
                                    'is_fullderate_group',
                                    'time_to_next_SPN5246',
                                    'ServiceDistance',
                                    'EventTimeStamp',
                                    'eventDescription',
                                    'EquipmentID',
                                    'LocationTimeStamp',
                                    'EquipID_Index',
                                    'time_interval_to_SPN5246_class',
                                    'MCTNumber',                                  
                                    'FaultId',
                                    'ecuSoftwareVersion',
                                    'ecuSerialNumber',
                                    'ecuModel',
                                    'ecuMake'                                                                                      
                                ]
                      )
y = TrainPre2019['time_interval_to_SPN5246_class']

# %%
X['spn_fmi'] = X['spn_fmi'].str.replace('.0', '')

# %%
X
# Out:
#        ecuSource  active activeTransitionCount  AcceleratorPedal  \
# 0             11     1.0                   127              14.4
# 1             49     1.0                     3              89.6
# 2              0     1.0                     6               0.0
# 3             11     1.0                   127              12.0
# 4             11     0.0                   127               NaN
# ...          ...     ...                   ...               ...
# 949523         0     0.0                    11               NaN
# 949524         0     1.0                     1               0.0
# 949525         0     0.0                     1               NaN
# 949526        11     1.0                   127              21.6
# 949527        11     0.0                   127               NaN
#
#         BarometricPressure  CruiseControlActive  CruiseControlSetSpeed  \
# 0                  13.9200                  0.0                0.00000
# 1                  14.4275                  0.0                0.00000
# 2                  14.3550                  0.0                0.00000
# 3                  14.5725                  0.0                0.00000
# 4                      NaN                  NaN                    NaN
# ...                    ...                  ...                    ...
# 949523                 NaN                  NaN                    NaN
# 949524             14.2100                  0.0               66.48672
# 949525                 NaN                  NaN                    NaN
# 949526             14.4275                  0.0               66.48672
# 949527                 NaN                  NaN                    NaN
#
#         DistanceLtd  EngineCoolantTemperature  EngineLoad  ...  \
# 0         120841.70                     185.0        18.0  ...
# 1         121687.10                     186.8        38.0  ...
# 2         123057.10                     185.0         0.0  ...
# 3         124496.50                     183.2        14.0  ...
# 4               NaN                       NaN         NaN  ...
# ...             ...                       ...         ...  ...
# 949523          NaN                       NaN         NaN  ...
# 949524     80838.70                     134.6        11.0  ...
# 949525          NaN                       NaN         NaN  ...
# 949526     83681.85                     154.4        12.0  ...
# 949527          NaN                       NaN         NaN  ...
#
#         FuelTemperature  IgnStatus  IntakeManifoldTemperature  LampStatus  \
# 0                 134.6        1.0                      154.4      1279.0
# 1                 100.4        1.0                      120.2      4351.0
# 2                 120.2        1.0                      118.4     17407.0
# 3                 109.4        1.0                      107.6      1279.0
# 4                   NaN        NaN                        NaN      1279.0
# ...                 ...        ...                        ...         ...
# 949523              NaN        NaN                        NaN      1023.0
# 949524             32.0        1.0                       84.2     17407.0
# 949525              NaN        NaN                        NaN      1023.0
# 949526             32.0        1.0                       93.2      1279.0
# 949527              NaN        NaN                        NaN      1279.0
#
#         ParkingBrake      Speed  SwitchedBatteryVoltage  Throttle  \
# 0                0.0   4.475814                 3276.75      14.4
# 1                0.0  64.637170                 3276.75      89.6
# 2                0.0  63.525490                 3276.75       0.0
# 3                0.0   4.364162                 3276.75      12.0
# 4                NaN        NaN                     NaN       NaN
# ...              ...        ...                     ...       ...
# 949523           NaN        NaN                     NaN       NaN
# 949524           0.0   2.058292                 3276.75       0.0
# 949525           NaN        NaN                     NaN       NaN
# 949526           0.0   4.378725                 3276.75       0.0
# 949527           NaN        NaN                     NaN       NaN
#
#         TurboBoostPressure  spn_fmi
# 0                     0.58    639_2
# 1                     4.64   596_31
# 2                    20.30  3226_10
# 3                     1.45    639_2
# 4                      NaN    639_2
# ...                    ...      ...
# 949523                 NaN  1761_18
# 949524                0.29   5848_9
# 949525                 NaN   5848_9
# 949526                1.74    639_2
# 949527                 NaN    639_2
#
# [949528 rows x 27 columns]

# %%
y
# Out:
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
#            ...
# 949523    9999999
# 949524    9999999
# 949525    9999999
# 949526    9999999
# 949527    9999999
# Name: time_interval_to_SPN5246_class, Length: 949528, dtype: category
# Categories (5, int64): [0, 1, 2, 3, 9999999]

# %%
X.describe()
# Out:
#               active  AcceleratorPedal  BarometricPressure  \
# count  949528.000000     426247.000000       476659.000000
# mean        0.520453         28.544902           14.191954
# std         0.499582         36.550423            1.195484
# min         0.000000          0.000000            3.045000
# 25%         0.000000          0.000000           14.210000
# 50%         1.000000          4.000000           14.355000
# 75%         1.000000         48.800000           14.500000
# max         1.000000        100.000000           15.225000
#
#        CruiseControlActive  CruiseControlSetSpeed    DistanceLtd  \
# count        466508.000000          467458.000000  476568.000000
# mean              0.096682              62.174458  364626.882789
# std               0.295525              12.239142  142701.441105
# min               0.000000               0.000000       0.000000
# 25%               0.000000              64.622600  267338.900000
# 50%               0.000000              66.486720  379825.250000
# 75%               0.000000              66.486720  481544.650000
# max               1.000000              69.593570  649549.000000
#
#        EngineCoolantTemperature     EngineLoad  EngineOilPressure  \
# count             476625.000000  476168.000000      476735.000000
# mean                 169.566761      31.959878          33.453187
# std                   32.811442      30.635726          11.282650
# min                   -7.600000       0.000000           0.000000
# 25%                  170.600000      11.000000          28.420000
# 50%                  183.200000      19.000000          36.540000
# 75%                  186.800000      48.000000          39.440000
# max                  406.400000     101.000000         145.000000
#
#        EngineOilTemperature  ...        FuelLtd       FuelRate  \
# count         475236.000000  ...  476017.000000  475932.000000
# mean             187.261404  ...   50560.896556       4.627839
# std               61.171250  ...   24171.307050       5.783522
# min              -39.156250  ...       0.000000       0.000000
# 25%              179.937500  ...   33494.638645       0.647223
# 50%              202.775000  ...   51938.602972       1.690706
# 75%              214.531300  ...   68751.040705       7.211920
# max             3212.544000  ...  312737.574126      25.611560
#
#        FuelTemperature      IgnStatus  IntakeManifoldTemperature  \
# count    248414.000000  494185.000000              476730.000000
# mean         37.043151       0.995724                 106.750817
# std          23.152840       0.065249                  25.476308
# min          17.600000       0.000000                 -40.000000
# 25%          32.000000       1.000000                  89.600000
# 50%          32.000000       1.000000                 109.400000
# 75%          32.000000       1.000000                 125.600000
# max         231.800000       1.000000                 264.200000
#
#         ParkingBrake          Speed  SwitchedBatteryVoltage       Throttle  \
# count  303591.000000  475134.000000           102624.000000  320557.000000
# mean        0.283948      26.293766             3104.761359      66.074916
# std         0.450913      28.208800              729.139651      46.345526
# min         0.000000       0.000000                7.650000       0.000000
# 25%         0.000000       0.000000             3276.750000       0.000000
# 50%         0.000000       9.699216             3276.750000     100.000000
# 75%         1.000000      59.933190             3276.750000     100.000000
# max         1.000000     158.447200             3278.750000     100.000000
#
#        TurboBoostPressure
# count       474652.000000
# mean             6.286150
# std              8.557188
# min              0.000000
# 25%              0.580000
# 50%              2.030000
# 75%              8.700000
# max             63.220000
#
# [8 rows x 23 columns]

# %%
X

le_y = LabelEncoder()

y_fitted = le_y.fit(y)
y_encoded = le_y.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size = 0.2, random_state = 321, shuffle=True, stratify = y_encoded)

# %% [markdown]
# # Apply SMOTE
# smote = SMOTE(random_state=3434)
# X_resampled, y_resampled = smote.fit_resample(X_train, y_train)    # might need another set of pipeline; alternatively, we can go with the following approach:

# %% [markdown]
#
#
#
# ct = ColumnTransformer(
#     transformers=[
#         ('scaler', StandardScaler(), [  'AcceleratorPedal',
#                                         'BarometricPressure',
#                                         'CruiseControlSetSpeed',
#                                         'DistanceLtd',
#                                         'EngineCoolantTemperature',
#                                         'EngineLoad',
#                                         'EngineOilPressure',
#                                         'EngineOilTemperature',
#                                         'EngineRpm',
#                                         'EngineTimeLtd',
#                                         'FuelLevel',
#                                         'FuelLtd',
#                                         'FuelRate',
#                                         'FuelTemperature',
#                                         'IntakeManifoldTemperature',
#                                         'Speed',
#                                         'Throttle',
#                                         'active',
#                                         'TurboBoostPressure',
#                                         'CruiseControlActive',
#                                         'IgnStatus',
#                                         'ParkingBrake',
#                                         'SwitchedBatteryVoltage'
#                                         ]),
#         ('target_encoder', TargetEncoder(handle_unknown='ignore'), [    'spn_fmi',
#                                                                         'ecuSource',
#                                                                         'LampStatus',
#                                                                         'activeTransitionCount'
#                                                                     ]) #,
#       # ('ordinal_encoder', OrdinalEncoder(handle_unknown='ignore'), [   'ecuSource',
#        #                                                                         'LampStatus'
#         #                                                                ])
#     ],
#     remainder='passthrough'
# )
#
# xgbc_pipe = Pipeline(
#     steps=[
#
#         ('imputer1', XGBImputer(categorical_features_index=[0, 2, -7, -1], replace_categorical_values_back=True, verbose=2)),
#     #    ('ct', ct),
#     #    ('imputer2', IterativeImputer(estimator = GradientBoostingRegressor(verbose=2, random_state=434), max_iter=10, random_state=343)),
#     #    ('smote', SMOTE(random_state=344)),
#         ('xgbc', XGBClassifier( enable_categorical=True,
#                                # booster='gbtree',
#                                 eval_metric='mlogloss',
#                                 objective = 'multi:softprob'
#                             )
#         )
#     ]
# ).fit(X_train, y_train)
#
# y_pred = xgbc_pipe.predict(X_test)

# %%
 

ct0 = ColumnTransformer(
        [('target_encoder', TargetEncoder(handle_unknown='ignore'), ['spn_fmi',
                                                                        'ecuSource',
                                                                        'LampStatus',
                                                                        'activeTransitionCount'
                                                                    ]
          )],
        remainder='passthrough')
        



xgbc_pipe = Pipeline(
    steps=[
        ('ct0', ct0),
        ('imputer1', XGBImputer(categorical_features_index=[0, 2, -7, -1], replace_categorical_values_back=True, verbose=2)),  # defaults to using OneHotEncoder for categorical variables
        ('StandardScaler', StandardScaler()),
        ('imputer2', IterativeImputer(estimator = HistGradientBoostingRegressor(verbose=2, random_state=434), max_iter=10, random_state=343)),
   #     ('smote', SMOTE(random_state=344)),
        ('xgbc', XGBClassifier(# tree_method = "hist",                                
                               enable_categorical=True, 
                                eval_metric='mlogloss',
                                objective = 'multi:softmax',
                                num_class = 5, 
                                random_state = 535                         
                            )
        ) 
    ]
).fit(X_train, y_train) 

y_pred = xgbc_pipe.predict(X_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgbimputer/xgbimputer.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   gamma_inferred_categorical_features_new = np.sum(Ximp[:,self.inferred_categorical_features_index] != Ximp_old[:,self.inferred_categorical_features_index])/self.inferred_categorical_features_index.size
# XGBImputer - Epoch: 1 | Categorical gamma: inf/nan | Numerical gamma: inf/0.0159559483
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgbimputer/xgbimputer.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   gamma_inferred_categorical_features_new = np.sum(Ximp[:,self.inferred_categorical_features_index] != Ximp_old[:,self.inferred_categorical_features_index])/self.inferred_categorical_features_index.size
# XGBImputer - Epoch: 2 | Categorical gamma: nan/nan | Numerical gamma: 0.0159559483/0.0036239566
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgbimputer/xgbimputer.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   gamma_inferred_categorical_features_new = np.sum(Ximp[:,self.inferred_categorical_features_index] != Ximp_old[:,self.inferred_categorical_features_index])/self.inferred_categorical_features_index.size
# XGBImputer - Epoch: 3 | Categorical gamma: nan/nan | Numerical gamma: 0.0036239566/0.0005564688
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgbimputer/xgbimputer.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   gamma_inferred_categorical_features_new = np.sum(Ximp[:,self.inferred_categorical_features_index] != Ximp_old[:,self.inferred_categorical_features_index])/self.inferred_categorical_features_index.size
# XGBImputer - Epoch: 4 | Categorical gamma: nan/nan | Numerical gamma: 0.0005564688/0.000598956
# Binning 0.142 GB of training data: 0.252 s
# Binning 0.016 GB of validation data: 0.030 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.42517, val loss: 0.42172, in 0.087s
# [2/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.36392, val loss: 0.36096, in 0.062s
# [3/100] 1 tree, 31 leaves, max depth = 6, train loss: 0.31404, val loss: 0.31130, in 0.063s
# [4/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.27356, val loss: 0.27093, in 0.065s
# [5/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.24016, val loss: 0.23771, in 0.086s
# [6/100] 1 tree, 31 leaves, max depth = 6, train loss: 0.21216, val loss: 0.21002, in 0.072s
# [7/100] 1 tree, 31 leaves, max depth = 6, train loss: 0.18926, val loss: 0.18735, in 0.060s
# [8/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.17046, val loss: 0.16868, in 0.067s
# [9/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.15469, val loss: 0.15319, in 0.072s
# [10/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.14131, val loss: 0.13998, in 0.075s
# [11/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.13021, val loss: 0.12901, in 0.067s
# [12/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.12123, val loss: 0.12015, in 0.063s
# [13/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.11356, val loss: 0.11271, in 0.066s
# [14/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.10691, val loss: 0.10622, in 0.063s
# [15/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.10148, val loss: 0.10089, in 0.068s
# [16/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.09643, val loss: 0.09581, in 0.061s
# [17/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.09220, val loss: 0.09160, in 0.064s
# [18/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.08849, val loss: 0.08808, in 0.070s
# [19/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.08534, val loss: 0.08501, in 0.077s
# [20/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.08270, val loss: 0.08252, in 0.080s
# [21/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.08050, val loss: 0.08033, in 0.061s
# [22/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.07826, val loss: 0.07804, in 0.070s
# [23/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.07629, val loss: 0.07610, in 0.091s
# [24/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.07450, val loss: 0.07431, in 0.092s
# [25/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.07298, val loss: 0.07289, in 0.065s
# [26/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.07135, val loss: 0.07133, in 0.065s
# [27/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.07003, val loss: 0.07000, in 0.078s
# [28/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.06872, val loss: 0.06876, in 0.066s
# [29/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.06767, val loss: 0.06764, in 0.057s
# [30/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.06663, val loss: 0.06662, in 0.060s
# [31/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.06574, val loss: 0.06574, in 0.062s
# [32/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.06482, val loss: 0.06479, in 0.068s
# [33/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.06396, val loss: 0.06396, in 0.066s
# [34/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.06293, val loss: 0.06299, in 0.064s
# [35/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.06200, val loss: 0.06212, in 0.062s
# [36/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.06142, val loss: 0.06153, in 0.064s
# [37/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.06069, val loss: 0.06081, in 0.064s
# [38/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.05991, val loss: 0.06005, in 0.071s
# [39/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05927, val loss: 0.05938, in 0.087s
# [40/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.05861, val loss: 0.05871, in 0.067s
# [41/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.05808, val loss: 0.05818, in 0.060s
# [42/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05758, val loss: 0.05769, in 0.062s
# [43/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05717, val loss: 0.05728, in 0.072s
# [44/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.05670, val loss: 0.05683, in 0.051s
# [45/100] 1 tree, 31 leaves, max depth = 16, train loss: 0.05606, val loss: 0.05622, in 0.057s
# [46/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.05564, val loss: 0.05582, in 0.060s
# [47/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.05521, val loss: 0.05544, in 0.060s
# [48/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.05466, val loss: 0.05497, in 0.061s
# [49/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.05423, val loss: 0.05460, in 0.052s
# [50/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.05387, val loss: 0.05424, in 0.057s
# [51/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05353, val loss: 0.05391, in 0.062s
# [52/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.05331, val loss: 0.05372, in 0.059s
# [53/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05307, val loss: 0.05348, in 0.065s
# [54/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.05268, val loss: 0.05302, in 0.055s
# [55/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.05236, val loss: 0.05275, in 0.060s
# [56/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05197, val loss: 0.05237, in 0.060s
# [57/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.05155, val loss: 0.05200, in 0.065s
# [58/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.05120, val loss: 0.05169, in 0.069s
# [59/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05087, val loss: 0.05134, in 0.054s
# [60/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05054, val loss: 0.05103, in 0.111s
# [61/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.05029, val loss: 0.05081, in 0.799s
# [62/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04994, val loss: 0.05049, in 0.219s
# [63/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04971, val loss: 0.05027, in 0.057s
# [64/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.04947, val loss: 0.05002, in 0.049s
# [65/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04927, val loss: 0.04982, in 0.057s
# [66/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04905, val loss: 0.04961, in 0.055s
# [67/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04887, val loss: 0.04944, in 0.061s
# [68/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04865, val loss: 0.04920, in 0.075s
# [69/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04829, val loss: 0.04885, in 0.068s
# [70/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04811, val loss: 0.04869, in 0.048s
# [71/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.04791, val loss: 0.04848, in 0.073s
# [72/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.04766, val loss: 0.04824, in 0.066s
# [73/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04747, val loss: 0.04807, in 0.058s
# [74/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.04724, val loss: 0.04783, in 0.051s
# [75/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.04703, val loss: 0.04764, in 0.060s
# [76/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.04687, val loss: 0.04751, in 0.057s
# [77/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04672, val loss: 0.04736, in 0.068s
# [78/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04650, val loss: 0.04716, in 0.063s
# [79/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04634, val loss: 0.04699, in 0.060s
# [80/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04617, val loss: 0.04681, in 0.053s
# [81/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04597, val loss: 0.04659, in 0.053s
# [82/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04577, val loss: 0.04643, in 0.064s
# [83/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04560, val loss: 0.04627, in 0.067s
# [84/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04547, val loss: 0.04614, in 0.056s
# [85/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04537, val loss: 0.04606, in 0.057s
# [86/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04528, val loss: 0.04599, in 0.114s
# [87/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04511, val loss: 0.04582, in 0.070s
# [88/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04498, val loss: 0.04570, in 0.076s
# [89/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.04483, val loss: 0.04558, in 0.058s
# [90/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04470, val loss: 0.04548, in 0.056s
# [91/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04459, val loss: 0.04537, in 0.054s
# [92/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04446, val loss: 0.04526, in 0.060s
# [93/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04439, val loss: 0.04521, in 0.058s
# [94/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.04418, val loss: 0.04502, in 0.073s
# [95/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04398, val loss: 0.04481, in 0.064s
# [96/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04381, val loss: 0.04459, in 0.054s
# [97/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.04371, val loss: 0.04450, in 0.051s
# [98/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.04353, val loss: 0.04438, in 0.060s
# [99/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.04341, val loss: 0.04426, in 0.057s
# [100/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.04327, val loss: 0.04415, in 0.052s
# Fit 100 trees in 7.776 s, (3100 total leaves)
# Time spent computing histograms: 3.456s
# Time spent finding best splits:  1.476s
# Time spent applying splits:      1.773s
# Time spent predicting:           0.072s
# Binning 0.142 GB of training data: 0.305 s
# Binning 0.016 GB of validation data: 0.045 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.40599, val loss: 0.40580, in 0.204s
# [2/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.32996, val loss: 0.32980, in 0.166s
# [3/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.26835, val loss: 0.26822, in 0.070s
# [4/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.21807, val loss: 0.21798, in 0.062s
# [5/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.17733, val loss: 0.17726, in 0.064s
# [6/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.14426, val loss: 0.14422, in 0.065s
# [7/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.11745, val loss: 0.11743, in 0.061s
# [8/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.09586, val loss: 0.09584, in 0.063s
# [9/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.07818, val loss: 0.07818, in 0.062s
# [10/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.06390, val loss: 0.06390, in 0.071s
# [11/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.05228, val loss: 0.05229, in 0.061s
# [12/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04287, val loss: 0.04291, in 0.039s
# [13/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.03524, val loss: 0.03531, in 0.040s
# [14/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.02911, val loss: 0.02917, in 0.035s
# [15/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.02408, val loss: 0.02415, in 0.061s
# [16/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.02003, val loss: 0.02012, in 0.047s
# [17/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.01670, val loss: 0.01679, in 0.044s
# [18/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.01401, val loss: 0.01410, in 0.256s
# [19/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.01177, val loss: 0.01187, in 0.147s
# [20/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00994, val loss: 0.01005, in 0.235s
# [21/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00847, val loss: 0.00859, in 0.129s
# [22/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00726, val loss: 0.00740, in 0.167s
# [23/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00629, val loss: 0.00645, in 0.273s
# [24/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00549, val loss: 0.00566, in 0.262s
# [25/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00486, val loss: 0.00502, in 0.130s
# [26/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00430, val loss: 0.00447, in 1.182s
# [27/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00386, val loss: 0.00403, in 0.200s
# [28/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00351, val loss: 0.00368, in 0.181s
# [29/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00322, val loss: 0.00339, in 0.215s
# [30/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00298, val loss: 0.00315, in 0.136s
# [31/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.00277, val loss: 0.00295, in 0.278s
# [32/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00260, val loss: 0.00279, in 0.183s
# [33/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00247, val loss: 0.00265, in 0.152s
# [34/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00235, val loss: 0.00254, in 0.141s
# [35/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00224, val loss: 0.00243, in 0.262s
# [36/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.00216, val loss: 0.00236, in 0.155s
# [37/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00209, val loss: 0.00228, in 0.310s
# [38/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00201, val loss: 0.00221, in 0.217s
# [39/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00195, val loss: 0.00216, in 0.149s
# [40/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00189, val loss: 0.00210, in 0.201s
# [41/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00181, val loss: 0.00202, in 0.308s
# [42/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00178, val loss: 0.00199, in 0.266s
# [43/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00173, val loss: 0.00194, in 0.175s
# [44/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.00170, val loss: 0.00190, in 0.108s
# [45/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00166, val loss: 0.00187, in 0.130s
# [46/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00163, val loss: 0.00184, in 0.214s
# [47/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00160, val loss: 0.00180, in 0.131s
# [48/100] 1 tree, 31 leaves, max depth = 16, train loss: 0.00157, val loss: 0.00178, in 0.119s
# [49/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.00155, val loss: 0.00176, in 0.285s
# [50/100] 1 tree, 31 leaves, max depth = 16, train loss: 0.00153, val loss: 0.00175, in 0.169s
# [51/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00151, val loss: 0.00173, in 0.231s
# [52/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00150, val loss: 0.00172, in 0.180s
# [53/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.00148, val loss: 0.00171, in 0.139s
# [54/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.00146, val loss: 0.00169, in 0.135s
# [55/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00145, val loss: 0.00168, in 0.289s
# [56/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00144, val loss: 0.00167, in 0.163s
# [57/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00142, val loss: 0.00165, in 0.145s
# [58/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00141, val loss: 0.00164, in 0.283s
# [59/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00138, val loss: 0.00162, in 0.201s
# [60/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00137, val loss: 0.00161, in 0.197s
# [61/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00136, val loss: 0.00160, in 0.811s
# [62/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.00135, val loss: 0.00159, in 0.422s
# [63/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00133, val loss: 0.00157, in 0.202s
# [64/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00132, val loss: 0.00157, in 0.177s
# [65/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00131, val loss: 0.00155, in 0.158s
# [66/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00129, val loss: 0.00154, in 0.212s
# [67/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00128, val loss: 0.00153, in 0.369s
# [68/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.00126, val loss: 0.00150, in 0.118s
# [69/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00125, val loss: 0.00150, in 0.129s
# [70/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.00124, val loss: 0.00147, in 0.457s
# [71/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.00122, val loss: 0.00146, in 0.188s
# [72/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00122, val loss: 0.00146, in 0.206s
# [73/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00121, val loss: 0.00145, in 0.117s
# [74/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00120, val loss: 0.00145, in 0.163s
# [75/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00120, val loss: 0.00144, in 0.269s
# [76/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00119, val loss: 0.00143, in 0.138s
# [77/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.00118, val loss: 0.00143, in 0.132s
# [78/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.00118, val loss: 0.00142, in 0.245s
# [79/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00117, val loss: 0.00142, in 0.130s
# [80/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.00116, val loss: 0.00139, in 0.108s
# [81/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00115, val loss: 0.00138, in 0.193s
# [82/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00115, val loss: 0.00138, in 0.171s
# [83/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.00114, val loss: 0.00138, in 0.179s
# [84/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00114, val loss: 0.00138, in 0.155s
# [85/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00113, val loss: 0.00137, in 0.210s
# [86/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00113, val loss: 0.00137, in 0.107s
# [87/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00112, val loss: 0.00137, in 0.114s
# [88/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00112, val loss: 0.00136, in 0.130s
# [89/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.00111, val loss: 0.00136, in 0.252s
# [90/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00111, val loss: 0.00136, in 0.149s
# [91/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00110, val loss: 0.00135, in 0.209s
# [92/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.00110, val loss: 0.00135, in 0.212s
# [93/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.00109, val loss: 0.00134, in 0.273s
# [94/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00109, val loss: 0.00134, in 0.223s
# [95/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00108, val loss: 0.00134, in 0.741s
# [96/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00108, val loss: 0.00133, in 0.653s
# [97/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00107, val loss: 0.00133, in 0.139s
# [98/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00107, val loss: 0.00133, in 0.446s
# [99/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00106, val loss: 0.00132, in 0.207s
# [100/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00105, val loss: 0.00132, in 0.252s
# Fit 100 trees in 20.904 s, (3100 total leaves)
# Time spent computing histograms: 9.165s
# Time spent finding best splits:  3.924s
# Time spent applying splits:      5.597s
# Time spent predicting:           0.296s
# Binning 0.142 GB of training data: 0.733 s
# Binning 0.016 GB of validation data: 0.115 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.41031, val loss: 0.40782, in 0.333s
# [2/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.33744, val loss: 0.33518, in 0.312s
# [3/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.27819, val loss: 0.27611, in 0.263s
# [4/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.23003, val loss: 0.22811, in 0.276s
# [5/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.19060, val loss: 0.18887, in 0.205s
# [6/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.15854, val loss: 0.15696, in 0.260s
# [7/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.13249, val loss: 0.13096, in 0.327s
# [8/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.11057, val loss: 0.10906, in 0.244s
# [9/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.09323, val loss: 0.09182, in 0.214s
# [10/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.07859, val loss: 0.07736, in 0.247s
# [11/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.06713, val loss: 0.06594, in 0.200s
# [12/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.05749, val loss: 0.05644, in 0.206s
# [13/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04945, val loss: 0.04857, in 0.328s
# [14/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.04298, val loss: 0.04215, in 0.183s
# [15/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.03726, val loss: 0.03662, in 0.447s
# [16/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.03241, val loss: 0.03189, in 0.206s
# [17/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.02846, val loss: 0.02806, in 1.071s
# [18/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.02516, val loss: 0.02485, in 0.240s
# [19/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.02246, val loss: 0.02221, in 0.161s
# [20/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.02044, val loss: 0.02021, in 0.460s
# [21/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.01850, val loss: 0.01835, in 0.237s
# [22/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.01700, val loss: 0.01691, in 0.212s
# [23/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.01589, val loss: 0.01576, in 0.348s
# [24/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.01476, val loss: 0.01472, in 0.445s
# [25/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.01388, val loss: 0.01389, in 0.286s
# [26/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.01309, val loss: 0.01315, in 0.312s
# [27/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.01245, val loss: 0.01250, in 0.326s
# [28/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.01180, val loss: 0.01183, in 0.433s
# [29/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.01128, val loss: 0.01130, in 0.199s
# [30/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.01086, val loss: 0.01087, in 0.180s
# [31/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.01055, val loss: 0.01056, in 0.234s
# [32/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.01012, val loss: 0.01013, in 0.161s
# [33/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00975, val loss: 0.00977, in 0.159s
# [34/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00938, val loss: 0.00940, in 0.275s
# [35/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00911, val loss: 0.00915, in 0.211s
# [36/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00888, val loss: 0.00896, in 0.061s
# [37/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00870, val loss: 0.00877, in 0.042s
# [38/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00848, val loss: 0.00854, in 0.041s
# [39/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00833, val loss: 0.00839, in 0.041s
# [40/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00820, val loss: 0.00825, in 0.038s
# [41/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00802, val loss: 0.00814, in 0.084s
# [42/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00784, val loss: 0.00797, in 0.065s
# [43/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.00765, val loss: 0.00781, in 0.046s
# [44/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00752, val loss: 0.00768, in 0.051s
# [45/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00739, val loss: 0.00755, in 0.085s
# [46/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00725, val loss: 0.00742, in 0.068s
# [47/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00714, val loss: 0.00735, in 0.059s
# [48/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00700, val loss: 0.00720, in 0.063s
# [49/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00691, val loss: 0.00712, in 0.060s
# [50/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.00682, val loss: 0.00703, in 0.077s
# [51/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00670, val loss: 0.00694, in 0.034s
# [52/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00659, val loss: 0.00683, in 0.056s
# [53/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00648, val loss: 0.00672, in 0.057s
# [54/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00642, val loss: 0.00667, in 0.061s
# [55/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00633, val loss: 0.00658, in 0.065s
# [56/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.00624, val loss: 0.00649, in 0.073s
# [57/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.00617, val loss: 0.00642, in 0.091s
# [58/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00610, val loss: 0.00636, in 0.036s
# [59/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.00604, val loss: 0.00630, in 0.037s
# [60/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00597, val loss: 0.00623, in 0.060s
# [61/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00592, val loss: 0.00619, in 0.053s
# [62/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00584, val loss: 0.00612, in 0.101s
# [63/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00576, val loss: 0.00604, in 0.761s
# [64/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00570, val loss: 0.00600, in 0.124s
# [65/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00564, val loss: 0.00595, in 0.075s
# [66/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00559, val loss: 0.00591, in 0.042s
# [67/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00555, val loss: 0.00586, in 0.043s
# [68/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00549, val loss: 0.00582, in 0.063s
# [69/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00544, val loss: 0.00576, in 0.068s
# [70/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00540, val loss: 0.00573, in 0.062s
# [71/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00537, val loss: 0.00570, in 0.054s
# [72/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00534, val loss: 0.00567, in 0.049s
# [73/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.00531, val loss: 0.00563, in 0.090s
# [74/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00525, val loss: 0.00558, in 0.062s
# [75/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.00521, val loss: 0.00555, in 0.162s
# [76/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00518, val loss: 0.00552, in 0.157s
# [77/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00516, val loss: 0.00549, in 0.129s
# [78/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00514, val loss: 0.00547, in 0.136s
# [79/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00512, val loss: 0.00546, in 0.070s
# [80/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.00508, val loss: 0.00542, in 0.082s
# [81/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00506, val loss: 0.00539, in 0.039s
# [82/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00502, val loss: 0.00537, in 0.028s
# [83/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.00499, val loss: 0.00534, in 0.029s
# [84/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.00497, val loss: 0.00532, in 0.033s
# [85/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.00493, val loss: 0.00528, in 0.031s
# [86/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00491, val loss: 0.00526, in 0.029s
# [87/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.00488, val loss: 0.00523, in 0.043s
# [88/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00486, val loss: 0.00521, in 0.039s
# [89/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00484, val loss: 0.00519, in 0.045s
# [90/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.00482, val loss: 0.00516, in 0.038s
# [91/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00479, val loss: 0.00514, in 0.039s
# [92/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.00478, val loss: 0.00512, in 0.038s
# [93/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.00476, val loss: 0.00511, in 0.037s
# [94/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.00474, val loss: 0.00508, in 0.044s
# [95/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00471, val loss: 0.00506, in 0.045s
# [96/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00466, val loss: 0.00502, in 0.036s
# [97/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.00463, val loss: 0.00498, in 0.031s
# [98/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00461, val loss: 0.00497, in 0.053s
# [99/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.00459, val loss: 0.00496, in 0.038s
# [100/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.00455, val loss: 0.00493, in 0.197s
# Fit 100 trees in 16.019 s, (3100 total leaves)
# Time spent computing histograms: 7.127s
# Time spent finding best splits:  2.775s
# Time spent applying splits:      3.837s
# Time spent predicting:           0.155s
# Binning 0.142 GB of training data: 0.755 s
# Binning 0.016 GB of validation data: 0.026 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.43791, val loss: 0.43870, in 0.085s
# [2/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.38769, val loss: 0.38826, in 0.043s
# [3/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.34696, val loss: 0.34731, in 0.059s
# [4/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.31379, val loss: 0.31394, in 0.059s
# [5/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.28687, val loss: 0.28688, in 0.057s
# [6/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.26471, val loss: 0.26464, in 0.086s
# [7/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.24676, val loss: 0.24660, in 0.077s
# [8/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.23213, val loss: 0.23191, in 0.075s
# [9/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.22005, val loss: 0.21973, in 0.790s
# [10/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.21020, val loss: 0.20984, in 0.180s
# [11/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.20204, val loss: 0.20165, in 0.074s
# [12/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.19549, val loss: 0.19508, in 0.072s
# [13/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.18998, val loss: 0.18955, in 0.089s
# [14/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.18546, val loss: 0.18507, in 0.067s
# [15/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.18173, val loss: 0.18128, in 0.069s
# [16/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.17871, val loss: 0.17826, in 0.047s
# [17/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.17600, val loss: 0.17550, in 0.103s
# [18/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.17378, val loss: 0.17334, in 0.073s
# [19/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.17192, val loss: 0.17152, in 0.067s
# [20/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.17028, val loss: 0.16979, in 0.068s
# [21/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.16897, val loss: 0.16848, in 0.067s
# [22/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.16789, val loss: 0.16740, in 0.063s
# [23/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.16684, val loss: 0.16631, in 0.052s
# [24/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.16603, val loss: 0.16551, in 0.065s
# [25/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.16525, val loss: 0.16475, in 0.074s
# [26/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.16462, val loss: 0.16415, in 0.067s
# [27/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.16394, val loss: 0.16348, in 0.064s
# [28/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.16335, val loss: 0.16290, in 0.070s
# [29/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.16280, val loss: 0.16236, in 0.043s
# [30/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.16239, val loss: 0.16194, in 0.064s
# [31/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.16205, val loss: 0.16159, in 0.070s
# [32/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.16169, val loss: 0.16123, in 0.081s
# [33/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.16134, val loss: 0.16088, in 0.072s
# [34/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.16078, val loss: 0.16038, in 0.079s
# [35/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.16050, val loss: 0.16009, in 0.040s
# [36/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.16010, val loss: 0.15974, in 0.057s
# [37/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.15973, val loss: 0.15938, in 0.059s
# [38/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.15939, val loss: 0.15907, in 0.081s
# [39/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.15911, val loss: 0.15881, in 0.065s
# [40/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.15889, val loss: 0.15861, in 0.069s
# [41/100] 1 tree, 31 leaves, max depth = 16, train loss: 0.15859, val loss: 0.15836, in 0.065s
# [42/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.15839, val loss: 0.15817, in 0.067s
# [43/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15818, val loss: 0.15799, in 0.069s
# [44/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15798, val loss: 0.15781, in 0.066s
# [45/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.15779, val loss: 0.15762, in 0.072s
# [46/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.15763, val loss: 0.15747, in 0.060s
# [47/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15745, val loss: 0.15728, in 0.068s
# [48/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15726, val loss: 0.15709, in 0.055s
# [49/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15713, val loss: 0.15696, in 0.054s
# [50/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.15701, val loss: 0.15683, in 0.063s
# [51/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15686, val loss: 0.15672, in 0.061s
# [52/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.15674, val loss: 0.15663, in 0.062s
# [53/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.15657, val loss: 0.15648, in 0.097s
# [54/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15648, val loss: 0.15639, in 0.763s
# [55/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.15639, val loss: 0.15632, in 0.183s
# [56/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.15625, val loss: 0.15616, in 0.058s
# [57/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15616, val loss: 0.15609, in 0.050s
# [58/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.15604, val loss: 0.15597, in 0.057s
# [59/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15592, val loss: 0.15586, in 0.059s
# [60/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.15580, val loss: 0.15575, in 0.061s
# [61/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15572, val loss: 0.15567, in 0.065s
# [62/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15560, val loss: 0.15557, in 0.070s
# [63/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15549, val loss: 0.15546, in 0.060s
# [64/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15541, val loss: 0.15540, in 0.053s
# [65/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.15535, val loss: 0.15536, in 0.091s
# [66/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15527, val loss: 0.15530, in 0.074s
# [67/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15515, val loss: 0.15516, in 0.063s
# [68/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15504, val loss: 0.15507, in 0.062s
# [69/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15498, val loss: 0.15503, in 0.059s
# [70/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15493, val loss: 0.15498, in 0.073s
# [71/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15485, val loss: 0.15489, in 0.064s
# [72/100] 1 tree, 31 leaves, max depth = 16, train loss: 0.15479, val loss: 0.15484, in 0.058s
# [73/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.15472, val loss: 0.15477, in 0.057s
# [74/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.15464, val loss: 0.15473, in 0.054s
# [75/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.15452, val loss: 0.15460, in 0.053s
# [76/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15447, val loss: 0.15456, in 0.060s
# [77/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.15443, val loss: 0.15453, in 0.051s
# [78/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.15438, val loss: 0.15448, in 0.081s
# [79/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.15430, val loss: 0.15437, in 0.056s
# [80/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15418, val loss: 0.15426, in 0.060s
# [81/100] 1 tree, 31 leaves, max depth = 16, train loss: 0.15410, val loss: 0.15421, in 0.058s
# [82/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.15400, val loss: 0.15414, in 0.063s
# [83/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15395, val loss: 0.15409, in 0.055s
# [84/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15389, val loss: 0.15400, in 0.066s
# [85/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.15377, val loss: 0.15388, in 0.063s
# [86/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.15369, val loss: 0.15382, in 0.060s
# [87/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15362, val loss: 0.15375, in 0.050s
# [88/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15357, val loss: 0.15373, in 0.047s
# [89/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.15350, val loss: 0.15368, in 0.055s
# [90/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.15344, val loss: 0.15362, in 0.057s
# [91/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.15341, val loss: 0.15360, in 0.048s
# [92/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15336, val loss: 0.15357, in 0.046s
# [93/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.15330, val loss: 0.15352, in 0.047s
# [94/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.15323, val loss: 0.15347, in 0.050s
# [95/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15318, val loss: 0.15344, in 0.060s
# [96/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.15308, val loss: 0.15337, in 0.089s
# [97/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.15306, val loss: 0.15336, in 0.050s
# [98/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.15303, val loss: 0.15334, in 0.047s
# [99/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15297, val loss: 0.15329, in 0.055s
# [100/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.15289, val loss: 0.15323, in 0.060s
# Fit 100 trees in 9.175 s, (3100 total leaves)
# Time spent computing histograms: 3.640s
# Time spent finding best splits:  1.661s
# Time spent applying splits:      1.985s
# Time spent predicting:           0.075s
# Binning 0.142 GB of training data: 0.209 s
# Binning 0.016 GB of validation data: 0.020 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 15 leaves, max depth = 6, train loss: 0.40502, val loss: 0.40485, in 0.038s
# [2/100] 1 tree, 11 leaves, max depth = 4, train loss: 0.32806, val loss: 0.32793, in 0.031s
# [3/100] 1 tree, 18 leaves, max depth = 6, train loss: 0.26573, val loss: 0.26562, in 0.038s
# [4/100] 1 tree, 14 leaves, max depth = 6, train loss: 0.21524, val loss: 0.21515, in 0.034s
# [5/100] 1 tree, 22 leaves, max depth = 6, train loss: 0.17435, val loss: 0.17427, in 0.047s
# [6/100] 1 tree, 22 leaves, max depth = 7, train loss: 0.14122, val loss: 0.14116, in 0.055s
# [7/100] 1 tree, 16 leaves, max depth = 6, train loss: 0.11439, val loss: 0.11434, in 0.039s
# [8/100] 1 tree, 7 leaves, max depth = 4, train loss: 0.09265, val loss: 0.09262, in 0.024s
# [9/100] 1 tree, 18 leaves, max depth = 6, train loss: 0.07505, val loss: 0.07502, in 0.046s
# [10/100] 1 tree, 11 leaves, max depth = 5, train loss: 0.06079, val loss: 0.06077, in 0.038s
# [11/100] 1 tree, 19 leaves, max depth = 5, train loss: 0.04924, val loss: 0.04922, in 0.046s
# [12/100] 1 tree, 24 leaves, max depth = 7, train loss: 0.03988, val loss: 0.03987, in 0.054s
# [13/100] 1 tree, 8 leaves, max depth = 5, train loss: 0.03231, val loss: 0.03229, in 0.027s
# [14/100] 1 tree, 12 leaves, max depth = 7, train loss: 0.02617, val loss: 0.02616, in 0.035s
# [15/100] 1 tree, 19 leaves, max depth = 6, train loss: 0.02120, val loss: 0.02119, in 0.048s
# [16/100] 1 tree, 13 leaves, max depth = 5, train loss: 0.01717, val loss: 0.01716, in 0.049s
# [17/100] 1 tree, 15 leaves, max depth = 6, train loss: 0.01391, val loss: 0.01390, in 0.042s
# [18/100] 1 tree, 11 leaves, max depth = 5, train loss: 0.01126, val loss: 0.01126, in 0.031s
# [19/100] 1 tree, 16 leaves, max depth = 6, train loss: 0.00912, val loss: 0.00912, in 0.039s
# [20/100] 1 tree, 23 leaves, max depth = 6, train loss: 0.00739, val loss: 0.00739, in 0.046s
# [21/100] 1 tree, 8 leaves, max depth = 4, train loss: 0.00599, val loss: 0.00598, in 0.026s
# [22/100] 1 tree, 14 leaves, max depth = 5, train loss: 0.00485, val loss: 0.00485, in 0.036s
# [23/100] 1 tree, 11 leaves, max depth = 4, train loss: 0.00393, val loss: 0.00393, in 0.033s
# [24/100] 1 tree, 14 leaves, max depth = 6, train loss: 0.00318, val loss: 0.00318, in 0.037s
# [25/100] 1 tree, 8 leaves, max depth = 5, train loss: 0.00258, val loss: 0.00258, in 0.029s
# [26/100] 1 tree, 22 leaves, max depth = 7, train loss: 0.00209, val loss: 0.00209, in 0.046s
# [27/100] 1 tree, 16 leaves, max depth = 6, train loss: 0.00169, val loss: 0.00169, in 0.035s
# [28/100] 1 tree, 9 leaves, max depth = 5, train loss: 0.00137, val loss: 0.00137, in 0.040s
# [29/100] 1 tree, 28 leaves, max depth = 7, train loss: 0.00111, val loss: 0.00111, in 0.053s
# [30/100] 1 tree, 19 leaves, max depth = 6, train loss: 0.00090, val loss: 0.00090, in 0.044s
# [31/100] 1 tree, 18 leaves, max depth = 6, train loss: 0.00073, val loss: 0.00073, in 0.042s
# [32/100] 1 tree, 18 leaves, max depth = 6, train loss: 0.00059, val loss: 0.00059, in 0.045s
# [33/100] 1 tree, 19 leaves, max depth = 5, train loss: 0.00048, val loss: 0.00048, in 0.043s
# [34/100] 1 tree, 11 leaves, max depth = 7, train loss: 0.00039, val loss: 0.00039, in 0.033s
# [35/100] 1 tree, 10 leaves, max depth = 4, train loss: 0.00031, val loss: 0.00031, in 0.030s
# [36/100] 1 tree, 17 leaves, max depth = 7, train loss: 0.00025, val loss: 0.00025, in 0.040s
# [37/100] 1 tree, 7 leaves, max depth = 4, train loss: 0.00021, val loss: 0.00021, in 0.028s
# [38/100] 1 tree, 19 leaves, max depth = 7, train loss: 0.00017, val loss: 0.00017, in 0.043s
# [39/100] 1 tree, 21 leaves, max depth = 6, train loss: 0.00013, val loss: 0.00013, in 0.043s
# [40/100] 1 tree, 19 leaves, max depth = 8, train loss: 0.00011, val loss: 0.00011, in 0.041s
# [41/100] 1 tree, 14 leaves, max depth = 6, train loss: 0.00009, val loss: 0.00009, in 0.032s
# [42/100] 1 tree, 14 leaves, max depth = 6, train loss: 0.00007, val loss: 0.00007, in 0.034s
# [43/100] 1 tree, 14 leaves, max depth = 5, train loss: 0.00006, val loss: 0.00006, in 0.032s
# [44/100] 1 tree, 23 leaves, max depth = 7, train loss: 0.00005, val loss: 0.00005, in 0.041s
# [45/100] 1 tree, 15 leaves, max depth = 5, train loss: 0.00004, val loss: 0.00004, in 0.033s
# [46/100] 1 tree, 16 leaves, max depth = 5, train loss: 0.00003, val loss: 0.00003, in 0.036s
# [47/100] 1 tree, 13 leaves, max depth = 6, train loss: 0.00002, val loss: 0.00002, in 0.032s
# [48/100] 1 tree, 13 leaves, max depth = 5, train loss: 0.00002, val loss: 0.00002, in 0.032s
# [49/100] 1 tree, 13 leaves, max depth = 6, train loss: 0.00002, val loss: 0.00002, in 0.035s
# [50/100] 1 tree, 14 leaves, max depth = 5, train loss: 0.00001, val loss: 0.00001, in 0.037s
# [51/100] 1 tree, 14 leaves, max depth = 6, train loss: 0.00001, val loss: 0.00001, in 0.037s
# [52/100] 1 tree, 18 leaves, max depth = 6, train loss: 0.00001, val loss: 0.00001, in 0.043s
# [53/100] 1 tree, 21 leaves, max depth = 7, train loss: 0.00001, val loss: 0.00001, in 0.045s
# [54/100] 1 tree, 22 leaves, max depth = 7, train loss: 0.00001, val loss: 0.00001, in 0.061s
# [55/100] 1 tree, 15 leaves, max depth = 6, train loss: 0.00000, val loss: 0.00000, in 0.159s
# [56/100] 1 tree, 19 leaves, max depth = 6, train loss: 0.00000, val loss: 0.00000, in 0.570s
# [57/100] 1 tree, 17 leaves, max depth = 6, train loss: 0.00000, val loss: 0.00000, in 0.142s
# [58/100] 1 tree, 20 leaves, max depth = 6, train loss: 0.00000, val loss: 0.00000, in 0.086s
# [59/100] 1 tree, 14 leaves, max depth = 7, train loss: 0.00000, val loss: 0.00000, in 0.036s
# [60/100] 1 tree, 25 leaves, max depth = 7, train loss: 0.00000, val loss: 0.00000, in 0.048s
# [61/100] 1 tree, 15 leaves, max depth = 7, train loss: 0.00000, val loss: 0.00000, in 0.034s
# [62/100] 1 tree, 29 leaves, max depth = 8, train loss: 0.00000, val loss: 0.00000, in 0.061s
# [63/100] 1 tree, 27 leaves, max depth = 7, train loss: 0.00000, val loss: 0.00000, in 0.054s
# [64/100] 1 tree, 16 leaves, max depth = 6, train loss: 0.00000, val loss: 0.00000, in 0.037s
# [65/100] 1 tree, 15 leaves, max depth = 6, train loss: 0.00000, val loss: 0.00000, in 0.040s
# [66/100] 1 tree, 11 leaves, max depth = 7, train loss: 0.00000, val loss: 0.00000, in 0.033s
# [67/100] 1 tree, 12 leaves, max depth = 5, train loss: 0.00000, val loss: 0.00000, in 0.033s
# [68/100] 1 tree, 13 leaves, max depth = 6, train loss: 0.00000, val loss: 0.00000, in 0.034s
# [69/100] 1 tree, 10 leaves, max depth = 4, train loss: 0.00000, val loss: 0.00000, in 0.033s
# [70/100] 1 tree, 14 leaves, max depth = 5, train loss: 0.00000, val loss: 0.00000, in 0.039s
# [71/100] 1 tree, 7 leaves, max depth = 4, train loss: 0.00000, val loss: 0.00000, in 0.030s
# [72/100] 1 tree, 11 leaves, max depth = 5, train loss: 0.00000, val loss: 0.00000, in 0.035s
# [73/100] 1 tree, 12 leaves, max depth = 6, train loss: 0.00000, val loss: 0.00000, in 0.035s
# [74/100] 1 tree, 18 leaves, max depth = 6, train loss: 0.00000, val loss: 0.00000, in 0.044s
# [75/100] 1 tree, 15 leaves, max depth = 6, train loss: 0.00000, val loss: 0.00000, in 0.057s
# [76/100] 1 tree, 21 leaves, max depth = 6, train loss: 0.00000, val loss: 0.00000, in 0.061s
# [77/100] 1 tree, 8 leaves, max depth = 4, train loss: 0.00000, val loss: 0.00000, in 0.025s
# [78/100] 1 tree, 23 leaves, max depth = 7, train loss: 0.00000, val loss: 0.00000, in 0.050s
# ...
# [42/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.12317, val loss: 0.13528, in 0.033s
# [43/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.12263, val loss: 0.13493, in 0.052s
# [44/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.12116, val loss: 0.13409, in 0.146s
# [45/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.12085, val loss: 0.13387, in 0.751s
# [46/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.12016, val loss: 0.13348, in 0.189s
# [47/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.11955, val loss: 0.13326, in 0.033s
# [48/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.11914, val loss: 0.13312, in 0.037s
# [49/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.11886, val loss: 0.13314, in 0.038s
# [50/100] 1 tree, 31 leaves, max depth = 18, train loss: 0.11774, val loss: 0.13220, in 0.033s
# [51/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.11749, val loss: 0.13201, in 0.033s
# [52/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.11678, val loss: 0.13166, in 0.063s
# [53/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.11557, val loss: 0.13061, in 0.032s
# [54/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.11510, val loss: 0.13017, in 0.028s
# [55/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.11488, val loss: 0.13006, in 0.044s
# [56/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.11414, val loss: 0.12928, in 0.031s
# [57/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.11393, val loss: 0.12923, in 0.037s
# [58/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.11348, val loss: 0.12907, in 0.050s
# [59/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.11323, val loss: 0.12913, in 0.044s
# [60/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.11291, val loss: 0.12899, in 0.054s
# [61/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.11254, val loss: 0.12868, in 0.045s
# [62/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.11231, val loss: 0.12857, in 0.048s
# [63/100] 1 tree, 31 leaves, max depth = 16, train loss: 0.11167, val loss: 0.12791, in 0.027s
# [64/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.11094, val loss: 0.12756, in 0.032s
# [65/100] 1 tree, 31 leaves, max depth = 17, train loss: 0.11031, val loss: 0.12724, in 0.042s
# [66/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.11019, val loss: 0.12718, in 0.024s
# [67/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.10990, val loss: 0.12691, in 0.031s
# [68/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.10926, val loss: 0.12642, in 0.030s
# [69/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.10861, val loss: 0.12597, in 0.046s
# [70/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.10854, val loss: 0.12592, in 0.036s
# [71/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.10799, val loss: 0.12566, in 0.030s
# [72/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.10754, val loss: 0.12526, in 0.049s
# [73/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.10727, val loss: 0.12506, in 0.048s
# [74/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.10696, val loss: 0.12483, in 0.032s
# [75/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.10686, val loss: 0.12482, in 0.029s
# [76/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.10635, val loss: 0.12447, in 0.049s
# [77/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.10607, val loss: 0.12439, in 0.029s
# [78/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.10596, val loss: 0.12432, in 0.028s
# [79/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.10567, val loss: 0.12420, in 0.044s
# [80/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.10526, val loss: 0.12388, in 0.028s
# [81/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.10518, val loss: 0.12384, in 0.025s
# [82/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.10488, val loss: 0.12376, in 0.043s
# [83/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.10440, val loss: 0.12340, in 0.033s
# [84/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.10394, val loss: 0.12299, in 0.034s
# [85/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.10358, val loss: 0.12252, in 0.049s
# [86/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.10348, val loss: 0.12249, in 0.027s
# [87/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.10329, val loss: 0.12243, in 0.031s
# [88/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.10295, val loss: 0.12212, in 0.057s
# [89/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.10273, val loss: 0.12186, in 0.031s
# [90/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.10262, val loss: 0.12179, in 0.032s
# [91/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.10231, val loss: 0.12164, in 0.028s
# [92/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.10225, val loss: 0.12155, in 0.046s
# [93/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.10191, val loss: 0.12139, in 0.028s
# [94/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.10155, val loss: 0.12125, in 0.029s
# [95/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.10111, val loss: 0.12095, in 0.043s
# [96/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.10097, val loss: 0.12096, in 0.029s
# [97/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.10082, val loss: 0.12092, in 0.029s
# [98/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.10070, val loss: 0.12089, in 0.029s
# [99/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.10039, val loss: 0.12069, in 0.028s
# [100/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.10000, val loss: 0.12062, in 0.046s
# Fit 100 trees in 4.821 s, (3100 total leaves)
# Time spent computing histograms: 2.080s
# Time spent finding best splits:  0.747s
# Time spent applying splits:      1.272s
# Time spent predicting:           0.037s
# Binning 0.071 GB of training data: 0.174 s
# Binning 0.008 GB of validation data: 0.028 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.41673, val loss: 0.41456, in 0.047s
# [2/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.34901, val loss: 0.34759, in 0.039s
# [3/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.29392, val loss: 0.29294, in 0.064s
# [4/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.24923, val loss: 0.24865, in 0.071s
# [5/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.21275, val loss: 0.21248, in 0.042s
# [6/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.18329, val loss: 0.18330, in 0.036s
# [7/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.15913, val loss: 0.15927, in 0.045s
# [8/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.13944, val loss: 0.13971, in 0.065s
# [9/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.12347, val loss: 0.12379, in 0.073s
# [10/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.11031, val loss: 0.11072, in 0.045s
# [11/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.09966, val loss: 0.10007, in 0.061s
# [12/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.09076, val loss: 0.09112, in 0.042s
# [13/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.08356, val loss: 0.08395, in 0.047s
# [14/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.07757, val loss: 0.07787, in 0.059s
# [15/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.07261, val loss: 0.07293, in 0.043s
# [16/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.06854, val loss: 0.06889, in 0.043s
# [17/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.06507, val loss: 0.06544, in 0.045s
# [18/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.06222, val loss: 0.06258, in 0.061s
# [19/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05993, val loss: 0.06029, in 0.048s
# [20/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05797, val loss: 0.05834, in 0.058s
# [21/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.05629, val loss: 0.05667, in 0.048s
# [22/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05494, val loss: 0.05531, in 0.061s
# [23/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.05374, val loss: 0.05407, in 0.044s
# [24/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.05269, val loss: 0.05301, in 0.097s
# [25/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05175, val loss: 0.05207, in 0.914s
# [26/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.05089, val loss: 0.05117, in 0.187s
# [27/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.05017, val loss: 0.05046, in 0.085s
# [28/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04957, val loss: 0.04985, in 0.036s
# [29/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.04908, val loss: 0.04937, in 0.036s
# [30/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04859, val loss: 0.04890, in 0.037s
# [31/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04810, val loss: 0.04841, in 0.052s
# [32/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04764, val loss: 0.04793, in 0.031s
# [33/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04728, val loss: 0.04758, in 0.035s
# [34/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.04679, val loss: 0.04708, in 0.052s
# [35/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04650, val loss: 0.04678, in 0.038s
# [36/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04624, val loss: 0.04653, in 0.034s
# [37/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04599, val loss: 0.04628, in 0.034s
# [38/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.04571, val loss: 0.04598, in 0.053s
# [39/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04544, val loss: 0.04574, in 0.035s
# [40/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04523, val loss: 0.04555, in 0.044s
# [41/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04504, val loss: 0.04538, in 0.033s
# [42/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04486, val loss: 0.04522, in 0.053s
# [43/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04467, val loss: 0.04502, in 0.036s
# [44/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.04451, val loss: 0.04485, in 0.042s
# [45/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04435, val loss: 0.04468, in 0.045s
# [46/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04421, val loss: 0.04455, in 0.049s
# [47/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04408, val loss: 0.04444, in 0.036s
# [48/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.04394, val loss: 0.04434, in 0.031s
# [49/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04381, val loss: 0.04424, in 0.045s
# [50/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.04369, val loss: 0.04412, in 0.052s
# [51/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04357, val loss: 0.04402, in 0.057s
# [52/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.04337, val loss: 0.04385, in 0.045s
# [53/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.04324, val loss: 0.04372, in 0.050s
# [54/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04305, val loss: 0.04354, in 0.034s
# [55/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.04295, val loss: 0.04345, in 0.034s
# [56/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.04283, val loss: 0.04336, in 0.046s
# [57/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.04272, val loss: 0.04327, in 0.039s
# [58/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.04252, val loss: 0.04307, in 0.034s
# [59/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04243, val loss: 0.04300, in 0.038s
# [60/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.04233, val loss: 0.04294, in 0.054s
# [61/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.04212, val loss: 0.04272, in 0.029s
# [62/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04202, val loss: 0.04265, in 0.037s
# [63/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.04195, val loss: 0.04259, in 0.060s
# [64/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04180, val loss: 0.04244, in 0.033s
# [65/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.04170, val loss: 0.04234, in 0.032s
# [66/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04164, val loss: 0.04229, in 0.053s
# [67/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.04155, val loss: 0.04223, in 0.031s
# [68/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.04148, val loss: 0.04217, in 0.028s
# [69/100] 1 tree, 31 leaves, max depth = 18, train loss: 0.04140, val loss: 0.04213, in 0.058s
# [70/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.04132, val loss: 0.04206, in 0.038s
# [71/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04126, val loss: 0.04200, in 0.031s
# [72/100] 1 tree, 31 leaves, max depth = 16, train loss: 0.04121, val loss: 0.04198, in 0.033s
# [73/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04106, val loss: 0.04181, in 0.051s
# [74/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04098, val loss: 0.04175, in 0.033s
# [75/100] 1 tree, 31 leaves, max depth = 18, train loss: 0.04087, val loss: 0.04167, in 0.036s
# [76/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04081, val loss: 0.04163, in 0.047s
# [77/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04070, val loss: 0.04152, in 0.038s
# [78/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04066, val loss: 0.04148, in 0.030s
# [79/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.04057, val loss: 0.04138, in 0.047s
# [80/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.04050, val loss: 0.04133, in 0.031s
# [81/100] 1 tree, 31 leaves, max depth = 15, train loss: 0.04039, val loss: 0.04123, in 0.032s
# [82/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04031, val loss: 0.04115, in 0.034s
# [83/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04027, val loss: 0.04113, in 0.040s
# [84/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.04018, val loss: 0.04106, in 0.033s
# [85/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04012, val loss: 0.04101, in 0.034s
# [86/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04008, val loss: 0.04097, in 0.043s
# [87/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.04000, val loss: 0.04091, in 0.028s
# [88/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.03994, val loss: 0.04085, in 0.036s
# [89/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.03988, val loss: 0.04080, in 0.060s
# [90/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.03983, val loss: 0.04077, in 0.035s
# [91/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.03980, val loss: 0.04075, in 0.121s
# [92/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.03974, val loss: 0.04072, in 0.185s
# [93/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.03969, val loss: 0.04067, in 0.138s
# [94/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.03963, val loss: 0.04062, in 0.105s
# [95/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.03957, val loss: 0.04057, in 0.099s
# [96/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.03950, val loss: 0.04052, in 0.030s
# [97/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.03945, val loss: 0.04047, in 0.043s
# [98/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.03942, val loss: 0.04045, in 0.031s
# [99/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.03937, val loss: 0.04041, in 0.030s
# [100/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.03933, val loss: 0.04038, in 0.044s
# Fit 100 trees in 6.095 s, (3100 total leaves)
# Time spent computing histograms: 2.652s
# Time spent finding best splits:  1.133s
# Time spent applying splits:      1.562s
# Time spent predicting:           0.049s
# XGBImputer - Epoch: 1 | Categorical gamma: inf/12. | Numerical gamma: inf/0.0175478018
# XGBImputer - Epoch: 2 | Categorical gamma: 12./12. | Numerical gamma: 0.0175478018/0.0010174972
# XGBImputer - Epoch: 3 | Categorical gamma: 12./5. | Numerical gamma: 0.0010174972/0.0006223228
# XGBImputer - Epoch: 4 | Categorical gamma: 5./0. | Numerical gamma: 0.0006223228/0.0006090931
# XGBImputer - Epoch: 5 | Categorical gamma: 0./0. | Numerical gamma: 0.0006090931/0.0002479977
# XGBImputer - Epoch: 6 | Categorical gamma: 0./3. | Numerical gamma: 0.0002479977/0.0004758112

# %% [markdown]
# ~ For Ref / Backup purposes ~
#
#
# ct1 = ColumnTransformer(
#     transformers=[
#         ('scaler', StandardScaler(), [  'AcceleratorPedal',
#                                         'BarometricPressure',
#                                         'CruiseControlSetSpeed',
#                                         'DistanceLtd',
#                                         'EngineCoolantTemperature',
#                                         'EngineLoad',
#                                         'EngineOilPressure',
#                                         'EngineOilTemperature',
#                                         'EngineRpm',
#                                         'EngineTimeLtd',
#                                         'FuelLevel',
#                                         'FuelLtd',
#                                         'FuelRate',
#                                         'FuelTemperature',
#                                         'IntakeManifoldTemperature',
#                                         'Speed',
#                                         'Throttle',
#                                         'active',
#                                         'TurboBoostPressure',
#                                         'CruiseControlActive',
#                                         'IgnStatus',
#                                         'ParkingBrake',
#                                         'SwitchedBatteryVoltage'
#                                         ]),
#
#          ('num_imputer', IterativeImputer(estimator=ExtraTreesRegressor(), max_iter=10, random_state=343), [
#                                         'AcceleratorPedal',
#                                         'BarometricPressure',
#                                         'CruiseControlSetSpeed',
#                                         'DistanceLtd',
#                                         'EngineCoolantTemperature',
#                                         'EngineLoad',
#                                         'EngineOilPressure',
#                                         'EngineOilTemperature',
#                                         'EngineRpm',
#                                         'EngineTimeLtd',
#                                         'FuelLevel',
#                                         'FuelLtd',
#                                         'FuelRate',
#                                         'FuelTemperature',
#                                         'IntakeManifoldTemperature',
#                                         'Speed',
#                                         'Throttle',
#                                         'active',
#                                         'TurboBoostPressure',
#                                         'CruiseControlActive',
#                                         'IgnStatus',
#                                         'ParkingBrake',
#                                         'SwitchedBatteryVoltage',
#                                         'spn_fmi',
#                                         'ecuSource',
#                                         'LampStatus',
#                                         'activeTransitionCount'
#                                         ])
#     ],
#     remainder='passthrough'
# )

# %% [markdown]
# ~ For Ref / Backup purposes ~
#
#
# xgbc_pipe = Pipeline(
#     steps=[
#         ('preprocessor0', ct0),
#         ('StandardScaler', StandardScaler()),
#         ('imputer', IterativeImputer(estimator=ExtraTreesRegressor(), max_iter=10, random_state=343)),
#         ('smote', SMOTE(random_state=3434)),
#         ('xgbc', XGBClassifier( enable_categorical=True,
#                                # max_cat_to_onehot=1,
#                                 booster='gbtree',
#                                 eval_metric='mlogloss',
#                                 objective = 'multi:softprob'
#                             )
#         )
#     ]
# ).fit(X_train, y_train)
#
# y_pred = xgbc_pipe.predict(X_test)

# %% [markdown]
# ~ For Ref / Backup purposes ~
#
# Other imputer methodologies to try: XGBImputer(), GradientBoostingRegressor(), ExtraTreesRegressor()

# %%
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {root_mean_squared_error(y_test, y_pred)}')
print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MAPE: {mean_absolute_percentage_error(y_test, y_pred)}')
print(f'R2: {r2_score(y_test, y_pred)}')
# Out:
# MSE: 3.0147336050467075
# RMSE: 1.7362988236610388
# MAE: 0.756553242130317
# MAPE: 2624147279006744.5
# R2: -0.025647898910128974

# %% [markdown]
# xgb = XGBClassifier(
#                     eval_metric='mlogloss'
#
#                     ).fit(X_train, y_train)

# %%
le_y
# Out:
# LabelEncoder()

# %%
y_fitted
# Out:
# LabelEncoder()

# %%
y_encoded
# Out:
# array([0, 0, 0, ..., 4, 4, 4], shape=(949528,))

# %%
y
# Out:
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
#            ...
# 949523    9999999
# 949524    9999999
# 949525    9999999
# 949526    9999999
# 949527    9999999
# Name: time_interval_to_SPN5246_class, Length: 949528, dtype: category
# Categories (5, int64): [0, 1, 2, 3, 9999999]

# %% [markdown]
# #RandomizedSearchCV
#
# param_dist = {
#     'max_depth': range(1, 10, 1),
#     'min_child_weight':range(1, 6, 1),
#     'learning_rate': stats.uniform(0.01, 0.1),
#     'subsample':[i/10.0 for i in range(1, 10)],
#     'colsample_bytree':[i/10.0 for i in range(1, 10)],
#     'n_estimators':stats.randint(1, 70),
#     'gamma':[i/10.0 for i in range(0, 5)],
#    # 'reg_alpha':[1e-5, 1e-2, 0.1, 1, 100],
#     'reg_alpha':[0, 0.001, 0.005, 0.01, 0.05]
#
# }
#
#
#
# # xgb_model = XGBClassifier()
#
# # Create the RandomizedSearchCV object
# cv = RepeatedStratifiedKFold(n_splits=10, shuffle=True, random_state=343)
# random_search = RandomizedSearchCV(xgbc_pipe[1], param_distributions=param_dist, n_iter=20, cv=cv, scoring='precision_macro', verbose=2, n_jobs=-1, random_state=321)
#
# # Fit the RandomizedSearchCV object to the training data
# random_search.fit(X_train, y_train)
#
# # Print the best set of hyperparameters and the corresponding score
# print("Best set of hyperparameters: ", random_search.best_params_)
# print("Best score: ", random_search.best_score_)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8092582646151254

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 18231,      6,      6,      0,  27659],
#        [    85,     82,      4,      0,    276],
#        [    50,      8,     54,      3,    138],
#        [     7,      0,      2,     88,     70],
#        [  7902,      4,      0,      3, 135228]])

# %% [markdown]
# Without ExtraTrees Imputer or SMOTE + XGBClassifier(): 106/(71+106+14+256) = 0.23 precision score for Time Interval Class 1
# With HistGradientBoostImputer + SMOTE + XGBClassifier(tree_method = "hist"): 0.6375838926 precision score for Time Interval Class 1
# With GradientBoostImputer + SMOTE + XGBClassifier(tree_method = "hist"): ___ precision score for Time Interval Class 1
# With GradientBoostImputer + SMOTE + XGBClassifier(): ___ precision score for Time Interval Class 1

# %%
print(classification_report(y_test, y_pred, zero_division = 0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.40      0.51     45902
#            1       0.82      0.18      0.30       447
#            2       0.82      0.21      0.34       253
#            3       0.94      0.53      0.67       167
#            4       0.83      0.94      0.88    143137
#
#     accuracy                           0.81    189906
#    macro avg       0.82      0.45      0.54    189906
# weighted avg       0.80      0.81      0.79    189906

# %% [markdown]
# scores = cross_val_score(xgbc_pipe, X_test, y_test, cv=10, scoring='precision_macro')

# %% [markdown]
# print('Cross Validation Macro Precision Scores:', scores)

# %% [markdown]
# ### Top Features' Importance

# %% [markdown]
# selection = SelectFromModel(xgbc_pipe[1], threshold=0.0001, prefit=True)

# %% [markdown]
# X_selected = selection.transform(X_train)
# X_selected

# %% [markdown]
# plot_importance_object = plot_importance(xgbc_pipe[1], importance_type='gain')
# plt.title('Feature Importance for Full Derate Prediction')
# plt.show()

# %% [markdown]
# feature_importances = xgbc_pipe[1].feature_importances_
#
# feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importances})
#
# feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
#
# top_27_features = feature_importance_df.head(27)
#
# print(top_27_features)

# %% [markdown]
# print("Top 27 features:", top_27_features['Feature'].tolist())

# %% [markdown]
# ### Import fresh test data (previously held out) for a fresh round of testing

# %%
test = pd.read_csv('../data/In2019_df_Cat9999999.csv')

# %%
FreshTest_In2019 = test
FreshTest_In2019
# Out:
#         Unnamed: 0.1  Unnamed: 0  RecordID    ESS_Id       EventTimeStamp  \
# 0             952775     1062090   1104925  73930906  2019-01-11 12:51:18
# 1             952776     1062091   1104926  73930907  2019-01-11 12:51:18
# 2             952781     1062096   1104931  73934247  2019-01-11 13:11:40
# 3             952782     1062097   1104932  73934248  2019-01-11 13:11:40
# 4             952809     1062135   1104970  73942005  2019-01-11 13:13:38
# ...              ...         ...       ...       ...                  ...
# 112014        977126     1089938   1137548  80503703  2019-03-16 11:22:32
# 112015        977150     1089962   1137572  80509396  2019-03-16 11:24:04
# 112016        977151     1089963   1137573  80509397  2019-03-16 11:27:41
# 112017        978491     1091502   1139112  80907838  2019-03-20 10:57:34
# 112018        978891     1091973   1139583  81025027  2019-03-21 10:05:14
#
#                                          eventDescription  actionDescription  \
# 0                               High Voltage (Fuel Level)                NaN
# 1                   High Voltage (Left Fuel Level Sensor)                NaN
# 2                               High Voltage (Fuel Level)                NaN
# 3                   High Voltage (Left Fuel Level Sensor)                NaN
# 4                               High Voltage (Fuel Level)                NaN
# ...                                                   ...                ...
# 112014  Incorrect Data J1939 Network #1 Primary Vehicl...                NaN
# 112015  Special Instructions Engine Starter Solenoid L...                NaN
# 112016                                                NaN                NaN
# 112017  Special Instructions Engine Starter Solenoid L...                NaN
# 112018                                                NaN                NaN
#
#                                        ecuSoftwareVersion ecuSerialNumber  \
# 0                                                 unknown         unknown
# 1                                                 unknown         unknown
# 2                                                 unknown         unknown
# 3                                                 unknown         unknown
# 4                                                 unknown         unknown
# ...                                                   ...             ...
# 112014  AAAI000051*AAAM010056*Z091290   *A82J170202A_b...      6232171647
# 112015                                5569997 *E250.e003*        K1243673
# 112016                                5569997 *E250.e003*        K1243673
# 112017                                                NaN        K1243673
# 112018                                5569997 *E250.e003*        K1243673
#
#                ecuModel  ...     Speed  SwitchedBatteryVoltage  Throttle  \
# 0               unknown  ...  46.52031                     NaN      34.4
# 1               unknown  ...  46.52031                     NaN      34.4
# 2               unknown  ...       NaN                     NaN       NaN
# 3               unknown  ...       NaN                     NaN       NaN
# 4               unknown  ...   0.00000                     NaN       0.0
# ...                 ...  ...       ...                     ...       ...
# 112014          EC80ESP  ...       NaN                     NaN       NaN
# 112015  FAOM-xx810S-EC3  ...   0.00000                     NaN     100.0
# 112016  FAOM-xx810S-EC3  ...   0.00000                     NaN     100.0
# 112017  FAOM-xx810S-EC3  ...       NaN                     NaN       NaN
# 112018  FAOM-xx810S-EC3  ...       NaN                     NaN       NaN
#
#         TurboBoostPressure        spn_fmi  is_fullderate  is_fullderate_group  \
# 0                    13.05       96.0_3.0              0                    1
# 1                    13.05      829.0_3.0              0                    1
# 2                      NaN       96.0_3.0              0                    1
# 3                      NaN      829.0_3.0              0                    1
# 4                     1.16       96.0_3.0              0                    1
# ...                    ...            ...            ...                  ...
# 112014                 NaN      639.0_2.0              0                    0
# 112015                0.29    1321.0_14.0              0                    0
# 112016                0.29  520321.0_13.0              0                    0
# 112017                 NaN    1321.0_14.0              0                    0
# 112018                 NaN  520321.0_13.0              0                    0
#
#         EquipID_Index  time_to_next_SPN5246  time_interval_to_SPN5246_class
# 0               301_1           239999976.0                         9999999
# 1               301_1           239999976.0                         9999999
# 2               301_1           239999976.0                         9999999
# 3               301_1           239999976.0                         9999999
# 4               301_1           239999976.0                         9999999
# ...               ...                   ...                             ...
# 112014    105437340_0           239999976.0                         9999999
# 112015    105437340_0           239999976.0                         9999999
# 112016    105437340_0           239999976.0                         9999999
# 112017    105437340_0           239999976.0                         9999999
# 112018    105437340_0           239999976.0                         9999999
#
# [112019 rows x 53 columns]

# %%
FreshTest_In2019[['ecuSource', 'LampStatus', 'time_interval_to_SPN5246_class', 'ecuSerialNumber', 'ecuModel', 'ecuMake']] = FreshTest_In2019[['ecuSource', 'LampStatus', 'time_interval_to_SPN5246_class', 'ecuSerialNumber', 'ecuModel', 'ecuMake']].astype('category')

# %%
FreshTest_In2019[['activeTransitionCount']] = FreshTest_In2019[['activeTransitionCount']].astype('category')

# %%
X_fresh_test = FreshTest_In2019.drop(columns = [    'Unnamed: 0',
                                                    'Unnamed: 0.1',
                                                    'RecordID',
                                                    'ESS_Id',
                                                    'actionDescription',
                                                    'spn',
                                                    'fmi',
                                                    'faultValue',
                                                    'MCTNumber',
                                                    'Latitude',
                                                    'Longitude',
                                                    'is_fullderate',
                                                    'is_fullderate_group',
                                                    'time_to_next_SPN5246',
                                                    'ServiceDistance',
                                                    'EventTimeStamp',
                                                    'eventDescription',
                                                    'EquipmentID',
                                                    'LocationTimeStamp',
                                                    'EquipID_Index',
                                                    'time_interval_to_SPN5246_class',
                                                    'MCTNumber',                                  
                                                    'FaultId',
                                                    'ecuSoftwareVersion',
                                                    'ecuSerialNumber',
                                                    'ecuModel',
                                                    'ecuMake'  
                                                    ]
                                     )  
X_fresh_test
# Out:
#        ecuSource  active activeTransitionCount  AcceleratorPedal  \
# 0             49    True                   126              34.0
# 1             49    True                   126              34.0
# 2             49   False                   126               NaN
# 3             49   False                   126               NaN
# 4             49    True                   126               0.0
# ...          ...     ...                   ...               ...
# 112014        11   False                   127               NaN
# 112015         3    True                     1               0.0
# 112016         3    True                     4               0.0
# 112017         3   False                     5               NaN
# 112018         3   False                    12               NaN
#
#         BarometricPressure CruiseControlActive  CruiseControlSetSpeed  \
# 0                     14.5               False                    0.0
# 1                     14.5               False                    0.0
# 2                      NaN                 NaN                    NaN
# 3                      NaN                 NaN                    NaN
# 4                     14.5               False                    0.0
# ...                    ...                 ...                    ...
# 112014                 NaN                 NaN                    NaN
# 112015                14.5               False                    0.0
# 112016                14.5               False                    0.0
# 112017                 NaN                 NaN                    NaN
# 112018                 NaN                 NaN                    NaN
#
#         DistanceLtd  EngineCoolantTemperature  EngineLoad  ...  \
# 0          389864.2                     145.4        46.0  ...
# 1          389864.2                     145.4        46.0  ...
# 2               NaN                       NaN         NaN  ...
# 3               NaN                       NaN         NaN  ...
# 4          389870.2                     156.2        13.0  ...
# ...             ...                       ...         ...  ...
# 112014          NaN                       NaN         NaN  ...
# 112015     147893.8                      82.4        25.0  ...
# 112016     147893.8                      91.4        24.0  ...
# 112017          NaN                       NaN         NaN  ...
# 112018          NaN                       NaN         NaN  ...
#
#         FuelTemperature  IgnStatus  IntakeManifoldTemperature  LampStatus  \
# 0                  71.6       True                       84.2      1279.0
# 1                  71.6       True                       84.2      1279.0
# 2                   NaN        NaN                        NaN       255.0
# 3                   NaN        NaN                        NaN       255.0
# 4                  87.8       True                      107.6      1279.0
# ...                 ...        ...                        ...         ...
# 112014              NaN        NaN                        NaN     50175.0
# 112015              NaN       True                       68.0     63487.0
# 112016              NaN       True                       73.4     63487.0
# 112017              NaN        NaN                        NaN     63487.0
# 112018              NaN        NaN                        NaN       255.0
#
#         ParkingBrake     Speed  SwitchedBatteryVoltage  Throttle  \
# 0              False  46.52031                     NaN      34.4
# 1              False  46.52031                     NaN      34.4
# 2                NaN       NaN                     NaN       NaN
# 3                NaN       NaN                     NaN       NaN
# 4               True   0.00000                     NaN       0.0
# ...              ...       ...                     ...       ...
# 112014           NaN       NaN                     NaN       NaN
# 112015          True   0.00000                     NaN     100.0
# 112016          True   0.00000                     NaN     100.0
# 112017           NaN       NaN                     NaN       NaN
# 112018           NaN       NaN                     NaN       NaN
#
#        TurboBoostPressure        spn_fmi
# 0                   13.05       96.0_3.0
# 1                   13.05      829.0_3.0
# 2                     NaN       96.0_3.0
# 3                     NaN      829.0_3.0
# 4                    1.16       96.0_3.0
# ...                   ...            ...
# 112014                NaN      639.0_2.0
# 112015               0.29    1321.0_14.0
# 112016               0.29  520321.0_13.0
# 112017                NaN    1321.0_14.0
# 112018                NaN  520321.0_13.0
#
# [112019 rows x 27 columns]

# %%
X_fresh_test['spn_fmi'] = X_fresh_test['spn_fmi'].str.replace('.0', '')

# %%
X_fresh_test.shape
# Out:
# (112019, 27)

# %% [markdown]
# X_FreshTest_Transformed = ct.transform(X_fresh_test)
# X_FreshTest_Transformed

# %%
y_fresh_pred = xgbc_pipe.predict(X_fresh_test)
# Out:
# XGBImputer - Epoch: 1 | Categorical gamma: inf/3.5 | Numerical gamma: inf/0.032006046
# XGBImputer - Epoch: 2 | Categorical gamma: 3.5/0. | Numerical gamma: 0.032006046/0.0026867768
# XGBImputer - Epoch: 3 | Categorical gamma: 0./167.5 | Numerical gamma: 0.0026867768/0.0012965534
# XGBImputer - Epoch: 4 | Categorical gamma: 167.5/6. | Numerical gamma: 0.0012965534/0.0011525417
# XGBImputer - Epoch: 5 | Categorical gamma: 6./31.5 | Numerical gamma: 0.0011525417/0.0014828868

# %%
y_fresh_pred
# Out:
# array([4, 4, 4, ..., 4, 4, 4], shape=(112019,), dtype=int32)

# %%
y_fresh_test = FreshTest_In2019['time_interval_to_SPN5246_class']

# %%
y_fresh_test_encoded = le_y.transform(y_fresh_test)

# %%
accuracy_score(y_fresh_test_encoded, y_fresh_pred)
# Out:
# 0.9565073782126247

# %%
confusion_matrix(y_fresh_test_encoded, y_fresh_pred)
# Out:
# array([[    99,      6,      9,      6,   1993],
#        [    14,      4,      6,      0,    287],
#        [     6,      1,      6,      0,    127],
#        [     1,      0,      0,     40,     60],
#        [  1962,     25,    137,    232, 106998]])

# %% [markdown]
# Without ExtraTrees Imputer or SMOTE + XGBClassifier(): 0 precision score for Time Interval Class 1
# With HistGradientBoostImputer + SMOTE + XGBClassifier(tree_method = "hist"): 0.421221865 precision score for Time Interval Class 1
# With GradientBoostImputer + SMOTE + XGBClassifier(tree_method = "hist"): ___ precision score for Time Interval Class 1
# With GradientBoostImputer + SMOTE + XGBClassifier(): ___ precision score for Time Interval Class 1

# %%
print(classification_report(y_fresh_test_encoded, y_fresh_pred, zero_division = 0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.05      0.05      0.05      2113
#            1       0.11      0.01      0.02       311
#            2       0.04      0.04      0.04       140
#            3       0.14      0.40      0.21       101
#            4       0.98      0.98      0.98    109354
#
#     accuracy                           0.96    112019
#    macro avg       0.26      0.30      0.26    112019
# weighted avg       0.96      0.96      0.96    112019

# %%
print(f'MSE: {mean_squared_error(y_fresh_test_encoded, y_fresh_pred)}')
print(f'RMSE: {root_mean_squared_error(y_fresh_test_encoded, y_fresh_pred)}')
print(f'MAE: {mean_absolute_error(y_fresh_test_encoded, y_fresh_pred)}')
print(f'MAPE: {mean_absolute_percentage_error(y_fresh_test_encoded, y_fresh_pred)}')
print(f'R2: {r2_score(y_fresh_test_encoded, y_fresh_pred)}')
# Out:
# MSE: 0.6033440755586106
# RMSE: 0.7767522613797855
# MAE: 0.15759826458011586
# MAPE: 322193979715469.3
# R2: -0.85591267391276

# %% [markdown]
# fresh_CV_scores = cross_val_score(xgbc_pipe, X_fresh_test, y_fresh_test_encoded, cv=10, scoring='precision_macro')

# %% [markdown]
# print('Cross Validation Macro Precision Scores:', fresh_CV_scores)

# %%
# submission.to_csv('../data/submission_XGBClassifier_TunedHyperparameter_TargetEncoder_LearningRatePt05_MaxTreeDepth5_MinChild1_Estimators199_TestSizePt001_MostFeatures_ExcludingMapCode.csv', index = False)
